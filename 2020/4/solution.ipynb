# %%
with open('input.txt', 'r') as f:
    inp = [line.strip() for line in f]
inp
# Out:
# ['eyr:2024 pid:662406624 hcl:#cfa07d byr:1947 iyr:2015 ecl:amb hgt:150cm',
#  '',
#  'iyr:2013 byr:1997 hgt:182cm hcl:#ceb3a1',
#  'eyr:2027',
#  'ecl:gry cid:102 pid:018128535',
#  '',
#  'hgt:61in iyr:2014 pid:916315544 hcl:#733820 ecl:oth',
#  '',
#  'hcl:#a97842',
#  'eyr:2026 byr:1980 ecl:grn pid:726519569 hgt:184cm cid:132 iyr:2011',
#  '',
#  'ecl:grn hcl:#6b5442 pid:619743219 cid:69 hgt:176cm eyr:2027 iyr:2012',
#  'byr:1980',
#  '',
#  'ecl:brn byr:1969 iyr:2014',
#  'hgt:164cm eyr:2020 pid:982796633 hcl:#602927',
#  '',
#  'ecl:gmt',
#  'iyr:1987 eyr:2039 pid:15115163 byr:2006',
#  'hcl:bfab0d',
#  '',
#  'cid:117',
#  'hcl:#efcc98',
#  'iyr:2010 pid:322719183',
#  'hgt:176cm',
#  'eyr:2020',
#  'byr:1957',
#  'ecl:brn',
#  '',
#  'byr:1954 hgt:178cm hcl:#38f7fd pid:838813262 ecl:blu',
#  'eyr:2029 iyr:2019',
#  '',
#  'eyr:2023 ecl:amb iyr:2020 byr:1927 pid:242570886 hcl:#18171d hgt:192cm',
#  '',
#  'iyr:1990 cid:295 hgt:131 pid:187cm byr:2014',
#  'ecl:xry hcl:z',
#  'eyr:1928',
#  '',
#  'ecl:hzl',
#  'byr:1953',
#  'eyr:2023 hcl:#866857',
#  'hgt:181cm iyr:2010 pid:568185567',
#  '',
#  'byr:2030 hcl:#fffffd ecl:#a4a596 hgt:168cm',
#  'iyr:1936 eyr:2020 cid:296 pid:168786676',
#  '',
#  'byr:2030 iyr:2026 eyr:1974 hcl:7fcaa5 ecl:utc',
#  'pid:190cm',
#  'hgt:67cm',
#  '',
#  'byr:2023 eyr:2037 hgt:59cm',
#  'ecl:lzr hcl:z iyr:2026 pid:#ea9083',
#  '',
#  'byr:2003 hcl:z hgt:91 iyr:1990 eyr:2024 ecl:#123d73',
#  'pid:48494230',
#  '',
#  'byr:2022 eyr:2020 iyr:2030 ecl:gmt',
#  'hgt:191cm pid:3509331253 hcl:#888785',
#  '',
#  'iyr:1994',
#  'ecl:#c3d564 byr:2009',
#  'hgt:162cm hcl:336498 pid:#e99d09',
#  'cid:288',
#  'eyr:1921',
#  '',
#  'byr:1924 cid:290 iyr:2010 ecl:amb eyr:2020',
#  'hgt:156cm hcl:#7d3b0c pid:795497164',
#  '',
#  'cid:301 iyr:2017 hgt:67cm',
#  'hcl:#888785 ecl:#0405b9 byr:1964 pid:707857518 eyr:1976',
#  '',
#  'ecl:gry pid:474303066',
#  'iyr:2011 hcl:#18171d hgt:165cm byr:1921 eyr:2024',
#  '',
#  'hcl:#6b5442 ecl:amb iyr:2020 hgt:191cm',
#  'byr:1949 cid:301',
#  'pid:075846582 eyr:2029',
#  '',
#  'hcl:#a97842 cid:186 iyr:2014',
#  'ecl:gry',
#  'hgt:191cm eyr:2023 pid:645548969',
#  'byr:1956',
#  '',
#  'pid:154cm hcl:z ecl:gmt iyr:1989 hgt:69in cid:53 byr:2010',
#  '',
#  'hgt:72cm byr:2023',
#  'eyr:2034 hcl:z ecl:#f5249e iyr:1997 pid:#79af7a',
#  '',
#  'eyr:2038 byr:2015',
#  'hgt:70cm ecl:grt hcl:9d58a1 iyr:1926 pid:6290928420',
#  '',
#  'pid:620857794 eyr:2022',
#  'byr:1950',
#  'hgt:159cm',
#  'hcl:#ceb3a1 ecl:amb iyr:2015',
#  '',
#  'eyr:1954 ecl:#ab2ce4 pid:#14eedd',
#  'iyr:2009',
#  'hcl:29e484',
#  'byr:2022 hgt:73cm',
#  '',
#  'hgt:59cm byr:2026 cid:245 iyr:2020',
#  'eyr:2029 pid:073943129 ecl:hzl',
#  'hcl:#b6652a',
#  '',
#  'iyr:2014 byr:2015 hcl:#a97842 eyr:2029',
#  'pid:#132098',
#  'hgt:150 ecl:oth',
#  '',
#  'hgt:151in ecl:#967d49 eyr:2026 hcl:#18171d',
#  'pid:384230726 byr:1934',
#  'iyr:2018',
#  '',
#  'iyr:2020 eyr:2021 byr:1937 pid:735047371 cid:159 ecl:blu hgt:177cm hcl:#22b774',
#  '',
#  'ecl:brn hcl:#6b5442 pid:117807698 cid:105 iyr:2016 byr:1977 hgt:183cm',
#  '',
#  'ecl:hzl hcl:#6b5442 byr:1933',
#  'iyr:2019 pid:348486702',
#  'eyr:2020 hgt:193cm',
#  '',
#  'byr:1928',
#  'ecl:gry',
#  'eyr:2028 hcl:#fffffd pid:571149069',
#  'iyr:2012 hgt:175cm',
#  '',
#  'pid:359108298',
#  'eyr:2027 hgt:158cm ecl:amb iyr:2016',
#  'hcl:#602927',
#  '',
#  'iyr:2027 byr:2015',
#  'hgt:191in pid:102033301 ecl:xry',
#  'eyr:2031 hcl:#602927',
#  '',
#  'ecl:oth cid:163 hcl:z iyr:2014',
#  'byr:1944 hgt:173cm',
#  'eyr:2027 pid:#0524c1',
#  '',
#  'ecl:brn',
#  'byr:2030 hgt:71cm eyr:1931 cid:165 iyr:2010 hcl:#cfa07d',
#  'pid:509642098',
#  '',
#  'hgt:166 iyr:2020 cid:308',
#  'eyr:2022 pid:950463527',
#  'byr:2017',
#  'hcl:z',
#  '',
#  'ecl:amb',
#  'eyr:2023 byr:1924',
#  'pid:901038027 hgt:70in',
#  'iyr:2010 hcl:z',
#  '',
#  'byr:1972',
#  'iyr:2013',
#  'hcl:d669ad hgt:64cm cid:247 ecl:#19aa26 eyr:2023',
#  '',
#  'hgt:71 hcl:#fffffd',
#  'byr:1976 cid:108 eyr:2038',
#  'ecl:grt iyr:2018 pid:190cm',
#  '',
#  'iyr:2017',
#  'byr:1963 ecl:grn hgt:175cm',
#  'pid:160915270 eyr:2028 hcl:#cfa07d',
#  '',
#  'pid:569740130 hgt:171cm hcl:#733820',
#  'ecl:gry eyr:2024 iyr:2020 byr:1973',
#  '',
#  'byr:1937',
#  'iyr:2016 ecl:gry hgt:181cm pid:521705827 hcl:#b6652a eyr:2027 cid:295',
#  '',
#  'hgt:156cm ecl:blu iyr:2019 hcl:#866857',
#  'pid:662418718 byr:2000 eyr:2024',
#  '',
#  'byr:1971 pid:693616099',
#  'hcl:#efcc98',
#  'hgt:175cm iyr:2016 ecl:gry',
#  'eyr:2023',
#  '',
#  'iyr:2013',
#  'eyr:2024',
#  'ecl:gry',
#  'pid:414295491 byr:1986',
#  'hgt:188cm hcl:#b6652a',
#  '',
#  'eyr:2022 byr:1975 iyr:2020',
#  'ecl:grn cid:68 hcl:#a97842',
#  'hgt:151cm pid:229803943',
#  '',
#  'cid:258 iyr:2012',
#  'ecl:hzl',
#  'byr:2001',
#  'eyr:2021',
#  'hcl:#866857 pid:990590217 hgt:172cm',
#  '',
#  'cid:339 byr:1957 hcl:#866857 pid:343480061 eyr:2039',
#  'hgt:191cm',
#  'iyr:2021',
#  'ecl:utc',
#  '',
#  'cid:281 hcl:z ecl:blu',
#  'byr:2020 pid:132694306 eyr:2020 iyr:1953',
#  '',
#  'hcl:#602927',
#  'byr:1933 eyr:2028',
#  'hgt:165cm ecl:gry iyr:2018 pid:658484617',
#  '',
#  'ecl:oth',
#  'hgt:188cm cid:110 pid:056975690 iyr:2016 byr:1950 eyr:2023 hcl:#cfa07d',
#  '',
#  'cid:342 hcl:#fffffd eyr:2024',
#  'pid:153555359 byr:1974',
#  'ecl:gry hgt:191cm iyr:2020',
#  '',
#  'byr:2019 ecl:#160ed3 eyr:1999 hcl:z',
#  'cid:146 pid:195693972 hgt:159cm',
#  '',
#  'iyr:2015 eyr:2030 hgt:191cm byr:1979',
#  'ecl:#ec4873 pid:994113786 hcl:#cfa07d',
#  '',
#  'pid:552331609',
#  'ecl:grn',
#  'hgt:171cm eyr:2022 hcl:#b6652a',
#  'iyr:2020 byr:1931',
#  '',
#  'hgt:177cm iyr:2010 pid:934058099',
#  'eyr:2020',
#  'ecl:blu',
#  'byr:1967',
#  'cid:112 hcl:#7d3b0c',
#  '',
#  'iyr:2028',
#  'hgt:138',
#  'cid:180 hcl:z',
#  'eyr:2022 pid:3286566621 byr:2002',
#  '',
#  'eyr:2020',
#  'iyr:2019',
#  'hcl:#a97842 pid:149148750 ecl:brn hgt:159cm',
#  'byr:1981 cid:339',
#  '',
#  'cid:344',
#  'eyr:2021 byr:1968 pid:777786047',
#  'ecl:grn hgt:192cm hcl:#888785',
#  'iyr:2015',
#  '',
#  'hgt:173cm',
#  'eyr:2030',
#  'hcl:#733820 pid:610226642 byr:1954 cid:80',
#  'iyr:2013 ecl:blu',
#  '',
#  'byr:1999 eyr:2023',
#  'ecl:amb pid:912145128',
#  'hgt:181cm',
#  'iyr:2015 hcl:#a97842',
#  '',
#  'eyr:2027 hgt:188cm',
#  'pid:080715145 hcl:#341e13 iyr:2013',
#  'ecl:oth',
#  'byr:1965',
#  '',
#  'hgt:170cm byr:1950 iyr:2013',
#  'pid:010541784',
#  'eyr:2027 ecl:zzz',
#  'hcl:a3bae8',
#  '',
#  'hgt:190cm eyr:2024 ecl:#6dcedc pid:909319684',
#  'iyr:2011 byr:1959 hcl:z cid:182',
#  '',
#  'eyr:2028',
#  'iyr:2016 hcl:#623a2f pid:208417572 byr:1929 cid:137 ecl:hzl',
#  'hgt:167cm',
#  '',
#  'hcl:#6b5442',
#  'ecl:grn',
#  'byr:1938',
#  'eyr:2023 cid:307',
#  'hgt:59in iyr:2014 pid:205268145',
#  '',
#  'pid:047489285 eyr:2026',
#  'hcl:#b6652a byr:1920',
#  'iyr:2015',
#  'hgt:183cm ecl:gry',
#  '',
#  'ecl:blu hcl:#508e8b iyr:2016 eyr:1954 hgt:151cm pid:086752750 byr:1920',
#  '',
#  'iyr:2011 byr:1981 hgt:186cm',
#  'cid:117 hcl:#6b5442 ecl:amb',
#  'pid:756830713 eyr:2026',
#  '',
#  'eyr:2037 pid:364464758 hcl:z ecl:grn',
#  'hgt:112 iyr:2013 byr:2022',
#  '',
#  'ecl:hzl',
#  'cid:65 pid:679487194',
#  'byr:1986 hgt:169cm hcl:#cfa07d eyr:2025 iyr:2013',
#  '',
#  'cid:192',
#  'byr:1921 pid:#5fe831 ecl:#fbb2b9 hgt:62cm eyr:1971 iyr:2024',
#  'hcl:z',
#  '',
#  'hcl:#cfa07d eyr:2026',
#  'hgt:74in',
#  'iyr:2019',
#  'ecl:xry',
#  'pid:622690982 byr:1982',
#  '',
#  'eyr:2026 pid:523515724 iyr:2013 byr:1973 hgt:167cm',
#  'ecl:grn hcl:#866857',
#  '',
#  'byr:2009',
#  'eyr:1985 pid:484497014 ecl:#0bfcf2 iyr:1992 cid:131 hcl:39d6b0 hgt:177in',
#  '',
#  'eyr:2020 iyr:2016 ecl:brn hcl:#ceb3a1 byr:1966 pid:696621560 cid:62',
#  'hgt:59in',
#  '',
#  'hgt:166cm hcl:#7d3b0c',
#  'iyr:2016',
#  'ecl:brn pid:190cm',
#  'eyr:2020',
#  'byr:2001',
#  '',
#  'eyr:2021',
#  'iyr:2012 hcl:#6b5442',
#  'ecl:amb hgt:169cm',
#  'pid:969150085',
#  'byr:1925',
#  '',
#  'ecl:brn hgt:175cm byr:1992 iyr:2016 pid:415209726 eyr:2027',
#  'cid:72 hcl:#866857',
#  '',
#  'iyr:2017',
#  'hcl:#733820 byr:1938 eyr:2020 pid:274486958 hgt:163cm',
#  '',
#  'hcl:4f5dd1 cid:336 ecl:grn iyr:1931 pid:6212280197',
#  'byr:2016 eyr:2037',
#  'hgt:187in',
#  '',
#  'iyr:2017 byr:1940 eyr:2025 pid:115098205 hgt:151cm',
#  'ecl:grn',
#  'cid:122',
#  'hcl:#6b5442',
#  '',
#  'hcl:#efcc98',
#  'iyr:2020 pid:709548547 hgt:179cm',
#  'eyr:2030 ecl:gry byr:1975',
#  '',
#  'cid:217 hcl:#888785 eyr:2029',
#  'ecl:hzl iyr:2013 pid:160053490',
#  'hgt:166cm byr:1992',
#  '',
#  'eyr:2024 cid:188 iyr:2016 hcl:ff3a59 ecl:xry pid:296357512 byr:2026',
#  '',
#  'hgt:154cm iyr:2010',
#  'ecl:blu pid:717041634 byr:1928 cid:123',
#  'eyr:2027',
#  'hcl:#a97842',
#  '',
#  'pid:391011205 ecl:hzl hgt:191cm iyr:2016 eyr:2028 cid:281 byr:1934',
#  '',
#  'byr:1937 hgt:65in',
#  'pid:667975382 ecl:gry cid:270 eyr:2024',
#  'iyr:2012',
#  '',
#  'hgt:179cm pid:065528723',
#  'hcl:#888785 byr:1937 eyr:2028',
#  'iyr:2013 ecl:hzl',
#  '',
#  'iyr:2027 cid:261 eyr:2037 ecl:#ced7d5 pid:157cm',
#  'hcl:3a80c1 byr:2029 hgt:187in',
#  '',
#  'eyr:2028',
#  'hgt:157cm hcl:#733820',
#  'iyr:2012 ecl:blu byr:1952 pid:915063263 cid:335',
#  '',
#  'eyr:2023 hcl:#efcc98 pid:490625944 byr:1961 ecl:grn hgt:155cm iyr:2018',
#  '',
#  'cid:247 pid:2807544665 eyr:2021',
#  'ecl:oth',
#  'hgt:191cm',
#  'byr:1928',
#  'iyr:2013 hcl:#623a2f',
#  '',
#  'eyr:2015',
#  'byr:2021',
#  'hcl:40d2fc hgt:69cm pid:159cm ecl:gmt',
#  '',
#  'hgt:175cm eyr:1992 cid:328 pid:263110997 ecl:#e53989 byr:2014 hcl:#a97842 iyr:2026',
#  '',
#  'pid:491396731 eyr:2027 hgt:172cm hcl:#623a2f cid:92 iyr:2017 byr:1983 ecl:grn',
#  '',
#  'hcl:#fffffd',
#  'iyr:2018 byr:1983 pid:714591144 ecl:grn eyr:2021',
#  'hgt:160cm',
#  '',
#  'eyr:2027',
#  'hgt:63in ecl:blu byr:1987 pid:397963077 iyr:2018 hcl:#ceb3a1',
#  '',
#  'eyr:2027',
#  'hgt:184cm',
#  'hcl:#6b5442 iyr:2012 byr:1984 ecl:blu pid:196287205',
#  '',
#  'iyr:1998',
#  'ecl:hzl',
#  'pid:7872103596 byr:1991',
#  'cid:275 eyr:2039',
#  'hgt:174cm hcl:0d2ad6',
#  '',
#  'iyr:2010 hcl:#efcc98',
#  'byr:1992 hgt:65cm eyr:2038 pid:383236012 cid:68 ecl:lzr',
#  '',
#  'hgt:190in cid:127',
#  'byr:1947 pid:515728209 hcl:#733820 iyr:2014 ecl:amb eyr:2020',
#  '',
#  'iyr:2017 eyr:2028',
#  'hcl:#623a2f',
#  'byr:1964 ecl:grn pid:198467794 hgt:169cm',
#  '',
#  'ecl:utc',
#  'hgt:59cm byr:2007 iyr:2030',
#  'hcl:7ac4db eyr:2038 pid:#7206c6',
#  '',
#  'iyr:2010',
#  'hcl:z eyr:2021 ecl:brn',
#  'hgt:173 cid:86',
#  'pid:194240791 byr:1975',
#  '',
#  'pid:9347286034',
#  'hgt:63cm',
#  'iyr:1992 eyr:2034 hcl:66031b ecl:grt byr:1929',
#  '',
#  'pid:593398904 byr:1939 iyr:2019 hcl:#b6652a ecl:gry eyr:2023',
#  'hgt:70cm',
#  '',
#  'byr:1991',
#  'iyr:2019 hgt:164cm pid:282852411 cid:340 ecl:amb',
#  'hcl:#341e13 eyr:2027',
#  '',
#  'eyr:2020',
#  'iyr:2014 ecl:grn hcl:#866857 hgt:158cm',
#  'byr:1931 pid:321748597',
#  '',
#  'cid:98 byr:2023 iyr:2019 pid:#48f79f',
#  'hcl:73c882 eyr:1973 hgt:151in',
#  'ecl:utc',
#  '',
#  'iyr:2023',
#  'hcl:#18171d',
#  'pid:52221892 eyr:2039',
#  'byr:2008 hgt:72cm ecl:#db8d14',
#  '',
#  'iyr:1966 cid:274',
#  'eyr:2034 pid:12256322',
#  'byr:2006 ecl:dne',
#  'hcl:985c2d',
#  '',
#  'hcl:#fd033b',
#  'eyr:2026 ecl:blu',
#  'iyr:2016',
#  'byr:1953 hgt:157cm',
#  'pid:502619036',
#  '',
#  'byr:2015 pid:159cm iyr:2025',
#  'hgt:158cm eyr:1943 hcl:z ecl:grn',
#  '',
#  'ecl:blu iyr:2016',
#  'pid:842400950',
#  'hcl:#733820',
#  'cid:266',
#  'eyr:2027 byr:1931',
#  'hgt:161cm',
#  '',
#  'iyr:2017 hgt:190cm byr:1994 pid:706570967',
#  'ecl:hzl hcl:#18171d',
#  'cid:180',
#  '',
#  'cid:197 pid:204952666 ecl:amb',
#  'hgt:70in iyr:2016 byr:1936 hcl:#98cbe3 eyr:2025',
#  '',
#  'pid:555499128',
#  'byr:1971 hgt:71in',
#  'cid:83 ecl:blu',
#  'hcl:#cfa07d eyr:2027',
#  '',
#  'ecl:hzl iyr:2014',
#  'pid:30428184 cid:237',
#  'hgt:171cm byr:1942 hcl:#888785 eyr:1986',
#  '',
#  'eyr:2025',
#  'pid:579385370 hgt:193cm',
#  'hcl:#c0946f byr:1979 iyr:2016',
#  'ecl:amb cid:284',
#  '',
#  'eyr:2029 byr:1946 pid:278271295',
#  'ecl:grn',
#  'hcl:#cfa07d cid:271',
#  'hgt:172cm',
#  'iyr:2020',
#  '',
#  'pid:731752614 eyr:2020 byr:1983',
#  'cid:248 ecl:oth hgt:179cm',
#  'iyr:2017 hcl:#fffffd',
#  '',
#  'hcl:z',
#  'cid:203 eyr:2032 ecl:#3f9d3d hgt:65cm pid:4042846885 byr:2019',
#  'iyr:1946',
#  '',
#  'hgt:171cm ecl:gry eyr:2027',
#  'iyr:2013',
#  'hcl:#7d3b0c pid:92288579',
#  'byr:1955',
#  '',
#  'ecl:brn hgt:164cm byr:1969 hcl:#cbf9c9 pid:022724981 eyr:2030 iyr:2013 cid:244',
#  '',
#  'hgt:162cm byr:1974 iyr:2015 pid:927525094 hcl:#3d3011 ecl:blu',
#  'eyr:2023',
#  '',
#  'hgt:157cm',
#  'eyr:2020',
#  'pid:221286943 hcl:#fffffd ecl:amb iyr:2018 byr:1945',
#  '',
#  'iyr:2019',
#  'eyr:2025 byr:1997 pid:341544323 hgt:174cm cid:113',
#  'ecl:hzl',
#  '',
#  'pid:138492032 hcl:e35302 ecl:#caaede',
#  'eyr:1931',
#  'byr:2001 hgt:156 iyr:1998',
#  '',
#  'pid:912182030 cid:189 hgt:162 hcl:#277b39',
#  'iyr:2013 eyr:2023 byr:2023 ecl:blu',
#  '',
#  'eyr:2027 hcl:#fffffd',
#  'ecl:brn',
#  'cid:304 iyr:2016 byr:1969',
#  'pid:866607511 hgt:192cm',
#  '',
#  'hgt:64in',
#  'ecl:amb',
#  'byr:1958',
#  'pid:720439412',
#  'iyr:2015 eyr:2022 hcl:#ceb3a1',
#  '',
#  'eyr:2024 hgt:159cm',
#  'pid:187867283 iyr:2016',
#  'ecl:oth hcl:#fffffd',
#  'byr:1988',
#  '',
#  'ecl:#910bf2 byr:1969 iyr:2011 hcl:z eyr:2024 pid:579502502',
#  'cid:103 hgt:174cm',
#  '',
#  'pid:718692455',
#  'eyr:2028',
#  'iyr:2016',
#  'hcl:#602927',
#  'ecl:blu byr:1954',
#  'cid:251 hgt:182cm',
#  '',
#  'eyr:2021 hcl:#341e13 ecl:amb',
#  'byr:1933 hgt:179cm iyr:2011 pid:083172316',
#  '',
#  'iyr:1998 hcl:z eyr:1944',
#  'byr:2006 pid:453368738',
#  'hgt:160 ecl:#9da5f1 cid:261',
#  '',
#  'hcl:#7d3b0c',
#  'iyr:2018',
#  'hgt:164cm eyr:2020 byr:1940 ecl:blu',
#  '',
#  'pid:993701676 eyr:2028 ecl:gry',
#  'byr:1951 hcl:#888785 cid:116',
#  'iyr:2020',
#  'hgt:192cm',
#  '',
#  'hcl:z eyr:2033',
#  'ecl:lzr iyr:2029 cid:326 hgt:68cm byr:2026',
#  'pid:96742419',
#  '',
#  'hcl:#a97842 ecl:brn',
#  'byr:1920',
#  'hgt:173cm iyr:2015',
#  'eyr:2024 pid:176967666',
#  '',
#  'byr:1930 eyr:2025 pid:792694131',
#  'hgt:179cm ecl:brn',
#  'hcl:#a97842',
#  'iyr:2015',
#  '',
#  'hgt:167cm byr:1960 eyr:2022 hcl:#efcc98',
#  'cid:87 ecl:blu iyr:2012',
#  'pid:431515059',
#  '',
#  'hcl:#cfa07d',
#  'eyr:2023',
#  'hgt:188cm ecl:grn pid:081575957 byr:1938 iyr:2012',
#  '',
#  'iyr:2010 byr:1973',
#  'cid:108',
#  'eyr:2026',
#  'pid:880191154 hcl:#888785 hgt:181cm',
#  'ecl:brn',
#  '',
#  'eyr:2021 iyr:2010 byr:1942 hcl:#7d3b0c ecl:hzl pid:886241926 hgt:171cm',
#  '',
#  'cid:53 byr:1993',
#  'pid:150cm eyr:2035',
#  'hcl:#888785 hgt:153cm ecl:#128262 iyr:2021',
#  '',
#  'ecl:gry',
#  'pid:555911148',
#  'hcl:#733820 eyr:2022 hgt:154cm iyr:2012',
#  'byr:1935 cid:338',
#  '',
#  'hcl:#b6652a',
#  'pid:833873846 iyr:2012',
#  'hgt:167cm eyr:2023 byr:1984',
#  '',
#  'eyr:2024',
#  'ecl:blu byr:1955',
#  'hcl:#b6652a pid:517975316 iyr:2010 hgt:166cm',
#  '',
#  'pid:133785752',
#  'ecl:blu',
#  'eyr:2024',
#  'byr:1973',
#  'iyr:2019 hcl:#fffffd',
#  'cid:236 hgt:173cm',
#  '',
#  'cid:222',
#  'byr:2013 hcl:z eyr:2036 pid:7443967478 ecl:brn',
#  'iyr:2030 hgt:62cm',
#  '',
#  'hgt:193cm cid:259',
#  'hcl:#18171d',
#  'ecl:grn',
#  'byr:1995 pid:727880050 eyr:2030 iyr:2010',
#  '',
#  'hcl:#c0946f cid:275 eyr:1954 pid:772184635 ecl:#76add7 byr:2009 iyr:2018 hgt:151cm',
#  '',
#  'ecl:#52ed0f eyr:2033 hcl:#18171d pid:475397948',
#  'byr:1946 iyr:2028 hgt:178cm',
#  '',
#  'iyr:2012 hgt:152cm',
#  'eyr:2027 byr:1923 ecl:brn',
#  'hcl:#18171d pid:513722888 cid:171',
#  '',
#  'iyr:2029',
#  'hgt:111 hcl:z ecl:#33e3bc eyr:1930',
#  'byr:1934 pid:94036732',
#  '',
#  'hgt:154cm eyr:2024 hcl:#6b5442 iyr:2017',
#  'byr:1974',
#  'ecl:amb pid:470968353 cid:345',
#  '',
#  'hgt:184cm hcl:#617375 eyr:2028',
#  'byr:1975 ecl:oth',
#  'iyr:2018 pid:735589126',
#  '',
#  'cid:261',
#  'hcl:#cfa07d pid:213013397',
#  'hgt:187cm',
#  'ecl:gry iyr:2016',
#  '',
#  'hcl:#623a2f',
#  'ecl:#34964b eyr:2009 pid:169cm byr:2028 hgt:169cm',
#  'iyr:2028',
#  '',
#  'eyr:2029 iyr:2016',
#  'byr:1985',
#  'hgt:192cm hcl:#602927 cid:167',
#  'ecl:blu pid:620818510',
#  '',
#  'eyr:2029',
#  'byr:1968',
#  'ecl:blu',
#  'hgt:183cm iyr:2011 pid:952376140 hcl:#efcc98',
#  '',
#  'iyr:2020',
#  'byr:1981 pid:850136149 eyr:2028 hgt:159cm hcl:#7d3b0c',
#  'ecl:brn',
#  '',
#  'ecl:brn pid:480452858 hgt:65in cid:340 eyr:2022',
#  'byr:1946',
#  'hcl:#602927 iyr:2015',
#  '',
#  'hgt:172 hcl:z eyr:1958 iyr:1941 byr:2019 pid:389995951 ecl:dne',
#  '',
#  'byr:2025 hcl:4c8dcd',
#  'hgt:177in',
#  'ecl:#55d635',
#  'cid:197 pid:91192572',
#  'iyr:1921 eyr:2038',
#  '',
#  'iyr:2027 pid:154cm',
#  'hgt:185in byr:2012',
#  'eyr:2036 hcl:efd47d',
#  'ecl:#64f98d',
#  'cid:86',
#  '',
#  'eyr:2029 pid:837224515 ecl:grn cid:231 hcl:#733820 iyr:2019',
#  'hgt:159cm',
#  'byr:1977',
#  '',
#  'pid:974518338 byr:1964 hcl:#cfa07d ecl:grn eyr:2030',
#  'hgt:61in',
#  'iyr:2019',
#  '',
#  'iyr:2019',
#  'hgt:192in cid:94',
#  'eyr:1922',
#  'byr:1925 hcl:z ecl:utc pid:#081266',
#  '',
#  'eyr:2027 iyr:2019 cid:328 byr:1961 hcl:#6b5442 ecl:blu hgt:177cm pid:235426720',
#  '',
#  'byr:1959',
#  'eyr:2025',
#  'pid:890034625 ecl:oth',
#  'hgt:62in cid:348 hcl:#733820',
#  '',
#  'hgt:161cm iyr:2018 pid:916160791 ecl:grn',
#  'byr:1951 hcl:#44d03a eyr:2025',
#  '',
#  'hgt:158cm byr:1942 iyr:2012 hcl:#602927',
#  'eyr:2026 ecl:gry pid:651231060',
#  '',
#  'ecl:hzl cid:340 pid:086942161 byr:1986 hcl:#a97842 iyr:2018',
#  'eyr:2028',
#  'hgt:181cm',
#  '',
#  'ecl:blu',
#  'pid:278922687 cid:238 iyr:2018 hgt:153cm eyr:2027',
#  'byr:1965',
#  'hcl:#733820',
#  '',
#  'eyr:2023 cid:208 hgt:178cm hcl:#341e13 byr:1937 pid:290981079 iyr:2010 ecl:grn',
#  '',
#  'hcl:#888785',
#  'ecl:amb',
#  'byr:1943 pid:559804716 eyr:2026 hgt:166cm',
#  'iyr:2019',
#  '',
#  'pid:947831563',
#  'ecl:gry',
#  'byr:1960 hcl:#341e13',
#  'iyr:2016 hgt:173cm eyr:2029',
#  '',
#  'ecl:blu iyr:2016 pid:724632073 hcl:#623a2f',
#  'eyr:2028 hgt:192cm byr:1958',
#  '',
#  'byr:2021',
#  'eyr:2016 hcl:z iyr:1988 pid:65353943',
#  'ecl:#bb553b',
#  'hgt:125',
#  '',
#  'hcl:#efcc98 byr:1963 pid:290433211 eyr:2023 ecl:hzl',
#  'hgt:172cm iyr:2013',
#  '',
#  'iyr:2015 ecl:brn',
#  'byr:2023 hcl:#18171d',
#  'pid:325330679',
#  'hgt:190in eyr:2023',
#  '',
#  'pid:745674970 hgt:160cm eyr:2021 byr:1925 ecl:gry hcl:#341e13 iyr:2015',
#  'cid:297',
#  '',
#  'eyr:2021',
#  'pid:596411633',
#  'byr:1947 ecl:blu cid:191 hcl:#341e13 hgt:168cm iyr:2019',
#  '',
#  'eyr:2030 pid:#902a6b iyr:1997 hcl:11f396 hgt:188cm byr:2025',
#  'ecl:dne',
#  '',
#  'eyr:2025',
#  'byr:2006',
#  'hcl:#888785 ecl:hzl hgt:187cm',
#  'iyr:2012 pid:017702828',
#  '',
#  'byr:1988 hcl:#18171d iyr:2019',
#  'pid:110591871',
#  'ecl:hzl',
#  'hgt:160cm',
#  'eyr:2029',
#  '',
#  'ecl:brn',
#  'hcl:#c0946f iyr:2030 pid:264404022 byr:1984 hgt:59cm eyr:2040',
#  '',
#  'pid:5973803069',
#  'hcl:#cfa07d ecl:grt',
#  'hgt:153cm eyr:2039 byr:1970',
#  'iyr:2025',
#  '',
#  'hcl:#fffffd',
#  'iyr:2022 byr:2026',
#  'hgt:180 pid:82035145 eyr:2034 cid:118 ecl:utc',
#  '',
#  'hgt:186cm eyr:2026',
#  'ecl:brn',
#  'iyr:2013 hcl:#8f4c9b pid:010260339 byr:1948',
#  '',
#  'ecl:amb hcl:#18171d iyr:2020 pid:259501214 byr:1978 hgt:193cm',
#  'cid:263 eyr:2022',
#  '',
#  'hgt:161cm iyr:2015 byr:2014 eyr:2003',
#  'pid:708958872 ecl:grt',
#  'hcl:f4a430',
#  '',
#  'hgt:170cm eyr:2021 pid:911638274 cid:110 byr:1963 ecl:blu',
#  'iyr:2015 hcl:1eda64',
#  '',
#  'ecl:oth byr:1949 hgt:174cm hcl:#18171d eyr:2022 iyr:2019',
#  'pid:305857230',
#  '',
#  'ecl:gry hcl:#a97842 pid:971971076 byr:2002 iyr:2019',
#  'hgt:188cm',
#  'eyr:2022 cid:238',
#  '',
#  'eyr:2027 pid:221315043 iyr:2010 hgt:159cm ecl:blu byr:1998 hcl:#6b5442',
#  '',
#  'hcl:#888785',
#  'byr:1926 eyr:2022 pid:433807814 ecl:grn',
#  'iyr:2010',
#  'hgt:181cm',
#  '',
#  'ecl:grn hgt:164cm byr:1951 hcl:#18171d cid:75 pid:845508281 eyr:2021 iyr:2017',
#  '',
#  'pid:#f59bc7',
#  'eyr:1987 hgt:191cm hcl:z byr:2024',
#  'iyr:1985',
#  '',
#  'hcl:#623a2f pid:497429747',
#  'hgt:189cm',
#  'byr:1987',
#  'eyr:2027 iyr:2012 cid:95 ecl:hzl',
#  '',
#  'byr:2000',
#  'hgt:165cm',
#  'iyr:2017 pid:519443292 eyr:2029 cid:240 hcl:#a97842',
#  'ecl:blu',
#  '',
#  'cid:67 pid:038299774',
#  'eyr:2023 iyr:2015 hgt:179cm byr:1941 hcl:#18171d ecl:amb',
#  '',
#  'byr:2000',
#  'eyr:2025 ecl:oth iyr:2017',
#  'pid:334154607',
#  'hcl:#fffffd hgt:173cm',
#  '',
#  'hcl:#888785 ecl:amb',
#  'cid:131 iyr:2018 byr:1996 eyr:2026',
#  'hgt:180cm pid:709543988',
#  '',
#  'iyr:1988',
#  'pid:263277424',
#  'hcl:ee8912 byr:1942 ecl:gry eyr:2040 hgt:161cm',
#  '',
#  'eyr:2020 byr:1966 iyr:2020 hgt:169cm pid:611918000',
#  'hcl:#7d3b0c ecl:hzl',
#  '',
#  'hgt:164cm ecl:brn',
#  'iyr:2015 pid:192054454 hcl:#6b5442 byr:1987 eyr:2022',
#  '',
#  'byr:1952',
#  'ecl:zzz',
#  'pid:215953654',
#  'eyr:2021 hcl:#efcc98 hgt:153cm iyr:2026',
#  '',
#  'hgt:167cm',
#  'hcl:#b6652a pid:847614726',
#  'eyr:2022 ecl:gry byr:1990 iyr:2015',
#  '',
#  'hgt:185cm ecl:oth iyr:2012',
#  'byr:1933',
#  'cid:250',
#  'pid:038674023',
#  'hcl:#c0946f',
#  '',
#  'pid:613273980 hcl:#a97842',
#  'ecl:oth byr:1924 hgt:179cm',
#  'eyr:2027 iyr:1950',
#  '',
#  'hcl:#cfa07d byr:2018 hgt:190cm pid:64530329',
#  'ecl:brn',
#  'iyr:2024',
#  '',
#  'hcl:z hgt:70cm pid:18807747',
#  'cid:284 byr:2023',
#  'eyr:2035 ecl:#4a1501',
#  'iyr:1954',
#  '',
#  'iyr:2016 hgt:152cm pid:886247173 byr:1940 hcl:#c0946f eyr:2027 ecl:oth cid:150',
#  '',
#  'hgt:152cm hcl:#48cfdf eyr:2025 cid:277',
#  'ecl:oth pid:246230621 byr:1932',
#  'iyr:2020',
#  '',
#  'ecl:amb pid:871180042',
#  'cid:117 hcl:#602927 iyr:2011 hgt:152cm',
#  'eyr:2030 byr:1999',
#  '',
#  'eyr:2024 ecl:hzl hgt:171cm',
#  'byr:1934 pid:356408125 iyr:2019 hcl:#b6652a',
#  'cid:169',
#  '',
#  'eyr:2023',
#  'hcl:#7d3b0c',
#  'byr:1934 hgt:67in ecl:oth pid:191785527',
#  'cid:117 iyr:2016',
#  '',
#  'iyr:2029',
#  'hcl:#602927 eyr:2022 byr:1931 ecl:oth hgt:192cm',
#  'pid:231475143',
#  '',
#  'ecl:grn iyr:2014 cid:250 hcl:#b6652a byr:1970 pid:675238417 hgt:162cm',
#  'eyr:2026',
#  '',
#  'ecl:brn',
#  'hcl:#623a2f eyr:2021 pid:293293433 hgt:158 byr:1977 iyr:2019',
#  '',
#  'ecl:oth hcl:#ceb3a1 pid:013111996 eyr:2023 hgt:180cm byr:1976 cid:224',
#  '',
#  'hgt:61cm',
#  'eyr:2027 ecl:amb pid:181cm iyr:1932',
#  'byr:1974',
#  'hcl:#18171d',
#  '',
#  'byr:1968 hgt:167cm',
#  'hcl:#a97842 eyr:2022 iyr:2018 ecl:hzl pid:940968694',
#  '',
#  'iyr:1943',
#  'hgt:96',
#  'cid:229',
#  'hcl:z eyr:1990 byr:2007 pid:#25aa73',
#  'ecl:#74592e',
#  '',
#  'hgt:182cm iyr:2018 ecl:hzl eyr:2029 byr:1946 pid:602345030',
#  'hcl:#ceb3a1',
#  '',
#  'pid:750306036 eyr:2020 hgt:181in ecl:xry',
#  'iyr:2011 hcl:z byr:1971 cid:71',
#  '',
#  'pid:183825747 iyr:2019 hcl:#6b5442',
#  'byr:1974',
#  'hgt:180cm eyr:2028',
#  'ecl:amb',
#  '',
#  'ecl:brn cid:200 pid:576495225',
#  'byr:1924',
#  'hcl:#efcc98 eyr:2022 iyr:2017 hgt:185cm',
#  '',
#  'iyr:2020 hgt:167cm byr:1965 ecl:brn hcl:#888785',
#  'eyr:2028 pid:752062953',
#  '',
#  'byr:2026',
#  'hcl:z',
#  'eyr:2020',
#  'ecl:#b4ec74 pid:187cm iyr:1974',
#  'cid:326 hgt:150cm',
#  '',
#  'byr:1996 pid:507323629',
#  'iyr:2015 cid:347 eyr:2026 hcl:#efcc98',
#  'ecl:amb hgt:157cm',
#  '',
#  'byr:2017 pid:456780590 hcl:#888785 eyr:1966 ecl:amb iyr:2023 cid:187 hgt:62cm',
#  '',
#  'ecl:hzl iyr:2015 hcl:#6b5442 hgt:152cm eyr:2028 byr:1982 pid:003269467',
#  '',
#  'iyr:2017 eyr:2026',
#  'ecl:blu cid:70 hcl:#7d3b0c',
#  'byr:1966 pid:160330947 hgt:189cm',
#  '',
#  'iyr:2010 ecl:amb',
#  'hgt:164cm eyr:2029 byr:1963',
#  'pid:596606374 hcl:#efcc98',
#  '',
#  'hcl:#fffffd cid:277 pid:102326370 hgt:154cm eyr:2026 iyr:2012 byr:1968',
#  'ecl:hzl',
#  '',
#  'ecl:oth pid:477189554 hcl:#6b5442 eyr:2022 byr:1948 hgt:74in cid:181',
#  'iyr:2016',
#  '',
#  'hgt:169cm hcl:#d7bc93',
#  'cid:344 ecl:oth',
#  'pid:#09c55d iyr:2017',
#  'eyr:2030 byr:1928',
#  '',
#  'hcl:5d02ff ecl:#ca7901 iyr:1959 byr:2006 eyr:2022',
#  'hgt:164in',
#  'pid:#d6cdfd',
#  '',
#  'ecl:amb pid:5739190196 eyr:2021 hgt:157in hcl:#efcc98 byr:2018 iyr:2028',
#  '',
#  'byr:1995 ecl:hzl',
#  'iyr:2017',
#  'hcl:#a97842 pid:917039291 eyr:2026 hgt:175cm',
#  '',
#  'iyr:2017 pid:756519868',
#  'hcl:#623a2f',
#  'eyr:2028',
#  'hgt:158cm',
#  'ecl:amb byr:1957',
#  '',
#  ...]

# %% [markdown]
# - byr (Birth Year)
# - iyr (Issue Year)
# - eyr (Expiration Year)
# - hgt (Height)
# - hcl (Hair Color)
# - ecl (Eye Color)
# - pid (Passport ID)

# %%
valid_fields = ['byr', 'iyr','eyr','hgt', 'hcl','ecl','pid']

# %%
cid = 'cid'

# %%
inp[-1]
# Out:
# 'cid:294 hcl:#b6652a iyr:2017'

# %%
len(inp)
# Out:
# 1121

# %%
passport_count = 1
for line in inp:
    if line == '':
        passport_count += 1
passport_count
# Out:
# 282

# %%
inp.append('')

passport_count = 0
valid_count = 0

kv_strings = []
fields = []
values = []
results = {"valids": []}

for line in inp:
    if line != '':
        print(line)
        kv_strings=line.split()
        for string in kv_strings:
            pair = string.split(':')
            fields.append(pair[0])
            values.append(pair[1])
    else:
        passport_count += 1
        
        print("")
        print(f"Passport #:{passport_count}")
        print(f"fields present: {fields}")
        print(f"valid fields: {valid_fields}")
        
        diff_fields = []
        diff_fields = [x for x in fields + valid_fields if x not in fields or x not in valid_fields]
        
        print(f"differences: {diff_fields}")
        print("")
        
        if len(diff_fields) == 1:
            if cid not in diff_fields:
                print("Passport is invalid!")
                print("")
            else:
                print("Passport is valid")
                print("")
                
                valid_count += 1
                passport = dict(zip(fields, values))
                results['valids'].append(passport)
                
                print(passport)
                
        elif len(diff_fields) > 0:
            print("Passport is invalid!")
            print("")
        else:
            print("Passport is valid")
            print("")
            
            valid_count += 1
            passport = dict(zip(fields, values))
            results['valids'].append(passport)
            
            print(passport)
        
        print("")
        print(f"Valid passports: {valid_count}")
        print("--" * 40)
        kv_strings = []
        fields =[]
        values =[]
# Out:
# eyr:2024 pid:662406624 hcl:#cfa07d byr:1947 iyr:2015 ecl:amb hgt:150cm
#
# Passport #:1
# fields present: ['eyr', 'pid', 'hcl', 'byr', 'iyr', 'ecl', 'hgt']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'eyr': '2024', 'pid': '662406624', 'hcl': '#cfa07d', 'byr': '1947', 'iyr': '2015', 'ecl': 'amb', 'hgt': '150cm'}
#
# Valid passports: 1
# --------------------------------------------------------------------------------
# iyr:2013 byr:1997 hgt:182cm hcl:#ceb3a1
# eyr:2027
# ecl:gry cid:102 pid:018128535
#
# Passport #:2
# fields present: ['iyr', 'byr', 'hgt', 'hcl', 'eyr', 'ecl', 'cid', 'pid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'iyr': '2013', 'byr': '1997', 'hgt': '182cm', 'hcl': '#ceb3a1', 'eyr': '2027', 'ecl': 'gry', 'cid': '102', 'pid': '018128535'}
#
# Valid passports: 2
# --------------------------------------------------------------------------------
# hgt:61in iyr:2014 pid:916315544 hcl:#733820 ecl:oth
#
# Passport #:3
# fields present: ['hgt', 'iyr', 'pid', 'hcl', 'ecl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['byr', 'eyr']
#
# Passport is invalid!
#
#
# Valid passports: 2
# --------------------------------------------------------------------------------
# hcl:#a97842
# eyr:2026 byr:1980 ecl:grn pid:726519569 hgt:184cm cid:132 iyr:2011
#
# Passport #:4
# fields present: ['hcl', 'eyr', 'byr', 'ecl', 'pid', 'hgt', 'cid', 'iyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'hcl': '#a97842', 'eyr': '2026', 'byr': '1980', 'ecl': 'grn', 'pid': '726519569', 'hgt': '184cm', 'cid': '132', 'iyr': '2011'}
#
# Valid passports: 3
# --------------------------------------------------------------------------------
# ecl:grn hcl:#6b5442 pid:619743219 cid:69 hgt:176cm eyr:2027 iyr:2012
# byr:1980
#
# Passport #:5
# fields present: ['ecl', 'hcl', 'pid', 'cid', 'hgt', 'eyr', 'iyr', 'byr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'ecl': 'grn', 'hcl': '#6b5442', 'pid': '619743219', 'cid': '69', 'hgt': '176cm', 'eyr': '2027', 'iyr': '2012', 'byr': '1980'}
#
# Valid passports: 4
# --------------------------------------------------------------------------------
# ecl:brn byr:1969 iyr:2014
# hgt:164cm eyr:2020 pid:982796633 hcl:#602927
#
# Passport #:6
# fields present: ['ecl', 'byr', 'iyr', 'hgt', 'eyr', 'pid', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'ecl': 'brn', 'byr': '1969', 'iyr': '2014', 'hgt': '164cm', 'eyr': '2020', 'pid': '982796633', 'hcl': '#602927'}
#
# Valid passports: 5
# --------------------------------------------------------------------------------
# ecl:gmt
# iyr:1987 eyr:2039 pid:15115163 byr:2006
# hcl:bfab0d
#
# Passport #:7
# fields present: ['ecl', 'iyr', 'eyr', 'pid', 'byr', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['hgt']
#
# Passport is invalid!
#
#
# Valid passports: 5
# --------------------------------------------------------------------------------
# cid:117
# hcl:#efcc98
# iyr:2010 pid:322719183
# hgt:176cm
# eyr:2020
# byr:1957
# ecl:brn
#
# Passport #:8
# fields present: ['cid', 'hcl', 'iyr', 'pid', 'hgt', 'eyr', 'byr', 'ecl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'cid': '117', 'hcl': '#efcc98', 'iyr': '2010', 'pid': '322719183', 'hgt': '176cm', 'eyr': '2020', 'byr': '1957', 'ecl': 'brn'}
#
# Valid passports: 6
# --------------------------------------------------------------------------------
# byr:1954 hgt:178cm hcl:#38f7fd pid:838813262 ecl:blu
# eyr:2029 iyr:2019
#
# Passport #:9
# fields present: ['byr', 'hgt', 'hcl', 'pid', 'ecl', 'eyr', 'iyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'byr': '1954', 'hgt': '178cm', 'hcl': '#38f7fd', 'pid': '838813262', 'ecl': 'blu', 'eyr': '2029', 'iyr': '2019'}
#
# Valid passports: 7
# --------------------------------------------------------------------------------
# eyr:2023 ecl:amb iyr:2020 byr:1927 pid:242570886 hcl:#18171d hgt:192cm
#
# Passport #:10
# fields present: ['eyr', 'ecl', 'iyr', 'byr', 'pid', 'hcl', 'hgt']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'eyr': '2023', 'ecl': 'amb', 'iyr': '2020', 'byr': '1927', 'pid': '242570886', 'hcl': '#18171d', 'hgt': '192cm'}
#
# Valid passports: 8
# --------------------------------------------------------------------------------
# iyr:1990 cid:295 hgt:131 pid:187cm byr:2014
# ecl:xry hcl:z
# eyr:1928
#
# Passport #:11
# fields present: ['iyr', 'cid', 'hgt', 'pid', 'byr', 'ecl', 'hcl', 'eyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'iyr': '1990', 'cid': '295', 'hgt': '131', 'pid': '187cm', 'byr': '2014', 'ecl': 'xry', 'hcl': 'z', 'eyr': '1928'}
#
# Valid passports: 9
# --------------------------------------------------------------------------------
# ecl:hzl
# byr:1953
# eyr:2023 hcl:#866857
# hgt:181cm iyr:2010 pid:568185567
#
# Passport #:12
# fields present: ['ecl', 'byr', 'eyr', 'hcl', 'hgt', 'iyr', 'pid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'ecl': 'hzl', 'byr': '1953', 'eyr': '2023', 'hcl': '#866857', 'hgt': '181cm', 'iyr': '2010', 'pid': '568185567'}
#
# Valid passports: 10
# --------------------------------------------------------------------------------
# byr:2030 hcl:#fffffd ecl:#a4a596 hgt:168cm
# iyr:1936 eyr:2020 cid:296 pid:168786676
#
# Passport #:13
# fields present: ['byr', 'hcl', 'ecl', 'hgt', 'iyr', 'eyr', 'cid', 'pid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'byr': '2030', 'hcl': '#fffffd', 'ecl': '#a4a596', 'hgt': '168cm', 'iyr': '1936', 'eyr': '2020', 'cid': '296', 'pid': '168786676'}
#
# Valid passports: 11
# --------------------------------------------------------------------------------
# byr:2030 iyr:2026 eyr:1974 hcl:7fcaa5 ecl:utc
# pid:190cm
# hgt:67cm
#
# Passport #:14
# fields present: ['byr', 'iyr', 'eyr', 'hcl', 'ecl', 'pid', 'hgt']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'byr': '2030', 'iyr': '2026', 'eyr': '1974', 'hcl': '7fcaa5', 'ecl': 'utc', 'pid': '190cm', 'hgt': '67cm'}
#
# Valid passports: 12
# --------------------------------------------------------------------------------
# byr:2023 eyr:2037 hgt:59cm
# ecl:lzr hcl:z iyr:2026 pid:#ea9083
#
# Passport #:15
# fields present: ['byr', 'eyr', 'hgt', 'ecl', 'hcl', 'iyr', 'pid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'byr': '2023', 'eyr': '2037', 'hgt': '59cm', 'ecl': 'lzr', 'hcl': 'z', 'iyr': '2026', 'pid': '#ea9083'}
#
# Valid passports: 13
# --------------------------------------------------------------------------------
# byr:2003 hcl:z hgt:91 iyr:1990 eyr:2024 ecl:#123d73
# pid:48494230
#
# Passport #:16
# fields present: ['byr', 'hcl', 'hgt', 'iyr', 'eyr', 'ecl', 'pid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'byr': '2003', 'hcl': 'z', 'hgt': '91', 'iyr': '1990', 'eyr': '2024', 'ecl': '#123d73', 'pid': '48494230'}
#
# Valid passports: 14
# --------------------------------------------------------------------------------
# byr:2022 eyr:2020 iyr:2030 ecl:gmt
# hgt:191cm pid:3509331253 hcl:#888785
#
# Passport #:17
# fields present: ['byr', 'eyr', 'iyr', 'ecl', 'hgt', 'pid', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'byr': '2022', 'eyr': '2020', 'iyr': '2030', 'ecl': 'gmt', 'hgt': '191cm', 'pid': '3509331253', 'hcl': '#888785'}
#
# Valid passports: 15
# --------------------------------------------------------------------------------
# iyr:1994
# ecl:#c3d564 byr:2009
# hgt:162cm hcl:336498 pid:#e99d09
# cid:288
# eyr:1921
#
# Passport #:18
# fields present: ['iyr', 'ecl', 'byr', 'hgt', 'hcl', 'pid', 'cid', 'eyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'iyr': '1994', 'ecl': '#c3d564', 'byr': '2009', 'hgt': '162cm', 'hcl': '336498', 'pid': '#e99d09', 'cid': '288', 'eyr': '1921'}
#
# Valid passports: 16
# --------------------------------------------------------------------------------
# byr:1924 cid:290 iyr:2010 ecl:amb eyr:2020
# hgt:156cm hcl:#7d3b0c pid:795497164
#
# Passport #:19
# fields present: ['byr', 'cid', 'iyr', 'ecl', 'eyr', 'hgt', 'hcl', 'pid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'byr': '1924', 'cid': '290', 'iyr': '2010', 'ecl': 'amb', 'eyr': '2020', 'hgt': '156cm', 'hcl': '#7d3b0c', 'pid': '795497164'}
#
# Valid passports: 17
# --------------------------------------------------------------------------------
# cid:301 iyr:2017 hgt:67cm
# hcl:#888785 ecl:#0405b9 byr:1964 pid:707857518 eyr:1976
#
# Passport #:20
# fields present: ['cid', 'iyr', 'hgt', 'hcl', 'ecl', 'byr', 'pid', 'eyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'cid': '301', 'iyr': '2017', 'hgt': '67cm', 'hcl': '#888785', 'ecl': '#0405b9', 'byr': '1964', 'pid': '707857518', 'eyr': '1976'}
#
# Valid passports: 18
# --------------------------------------------------------------------------------
# ecl:gry pid:474303066
# iyr:2011 hcl:#18171d hgt:165cm byr:1921 eyr:2024
#
# Passport #:21
# fields present: ['ecl', 'pid', 'iyr', 'hcl', 'hgt', 'byr', 'eyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'ecl': 'gry', 'pid': '474303066', 'iyr': '2011', 'hcl': '#18171d', 'hgt': '165cm', 'byr': '1921', 'eyr': '2024'}
#
# Valid passports: 19
# --------------------------------------------------------------------------------
# hcl:#6b5442 ecl:amb iyr:2020 hgt:191cm
# byr:1949 cid:301
# pid:075846582 eyr:2029
#
# Passport #:22
# fields present: ['hcl', 'ecl', 'iyr', 'hgt', 'byr', 'cid', 'pid', 'eyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'hcl': '#6b5442', 'ecl': 'amb', 'iyr': '2020', 'hgt': '191cm', 'byr': '1949', 'cid': '301', 'pid': '075846582', 'eyr': '2029'}
#
# Valid passports: 20
# --------------------------------------------------------------------------------
# hcl:#a97842 cid:186 iyr:2014
# ecl:gry
# hgt:191cm eyr:2023 pid:645548969
# byr:1956
#
# Passport #:23
# fields present: ['hcl', 'cid', 'iyr', 'ecl', 'hgt', 'eyr', 'pid', 'byr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'hcl': '#a97842', 'cid': '186', 'iyr': '2014', 'ecl': 'gry', 'hgt': '191cm', 'eyr': '2023', 'pid': '645548969', 'byr': '1956'}
#
# Valid passports: 21
# --------------------------------------------------------------------------------
# pid:154cm hcl:z ecl:gmt iyr:1989 hgt:69in cid:53 byr:2010
#
# Passport #:24
# fields present: ['pid', 'hcl', 'ecl', 'iyr', 'hgt', 'cid', 'byr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid', 'eyr']
#
# Passport is invalid!
#
#
# Valid passports: 21
# --------------------------------------------------------------------------------
# hgt:72cm byr:2023
# eyr:2034 hcl:z ecl:#f5249e iyr:1997 pid:#79af7a
#
# Passport #:25
# fields present: ['hgt', 'byr', 'eyr', 'hcl', 'ecl', 'iyr', 'pid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'hgt': '72cm', 'byr': '2023', 'eyr': '2034', 'hcl': 'z', 'ecl': '#f5249e', 'iyr': '1997', 'pid': '#79af7a'}
#
# Valid passports: 22
# --------------------------------------------------------------------------------
# eyr:2038 byr:2015
# hgt:70cm ecl:grt hcl:9d58a1 iyr:1926 pid:6290928420
#
# Passport #:26
# fields present: ['eyr', 'byr', 'hgt', 'ecl', 'hcl', 'iyr', 'pid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'eyr': '2038', 'byr': '2015', 'hgt': '70cm', 'ecl': 'grt', 'hcl': '9d58a1', 'iyr': '1926', 'pid': '6290928420'}
#
# Valid passports: 23
# --------------------------------------------------------------------------------
# pid:620857794 eyr:2022
# byr:1950
# hgt:159cm
# hcl:#ceb3a1 ecl:amb iyr:2015
#
# Passport #:27
# fields present: ['pid', 'eyr', 'byr', 'hgt', 'hcl', 'ecl', 'iyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'pid': '620857794', 'eyr': '2022', 'byr': '1950', 'hgt': '159cm', 'hcl': '#ceb3a1', 'ecl': 'amb', 'iyr': '2015'}
#
# Valid passports: 24
# --------------------------------------------------------------------------------
# eyr:1954 ecl:#ab2ce4 pid:#14eedd
# iyr:2009
# hcl:29e484
# byr:2022 hgt:73cm
#
# Passport #:28
# fields present: ['eyr', 'ecl', 'pid', 'iyr', 'hcl', 'byr', 'hgt']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'eyr': '1954', 'ecl': '#ab2ce4', 'pid': '#14eedd', 'iyr': '2009', 'hcl': '29e484', 'byr': '2022', 'hgt': '73cm'}
#
# Valid passports: 25
# --------------------------------------------------------------------------------
# hgt:59cm byr:2026 cid:245 iyr:2020
# eyr:2029 pid:073943129 ecl:hzl
# hcl:#b6652a
#
# Passport #:29
# fields present: ['hgt', 'byr', 'cid', 'iyr', 'eyr', 'pid', 'ecl', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'hgt': '59cm', 'byr': '2026', 'cid': '245', 'iyr': '2020', 'eyr': '2029', 'pid': '073943129', 'ecl': 'hzl', 'hcl': '#b6652a'}
#
# Valid passports: 26
# --------------------------------------------------------------------------------
# iyr:2014 byr:2015 hcl:#a97842 eyr:2029
# pid:#132098
# hgt:150 ecl:oth
#
# Passport #:30
# fields present: ['iyr', 'byr', 'hcl', 'eyr', 'pid', 'hgt', 'ecl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'iyr': '2014', 'byr': '2015', 'hcl': '#a97842', 'eyr': '2029', 'pid': '#132098', 'hgt': '150', 'ecl': 'oth'}
#
# Valid passports: 27
# --------------------------------------------------------------------------------
# hgt:151in ecl:#967d49 eyr:2026 hcl:#18171d
# pid:384230726 byr:1934
# iyr:2018
#
# Passport #:31
# fields present: ['hgt', 'ecl', 'eyr', 'hcl', 'pid', 'byr', 'iyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'hgt': '151in', 'ecl': '#967d49', 'eyr': '2026', 'hcl': '#18171d', 'pid': '384230726', 'byr': '1934', 'iyr': '2018'}
#
# Valid passports: 28
# --------------------------------------------------------------------------------
# iyr:2020 eyr:2021 byr:1937 pid:735047371 cid:159 ecl:blu hgt:177cm hcl:#22b774
#
# Passport #:32
# fields present: ['iyr', 'eyr', 'byr', 'pid', 'cid', 'ecl', 'hgt', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'iyr': '2020', 'eyr': '2021', 'byr': '1937', 'pid': '735047371', 'cid': '159', 'ecl': 'blu', 'hgt': '177cm', 'hcl': '#22b774'}
#
# Valid passports: 29
# --------------------------------------------------------------------------------
# ecl:brn hcl:#6b5442 pid:117807698 cid:105 iyr:2016 byr:1977 hgt:183cm
#
# Passport #:33
# fields present: ['ecl', 'hcl', 'pid', 'cid', 'iyr', 'byr', 'hgt']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid', 'eyr']
#
# Passport is invalid!
#
#
# Valid passports: 29
# --------------------------------------------------------------------------------
# ecl:hzl hcl:#6b5442 byr:1933
# iyr:2019 pid:348486702
# eyr:2020 hgt:193cm
#
# Passport #:34
# fields present: ['ecl', 'hcl', 'byr', 'iyr', 'pid', 'eyr', 'hgt']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'ecl': 'hzl', 'hcl': '#6b5442', 'byr': '1933', 'iyr': '2019', 'pid': '348486702', 'eyr': '2020', 'hgt': '193cm'}
#
# Valid passports: 30
# --------------------------------------------------------------------------------
# byr:1928
# ecl:gry
# eyr:2028 hcl:#fffffd pid:571149069
# iyr:2012 hgt:175cm
#
# Passport #:35
# fields present: ['byr', 'ecl', 'eyr', 'hcl', 'pid', 'iyr', 'hgt']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'byr': '1928', 'ecl': 'gry', 'eyr': '2028', 'hcl': '#fffffd', 'pid': '571149069', 'iyr': '2012', 'hgt': '175cm'}
#
# Valid passports: 31
# --------------------------------------------------------------------------------
# pid:359108298
# eyr:2027 hgt:158cm ecl:amb iyr:2016
# hcl:#602927
#
# Passport #:36
# fields present: ['pid', 'eyr', 'hgt', 'ecl', 'iyr', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['byr']
#
# Passport is invalid!
#
#
# Valid passports: 31
# --------------------------------------------------------------------------------
# iyr:2027 byr:2015
# hgt:191in pid:102033301 ecl:xry
# eyr:2031 hcl:#602927
#
# Passport #:37
# fields present: ['iyr', 'byr', 'hgt', 'pid', 'ecl', 'eyr', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'iyr': '2027', 'byr': '2015', 'hgt': '191in', 'pid': '102033301', 'ecl': 'xry', 'eyr': '2031', 'hcl': '#602927'}
#
# Valid passports: 32
# --------------------------------------------------------------------------------
# ecl:oth cid:163 hcl:z iyr:2014
# byr:1944 hgt:173cm
# eyr:2027 pid:#0524c1
#
# Passport #:38
# fields present: ['ecl', 'cid', 'hcl', 'iyr', 'byr', 'hgt', 'eyr', 'pid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'ecl': 'oth', 'cid': '163', 'hcl': 'z', 'iyr': '2014', 'byr': '1944', 'hgt': '173cm', 'eyr': '2027', 'pid': '#0524c1'}
#
# Valid passports: 33
# --------------------------------------------------------------------------------
# ecl:brn
# byr:2030 hgt:71cm eyr:1931 cid:165 iyr:2010 hcl:#cfa07d
# pid:509642098
#
# Passport #:39
# fields present: ['ecl', 'byr', 'hgt', 'eyr', 'cid', 'iyr', 'hcl', 'pid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'ecl': 'brn', 'byr': '2030', 'hgt': '71cm', 'eyr': '1931', 'cid': '165', 'iyr': '2010', 'hcl': '#cfa07d', 'pid': '509642098'}
#
# Valid passports: 34
# --------------------------------------------------------------------------------
# hgt:166 iyr:2020 cid:308
# eyr:2022 pid:950463527
# byr:2017
# hcl:z
#
# Passport #:40
# fields present: ['hgt', 'iyr', 'cid', 'eyr', 'pid', 'byr', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid', 'ecl']
#
# Passport is invalid!
#
#
# Valid passports: 34
# --------------------------------------------------------------------------------
# ecl:amb
# eyr:2023 byr:1924
# pid:901038027 hgt:70in
# iyr:2010 hcl:z
#
# Passport #:41
# fields present: ['ecl', 'eyr', 'byr', 'pid', 'hgt', 'iyr', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'ecl': 'amb', 'eyr': '2023', 'byr': '1924', 'pid': '901038027', 'hgt': '70in', 'iyr': '2010', 'hcl': 'z'}
#
# Valid passports: 35
# --------------------------------------------------------------------------------
# byr:1972
# iyr:2013
# hcl:d669ad hgt:64cm cid:247 ecl:#19aa26 eyr:2023
#
# Passport #:42
# fields present: ['byr', 'iyr', 'hcl', 'hgt', 'cid', 'ecl', 'eyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid', 'pid']
#
# Passport is invalid!
#
#
# Valid passports: 35
# --------------------------------------------------------------------------------
# hgt:71 hcl:#fffffd
# byr:1976 cid:108 eyr:2038
# ecl:grt iyr:2018 pid:190cm
#
# Passport #:43
# fields present: ['hgt', 'hcl', 'byr', 'cid', 'eyr', 'ecl', 'iyr', 'pid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'hgt': '71', 'hcl': '#fffffd', 'byr': '1976', 'cid': '108', 'eyr': '2038', 'ecl': 'grt', 'iyr': '2018', 'pid': '190cm'}
#
# Valid passports: 36
# --------------------------------------------------------------------------------
# iyr:2017
# byr:1963 ecl:grn hgt:175cm
# pid:160915270 eyr:2028 hcl:#cfa07d
#
# Passport #:44
# fields present: ['iyr', 'byr', 'ecl', 'hgt', 'pid', 'eyr', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'iyr': '2017', 'byr': '1963', 'ecl': 'grn', 'hgt': '175cm', 'pid': '160915270', 'eyr': '2028', 'hcl': '#cfa07d'}
#
# Valid passports: 37
# --------------------------------------------------------------------------------
# pid:569740130 hgt:171cm hcl:#733820
# ecl:gry eyr:2024 iyr:2020 byr:1973
#
# Passport #:45
# fields present: ['pid', 'hgt', 'hcl', 'ecl', 'eyr', 'iyr', 'byr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'pid': '569740130', 'hgt': '171cm', 'hcl': '#733820', 'ecl': 'gry', 'eyr': '2024', 'iyr': '2020', 'byr': '1973'}
#
# Valid passports: 38
# --------------------------------------------------------------------------------
# byr:1937
# iyr:2016 ecl:gry hgt:181cm pid:521705827 hcl:#b6652a eyr:2027 cid:295
#
# Passport #:46
# fields present: ['byr', 'iyr', 'ecl', 'hgt', 'pid', 'hcl', 'eyr', 'cid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'byr': '1937', 'iyr': '2016', 'ecl': 'gry', 'hgt': '181cm', 'pid': '521705827', 'hcl': '#b6652a', 'eyr': '2027', 'cid': '295'}
#
# Valid passports: 39
# --------------------------------------------------------------------------------
# hgt:156cm ecl:blu iyr:2019 hcl:#866857
# pid:662418718 byr:2000 eyr:2024
#
# Passport #:47
# fields present: ['hgt', 'ecl', 'iyr', 'hcl', 'pid', 'byr', 'eyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'hgt': '156cm', 'ecl': 'blu', 'iyr': '2019', 'hcl': '#866857', 'pid': '662418718', 'byr': '2000', 'eyr': '2024'}
#
# Valid passports: 40
# --------------------------------------------------------------------------------
# byr:1971 pid:693616099
# hcl:#efcc98
# hgt:175cm iyr:2016 ecl:gry
# eyr:2023
#
# Passport #:48
# fields present: ['byr', 'pid', 'hcl', 'hgt', 'iyr', 'ecl', 'eyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'byr': '1971', 'pid': '693616099', 'hcl': '#efcc98', 'hgt': '175cm', 'iyr': '2016', 'ecl': 'gry', 'eyr': '2023'}
#
# Valid passports: 41
# --------------------------------------------------------------------------------
# iyr:2013
# eyr:2024
# ecl:gry
# pid:414295491 byr:1986
# hgt:188cm hcl:#b6652a
#
# Passport #:49
# fields present: ['iyr', 'eyr', 'ecl', 'pid', 'byr', 'hgt', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'iyr': '2013', 'eyr': '2024', 'ecl': 'gry', 'pid': '414295491', 'byr': '1986', 'hgt': '188cm', 'hcl': '#b6652a'}
#
# Valid passports: 42
# --------------------------------------------------------------------------------
# eyr:2022 byr:1975 iyr:2020
# ecl:grn cid:68 hcl:#a97842
# hgt:151cm pid:229803943
#
# Passport #:50
# fields present: ['eyr', 'byr', 'iyr', 'ecl', 'cid', 'hcl', 'hgt', 'pid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'eyr': '2022', 'byr': '1975', 'iyr': '2020', 'ecl': 'grn', 'cid': '68', 'hcl': '#a97842', 'hgt': '151cm', 'pid': '229803943'}
#
# Valid passports: 43
# --------------------------------------------------------------------------------
# cid:258 iyr:2012
# ecl:hzl
# byr:2001
# eyr:2021
# hcl:#866857 pid:990590217 hgt:172cm
#
# Passport #:51
# fields present: ['cid', 'iyr', 'ecl', 'byr', 'eyr', 'hcl', 'pid', 'hgt']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'cid': '258', 'iyr': '2012', 'ecl': 'hzl', 'byr': '2001', 'eyr': '2021', 'hcl': '#866857', 'pid': '990590217', 'hgt': '172cm'}
#
# Valid passports: 44
# --------------------------------------------------------------------------------
# cid:339 byr:1957 hcl:#866857 pid:343480061 eyr:2039
# hgt:191cm
# iyr:2021
# ecl:utc
#
# Passport #:52
# fields present: ['cid', 'byr', 'hcl', 'pid', 'eyr', 'hgt', 'iyr', 'ecl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'cid': '339', 'byr': '1957', 'hcl': '#866857', 'pid': '343480061', 'eyr': '2039', 'hgt': '191cm', 'iyr': '2021', 'ecl': 'utc'}
#
# Valid passports: 45
# --------------------------------------------------------------------------------
# cid:281 hcl:z ecl:blu
# byr:2020 pid:132694306 eyr:2020 iyr:1953
#
# Passport #:53
# fields present: ['cid', 'hcl', 'ecl', 'byr', 'pid', 'eyr', 'iyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid', 'hgt']
#
# Passport is invalid!
#
#
# Valid passports: 45
# --------------------------------------------------------------------------------
# hcl:#602927
# byr:1933 eyr:2028
# hgt:165cm ecl:gry iyr:2018 pid:658484617
#
# Passport #:54
# fields present: ['hcl', 'byr', 'eyr', 'hgt', 'ecl', 'iyr', 'pid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'hcl': '#602927', 'byr': '1933', 'eyr': '2028', 'hgt': '165cm', 'ecl': 'gry', 'iyr': '2018', 'pid': '658484617'}
#
# Valid passports: 46
# --------------------------------------------------------------------------------
# ecl:oth
# hgt:188cm cid:110 pid:056975690 iyr:2016 byr:1950 eyr:2023 hcl:#cfa07d
#
# Passport #:55
# fields present: ['ecl', 'hgt', 'cid', 'pid', 'iyr', 'byr', 'eyr', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'ecl': 'oth', 'hgt': '188cm', 'cid': '110', 'pid': '056975690', 'iyr': '2016', 'byr': '1950', 'eyr': '2023', 'hcl': '#cfa07d'}
#
# Valid passports: 47
# --------------------------------------------------------------------------------
# cid:342 hcl:#fffffd eyr:2024
# pid:153555359 byr:1974
# ecl:gry hgt:191cm iyr:2020
#
# Passport #:56
# fields present: ['cid', 'hcl', 'eyr', 'pid', 'byr', 'ecl', 'hgt', 'iyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'cid': '342', 'hcl': '#fffffd', 'eyr': '2024', 'pid': '153555359', 'byr': '1974', 'ecl': 'gry', 'hgt': '191cm', 'iyr': '2020'}
#
# Valid passports: 48
# --------------------------------------------------------------------------------
# byr:2019 ecl:#160ed3 eyr:1999 hcl:z
# cid:146 pid:195693972 hgt:159cm
#
# Passport #:57
# fields present: ['byr', 'ecl', 'eyr', 'hcl', 'cid', 'pid', 'hgt']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid', 'iyr']
#
# Passport is invalid!
#
#
# Valid passports: 48
# --------------------------------------------------------------------------------
# iyr:2015 eyr:2030 hgt:191cm byr:1979
# ecl:#ec4873 pid:994113786 hcl:#cfa07d
#
# Passport #:58
# fields present: ['iyr', 'eyr', 'hgt', 'byr', 'ecl', 'pid', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'iyr': '2015', 'eyr': '2030', 'hgt': '191cm', 'byr': '1979', 'ecl': '#ec4873', 'pid': '994113786', 'hcl': '#cfa07d'}
#
# Valid passports: 49
# --------------------------------------------------------------------------------
# pid:552331609
# ecl:grn
# hgt:171cm eyr:2022 hcl:#b6652a
# iyr:2020 byr:1931
#
# Passport #:59
# fields present: ['pid', 'ecl', 'hgt', 'eyr', 'hcl', 'iyr', 'byr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'pid': '552331609', 'ecl': 'grn', 'hgt': '171cm', 'eyr': '2022', 'hcl': '#b6652a', 'iyr': '2020', 'byr': '1931'}
#
# Valid passports: 50
# --------------------------------------------------------------------------------
# hgt:177cm iyr:2010 pid:934058099
# eyr:2020
# ecl:blu
# byr:1967
# cid:112 hcl:#7d3b0c
#
# Passport #:60
# fields present: ['hgt', 'iyr', 'pid', 'eyr', 'ecl', 'byr', 'cid', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'hgt': '177cm', 'iyr': '2010', 'pid': '934058099', 'eyr': '2020', 'ecl': 'blu', 'byr': '1967', 'cid': '112', 'hcl': '#7d3b0c'}
#
# Valid passports: 51
# --------------------------------------------------------------------------------
# iyr:2028
# hgt:138
# cid:180 hcl:z
# eyr:2022 pid:3286566621 byr:2002
#
# Passport #:61
# fields present: ['iyr', 'hgt', 'cid', 'hcl', 'eyr', 'pid', 'byr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid', 'ecl']
#
# Passport is invalid!
#
#
# Valid passports: 51
# --------------------------------------------------------------------------------
# eyr:2020
# iyr:2019
# hcl:#a97842 pid:149148750 ecl:brn hgt:159cm
# byr:1981 cid:339
#
# Passport #:62
# fields present: ['eyr', 'iyr', 'hcl', 'pid', 'ecl', 'hgt', 'byr', 'cid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'eyr': '2020', 'iyr': '2019', 'hcl': '#a97842', 'pid': '149148750', 'ecl': 'brn', 'hgt': '159cm', 'byr': '1981', 'cid': '339'}
#
# Valid passports: 52
# --------------------------------------------------------------------------------
# cid:344
# eyr:2021 byr:1968 pid:777786047
# ecl:grn hgt:192cm hcl:#888785
# iyr:2015
#
# Passport #:63
# fields present: ['cid', 'eyr', 'byr', 'pid', 'ecl', 'hgt', 'hcl', 'iyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'cid': '344', 'eyr': '2021', 'byr': '1968', 'pid': '777786047', 'ecl': 'grn', 'hgt': '192cm', 'hcl': '#888785', 'iyr': '2015'}
#
# Valid passports: 53
# --------------------------------------------------------------------------------
# hgt:173cm
# eyr:2030
# hcl:#733820 pid:610226642 byr:1954 cid:80
# iyr:2013 ecl:blu
#
# Passport #:64
# fields present: ['hgt', 'eyr', 'hcl', 'pid', 'byr', 'cid', 'iyr', 'ecl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'hgt': '173cm', 'eyr': '2030', 'hcl': '#733820', 'pid': '610226642', 'byr': '1954', 'cid': '80', 'iyr': '2013', 'ecl': 'blu'}
#
# Valid passports: 54
# --------------------------------------------------------------------------------
# byr:1999 eyr:2023
# ecl:amb pid:912145128
# hgt:181cm
# iyr:2015 hcl:#a97842
#
# Passport #:65
# fields present: ['byr', 'eyr', 'ecl', 'pid', 'hgt', 'iyr', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'byr': '1999', 'eyr': '2023', 'ecl': 'amb', 'pid': '912145128', 'hgt': '181cm', 'iyr': '2015', 'hcl': '#a97842'}
#
# Valid passports: 55
# --------------------------------------------------------------------------------
# eyr:2027 hgt:188cm
# pid:080715145 hcl:#341e13 iyr:2013
# ecl:oth
# byr:1965
#
# Passport #:66
# fields present: ['eyr', 'hgt', 'pid', 'hcl', 'iyr', 'ecl', 'byr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'eyr': '2027', 'hgt': '188cm', 'pid': '080715145', 'hcl': '#341e13', 'iyr': '2013', 'ecl': 'oth', 'byr': '1965'}
#
# Valid passports: 56
# --------------------------------------------------------------------------------
# hgt:170cm byr:1950 iyr:2013
# pid:010541784
# eyr:2027 ecl:zzz
# hcl:a3bae8
#
# Passport #:67
# fields present: ['hgt', 'byr', 'iyr', 'pid', 'eyr', 'ecl', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'hgt': '170cm', 'byr': '1950', 'iyr': '2013', 'pid': '010541784', 'eyr': '2027', 'ecl': 'zzz', 'hcl': 'a3bae8'}
#
# Valid passports: 57
# --------------------------------------------------------------------------------
# hgt:190cm eyr:2024 ecl:#6dcedc pid:909319684
# iyr:2011 byr:1959 hcl:z cid:182
#
# Passport #:68
# fields present: ['hgt', 'eyr', 'ecl', 'pid', 'iyr', 'byr', 'hcl', 'cid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'hgt': '190cm', 'eyr': '2024', 'ecl': '#6dcedc', 'pid': '909319684', 'iyr': '2011', 'byr': '1959', 'hcl': 'z', 'cid': '182'}
#
# Valid passports: 58
# --------------------------------------------------------------------------------
# eyr:2028
# iyr:2016 hcl:#623a2f pid:208417572 byr:1929 cid:137 ecl:hzl
# hgt:167cm
#
# Passport #:69
# fields present: ['eyr', 'iyr', 'hcl', 'pid', 'byr', 'cid', 'ecl', 'hgt']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'eyr': '2028', 'iyr': '2016', 'hcl': '#623a2f', 'pid': '208417572', 'byr': '1929', 'cid': '137', 'ecl': 'hzl', 'hgt': '167cm'}
#
# Valid passports: 59
# --------------------------------------------------------------------------------
# hcl:#6b5442
# ecl:grn
# byr:1938
# eyr:2023 cid:307
# hgt:59in iyr:2014 pid:205268145
#
# Passport #:70
# fields present: ['hcl', 'ecl', 'byr', 'eyr', 'cid', 'hgt', 'iyr', 'pid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'hcl': '#6b5442', 'ecl': 'grn', 'byr': '1938', 'eyr': '2023', 'cid': '307', 'hgt': '59in', 'iyr': '2014', 'pid': '205268145'}
#
# Valid passports: 60
# --------------------------------------------------------------------------------
# pid:047489285 eyr:2026
# hcl:#b6652a byr:1920
# iyr:2015
# hgt:183cm ecl:gry
#
# Passport #:71
# fields present: ['pid', 'eyr', 'hcl', 'byr', 'iyr', 'hgt', 'ecl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'pid': '047489285', 'eyr': '2026', 'hcl': '#b6652a', 'byr': '1920', 'iyr': '2015', 'hgt': '183cm', 'ecl': 'gry'}
#
# Valid passports: 61
# --------------------------------------------------------------------------------
# ecl:blu hcl:#508e8b iyr:2016 eyr:1954 hgt:151cm pid:086752750 byr:1920
#
# Passport #:72
# fields present: ['ecl', 'hcl', 'iyr', 'eyr', 'hgt', 'pid', 'byr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'ecl': 'blu', 'hcl': '#508e8b', 'iyr': '2016', 'eyr': '1954', 'hgt': '151cm', 'pid': '086752750', 'byr': '1920'}
#
# Valid passports: 62
# --------------------------------------------------------------------------------
# iyr:2011 byr:1981 hgt:186cm
# cid:117 hcl:#6b5442 ecl:amb
# pid:756830713 eyr:2026
#
# Passport #:73
# fields present: ['iyr', 'byr', 'hgt', 'cid', 'hcl', 'ecl', 'pid', 'eyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'iyr': '2011', 'byr': '1981', 'hgt': '186cm', 'cid': '117', 'hcl': '#6b5442', 'ecl': 'amb', 'pid': '756830713', 'eyr': '2026'}
#
# Valid passports: 63
# --------------------------------------------------------------------------------
# eyr:2037 pid:364464758 hcl:z ecl:grn
# hgt:112 iyr:2013 byr:2022
#
# Passport #:74
# fields present: ['eyr', 'pid', 'hcl', 'ecl', 'hgt', 'iyr', 'byr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'eyr': '2037', 'pid': '364464758', 'hcl': 'z', 'ecl': 'grn', 'hgt': '112', 'iyr': '2013', 'byr': '2022'}
#
# Valid passports: 64
# --------------------------------------------------------------------------------
# ecl:hzl
# cid:65 pid:679487194
# byr:1986 hgt:169cm hcl:#cfa07d eyr:2025 iyr:2013
#
# Passport #:75
# fields present: ['ecl', 'cid', 'pid', 'byr', 'hgt', 'hcl', 'eyr', 'iyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'ecl': 'hzl', 'cid': '65', 'pid': '679487194', 'byr': '1986', 'hgt': '169cm', 'hcl': '#cfa07d', 'eyr': '2025', 'iyr': '2013'}
#
# Valid passports: 65
# --------------------------------------------------------------------------------
# cid:192
# byr:1921 pid:#5fe831 ecl:#fbb2b9 hgt:62cm eyr:1971 iyr:2024
# hcl:z
#
# Passport #:76
# fields present: ['cid', 'byr', 'pid', 'ecl', 'hgt', 'eyr', 'iyr', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'cid': '192', 'byr': '1921', 'pid': '#5fe831', 'ecl': '#fbb2b9', 'hgt': '62cm', 'eyr': '1971', 'iyr': '2024', 'hcl': 'z'}
#
# Valid passports: 66
# --------------------------------------------------------------------------------
# hcl:#cfa07d eyr:2026
# hgt:74in
# iyr:2019
# ecl:xry
# pid:622690982 byr:1982
#
# Passport #:77
# fields present: ['hcl', 'eyr', 'hgt', 'iyr', 'ecl', 'pid', 'byr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'hcl': '#cfa07d', 'eyr': '2026', 'hgt': '74in', 'iyr': '2019', 'ecl': 'xry', 'pid': '622690982', 'byr': '1982'}
#
# Valid passports: 67
# --------------------------------------------------------------------------------
# eyr:2026 pid:523515724 iyr:2013 byr:1973 hgt:167cm
# ecl:grn hcl:#866857
#
# Passport #:78
# fields present: ['eyr', 'pid', 'iyr', 'byr', 'hgt', 'ecl', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'eyr': '2026', 'pid': '523515724', 'iyr': '2013', 'byr': '1973', 'hgt': '167cm', 'ecl': 'grn', 'hcl': '#866857'}
#
# Valid passports: 68
# --------------------------------------------------------------------------------
# byr:2009
# eyr:1985 pid:484497014 ecl:#0bfcf2 iyr:1992 cid:131 hcl:39d6b0 hgt:177in
#
# Passport #:79
# fields present: ['byr', 'eyr', 'pid', 'ecl', 'iyr', 'cid', 'hcl', 'hgt']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'byr': '2009', 'eyr': '1985', 'pid': '484497014', 'ecl': '#0bfcf2', 'iyr': '1992', 'cid': '131', 'hcl': '39d6b0', 'hgt': '177in'}
#
# Valid passports: 69
# --------------------------------------------------------------------------------
# eyr:2020 iyr:2016 ecl:brn hcl:#ceb3a1 byr:1966 pid:696621560 cid:62
# hgt:59in
#
# Passport #:80
# fields present: ['eyr', 'iyr', 'ecl', 'hcl', 'byr', 'pid', 'cid', 'hgt']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'eyr': '2020', 'iyr': '2016', 'ecl': 'brn', 'hcl': '#ceb3a1', 'byr': '1966', 'pid': '696621560', 'cid': '62', 'hgt': '59in'}
#
# Valid passports: 70
# --------------------------------------------------------------------------------
# hgt:166cm hcl:#7d3b0c
# iyr:2016
# ecl:brn pid:190cm
# eyr:2020
# byr:2001
#
# Passport #:81
# fields present: ['hgt', 'hcl', 'iyr', 'ecl', 'pid', 'eyr', 'byr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'hgt': '166cm', 'hcl': '#7d3b0c', 'iyr': '2016', 'ecl': 'brn', 'pid': '190cm', 'eyr': '2020', 'byr': '2001'}
#
# Valid passports: 71
# --------------------------------------------------------------------------------
# eyr:2021
# iyr:2012 hcl:#6b5442
# ecl:amb hgt:169cm
# pid:969150085
# byr:1925
#
# Passport #:82
# fields present: ['eyr', 'iyr', 'hcl', 'ecl', 'hgt', 'pid', 'byr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'eyr': '2021', 'iyr': '2012', 'hcl': '#6b5442', 'ecl': 'amb', 'hgt': '169cm', 'pid': '969150085', 'byr': '1925'}
#
# Valid passports: 72
# --------------------------------------------------------------------------------
# ecl:brn hgt:175cm byr:1992 iyr:2016 pid:415209726 eyr:2027
# cid:72 hcl:#866857
#
# Passport #:83
# fields present: ['ecl', 'hgt', 'byr', 'iyr', 'pid', 'eyr', 'cid', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'ecl': 'brn', 'hgt': '175cm', 'byr': '1992', 'iyr': '2016', 'pid': '415209726', 'eyr': '2027', 'cid': '72', 'hcl': '#866857'}
#
# Valid passports: 73
# --------------------------------------------------------------------------------
# iyr:2017
# hcl:#733820 byr:1938 eyr:2020 pid:274486958 hgt:163cm
#
# Passport #:84
# fields present: ['iyr', 'hcl', 'byr', 'eyr', 'pid', 'hgt']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['ecl']
#
# Passport is invalid!
#
#
# Valid passports: 73
# --------------------------------------------------------------------------------
# hcl:4f5dd1 cid:336 ecl:grn iyr:1931 pid:6212280197
# byr:2016 eyr:2037
# hgt:187in
#
# Passport #:85
# fields present: ['hcl', 'cid', 'ecl', 'iyr', 'pid', 'byr', 'eyr', 'hgt']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'hcl': '4f5dd1', 'cid': '336', 'ecl': 'grn', 'iyr': '1931', 'pid': '6212280197', 'byr': '2016', 'eyr': '2037', 'hgt': '187in'}
#
# Valid passports: 74
# --------------------------------------------------------------------------------
# iyr:2017 byr:1940 eyr:2025 pid:115098205 hgt:151cm
# ecl:grn
# cid:122
# hcl:#6b5442
#
# Passport #:86
# fields present: ['iyr', 'byr', 'eyr', 'pid', 'hgt', 'ecl', 'cid', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'iyr': '2017', 'byr': '1940', 'eyr': '2025', 'pid': '115098205', 'hgt': '151cm', 'ecl': 'grn', 'cid': '122', 'hcl': '#6b5442'}
#
# Valid passports: 75
# --------------------------------------------------------------------------------
# hcl:#efcc98
# iyr:2020 pid:709548547 hgt:179cm
# eyr:2030 ecl:gry byr:1975
#
# Passport #:87
# fields present: ['hcl', 'iyr', 'pid', 'hgt', 'eyr', 'ecl', 'byr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'hcl': '#efcc98', 'iyr': '2020', 'pid': '709548547', 'hgt': '179cm', 'eyr': '2030', 'ecl': 'gry', 'byr': '1975'}
#
# Valid passports: 76
# --------------------------------------------------------------------------------
# cid:217 hcl:#888785 eyr:2029
# ecl:hzl iyr:2013 pid:160053490
# hgt:166cm byr:1992
#
# Passport #:88
# fields present: ['cid', 'hcl', 'eyr', 'ecl', 'iyr', 'pid', 'hgt', 'byr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'cid': '217', 'hcl': '#888785', 'eyr': '2029', 'ecl': 'hzl', 'iyr': '2013', 'pid': '160053490', 'hgt': '166cm', 'byr': '1992'}
#
# Valid passports: 77
# --------------------------------------------------------------------------------
# eyr:2024 cid:188 iyr:2016 hcl:ff3a59 ecl:xry pid:296357512 byr:2026
#
# Passport #:89
# fields present: ['eyr', 'cid', 'iyr', 'hcl', 'ecl', 'pid', 'byr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid', 'hgt']
#
# Passport is invalid!
#
#
# Valid passports: 77
# --------------------------------------------------------------------------------
# hgt:154cm iyr:2010
# ecl:blu pid:717041634 byr:1928 cid:123
# eyr:2027
# hcl:#a97842
#
# Passport #:90
# fields present: ['hgt', 'iyr', 'ecl', 'pid', 'byr', 'cid', 'eyr', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'hgt': '154cm', 'iyr': '2010', 'ecl': 'blu', 'pid': '717041634', 'byr': '1928', 'cid': '123', 'eyr': '2027', 'hcl': '#a97842'}
#
# Valid passports: 78
# --------------------------------------------------------------------------------
# pid:391011205 ecl:hzl hgt:191cm iyr:2016 eyr:2028 cid:281 byr:1934
#
# Passport #:91
# fields present: ['pid', 'ecl', 'hgt', 'iyr', 'eyr', 'cid', 'byr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid', 'hcl']
#
# Passport is invalid!
#
#
# Valid passports: 78
# --------------------------------------------------------------------------------
# byr:1937 hgt:65in
# pid:667975382 ecl:gry cid:270 eyr:2024
# iyr:2012
#
# Passport #:92
# fields present: ['byr', 'hgt', 'pid', 'ecl', 'cid', 'eyr', 'iyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid', 'hcl']
#
# Passport is invalid!
#
#
# Valid passports: 78
# --------------------------------------------------------------------------------
# hgt:179cm pid:065528723
# hcl:#888785 byr:1937 eyr:2028
# iyr:2013 ecl:hzl
#
# Passport #:93
# fields present: ['hgt', 'pid', 'hcl', 'byr', 'eyr', 'iyr', 'ecl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'hgt': '179cm', 'pid': '065528723', 'hcl': '#888785', 'byr': '1937', 'eyr': '2028', 'iyr': '2013', 'ecl': 'hzl'}
#
# Valid passports: 79
# --------------------------------------------------------------------------------
# iyr:2027 cid:261 eyr:2037 ecl:#ced7d5 pid:157cm
# hcl:3a80c1 byr:2029 hgt:187in
#
# Passport #:94
# fields present: ['iyr', 'cid', 'eyr', 'ecl', 'pid', 'hcl', 'byr', 'hgt']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'iyr': '2027', 'cid': '261', 'eyr': '2037', 'ecl': '#ced7d5', 'pid': '157cm', 'hcl': '3a80c1', 'byr': '2029', 'hgt': '187in'}
#
# Valid passports: 80
# --------------------------------------------------------------------------------
# eyr:2028
# hgt:157cm hcl:#733820
# iyr:2012 ecl:blu byr:1952 pid:915063263 cid:335
#
# Passport #:95
# fields present: ['eyr', 'hgt', 'hcl', 'iyr', 'ecl', 'byr', 'pid', 'cid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'eyr': '2028', 'hgt': '157cm', 'hcl': '#733820', 'iyr': '2012', 'ecl': 'blu', 'byr': '1952', 'pid': '915063263', 'cid': '335'}
#
# Valid passports: 81
# --------------------------------------------------------------------------------
# eyr:2023 hcl:#efcc98 pid:490625944 byr:1961 ecl:grn hgt:155cm iyr:2018
#
# Passport #:96
# fields present: ['eyr', 'hcl', 'pid', 'byr', 'ecl', 'hgt', 'iyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'eyr': '2023', 'hcl': '#efcc98', 'pid': '490625944', 'byr': '1961', 'ecl': 'grn', 'hgt': '155cm', 'iyr': '2018'}
#
# Valid passports: 82
# --------------------------------------------------------------------------------
# cid:247 pid:2807544665 eyr:2021
# ecl:oth
# hgt:191cm
# byr:1928
# iyr:2013 hcl:#623a2f
#
# Passport #:97
# fields present: ['cid', 'pid', 'eyr', 'ecl', 'hgt', 'byr', 'iyr', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'cid': '247', 'pid': '2807544665', 'eyr': '2021', 'ecl': 'oth', 'hgt': '191cm', 'byr': '1928', 'iyr': '2013', 'hcl': '#623a2f'}
#
# Valid passports: 83
# --------------------------------------------------------------------------------
# eyr:2015
# byr:2021
# hcl:40d2fc hgt:69cm pid:159cm ecl:gmt
#
# Passport #:98
# fields present: ['eyr', 'byr', 'hcl', 'hgt', 'pid', 'ecl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['iyr']
#
# Passport is invalid!
#
#
# Valid passports: 83
# --------------------------------------------------------------------------------
# hgt:175cm eyr:1992 cid:328 pid:263110997 ecl:#e53989 byr:2014 hcl:#a97842 iyr:2026
#
# Passport #:99
# fields present: ['hgt', 'eyr', 'cid', 'pid', 'ecl', 'byr', 'hcl', 'iyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'hgt': '175cm', 'eyr': '1992', 'cid': '328', 'pid': '263110997', 'ecl': '#e53989', 'byr': '2014', 'hcl': '#a97842', 'iyr': '2026'}
#
# Valid passports: 84
# --------------------------------------------------------------------------------
# pid:491396731 eyr:2027 hgt:172cm hcl:#623a2f cid:92 iyr:2017 byr:1983 ecl:grn
#
# Passport #:100
# fields present: ['pid', 'eyr', 'hgt', 'hcl', 'cid', 'iyr', 'byr', 'ecl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'pid': '491396731', 'eyr': '2027', 'hgt': '172cm', 'hcl': '#623a2f', 'cid': '92', 'iyr': '2017', 'byr': '1983', 'ecl': 'grn'}
#
# Valid passports: 85
# --------------------------------------------------------------------------------
# hcl:#fffffd
# iyr:2018 byr:1983 pid:714591144 ecl:grn eyr:2021
# hgt:160cm
#
# Passport #:101
# fields present: ['hcl', 'iyr', 'byr', 'pid', 'ecl', 'eyr', 'hgt']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'hcl': '#fffffd', 'iyr': '2018', 'byr': '1983', 'pid': '714591144', 'ecl': 'grn', 'eyr': '2021', 'hgt': '160cm'}
#
# Valid passports: 86
# --------------------------------------------------------------------------------
# eyr:2027
# hgt:63in ecl:blu byr:1987 pid:397963077 iyr:2018 hcl:#ceb3a1
#
# Passport #:102
# fields present: ['eyr', 'hgt', 'ecl', 'byr', 'pid', 'iyr', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'eyr': '2027', 'hgt': '63in', 'ecl': 'blu', 'byr': '1987', 'pid': '397963077', 'iyr': '2018', 'hcl': '#ceb3a1'}
#
# Valid passports: 87
# --------------------------------------------------------------------------------
# eyr:2027
# hgt:184cm
# hcl:#6b5442 iyr:2012 byr:1984 ecl:blu pid:196287205
#
# Passport #:103
# fields present: ['eyr', 'hgt', 'hcl', 'iyr', 'byr', 'ecl', 'pid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'eyr': '2027', 'hgt': '184cm', 'hcl': '#6b5442', 'iyr': '2012', 'byr': '1984', 'ecl': 'blu', 'pid': '196287205'}
#
# Valid passports: 88
# --------------------------------------------------------------------------------
# iyr:1998
# ecl:hzl
# pid:7872103596 byr:1991
# cid:275 eyr:2039
# hgt:174cm hcl:0d2ad6
#
# Passport #:104
# ...
#
# Valid passports: 221
# --------------------------------------------------------------------------------
# byr:1995 ecl:hzl
# iyr:2017
# hcl:#a97842 pid:917039291 eyr:2026 hgt:175cm
#
# Passport #:249
# fields present: ['byr', 'ecl', 'iyr', 'hcl', 'pid', 'eyr', 'hgt']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'byr': '1995', 'ecl': 'hzl', 'iyr': '2017', 'hcl': '#a97842', 'pid': '917039291', 'eyr': '2026', 'hgt': '175cm'}
#
# Valid passports: 222
# --------------------------------------------------------------------------------
# iyr:2017 pid:756519868
# hcl:#623a2f
# eyr:2028
# hgt:158cm
# ecl:amb byr:1957
#
# Passport #:250
# fields present: ['iyr', 'pid', 'hcl', 'eyr', 'hgt', 'ecl', 'byr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'iyr': '2017', 'pid': '756519868', 'hcl': '#623a2f', 'eyr': '2028', 'hgt': '158cm', 'ecl': 'amb', 'byr': '1957'}
#
# Valid passports: 223
# --------------------------------------------------------------------------------
# iyr:2012
# hgt:158cm
# byr:2014 pid:973021666 hcl:f04766 eyr:2035 ecl:utc
#
# Passport #:251
# fields present: ['iyr', 'hgt', 'byr', 'pid', 'hcl', 'eyr', 'ecl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'iyr': '2012', 'hgt': '158cm', 'byr': '2014', 'pid': '973021666', 'hcl': 'f04766', 'eyr': '2035', 'ecl': 'utc'}
#
# Valid passports: 224
# --------------------------------------------------------------------------------
# ecl:blu
# byr:1989 eyr:2022
# pid:520765501
# cid:200 hgt:193cm hcl:#a97842 iyr:2011
#
# Passport #:252
# fields present: ['ecl', 'byr', 'eyr', 'pid', 'cid', 'hgt', 'hcl', 'iyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'ecl': 'blu', 'byr': '1989', 'eyr': '2022', 'pid': '520765501', 'cid': '200', 'hgt': '193cm', 'hcl': '#a97842', 'iyr': '2011'}
#
# Valid passports: 225
# --------------------------------------------------------------------------------
# byr:1959
# ecl:blu hcl:#733820 cid:284 hgt:162cm
# eyr:2022 pid:751629408 iyr:2016
#
# Passport #:253
# fields present: ['byr', 'ecl', 'hcl', 'cid', 'hgt', 'eyr', 'pid', 'iyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'byr': '1959', 'ecl': 'blu', 'hcl': '#733820', 'cid': '284', 'hgt': '162cm', 'eyr': '2022', 'pid': '751629408', 'iyr': '2016'}
#
# Valid passports: 226
# --------------------------------------------------------------------------------
# byr:1978 cid:301
# ecl:oth hgt:67cm hcl:#888785
# eyr:2040 iyr:2025 pid:26038514
#
# Passport #:254
# fields present: ['byr', 'cid', 'ecl', 'hgt', 'hcl', 'eyr', 'iyr', 'pid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'byr': '1978', 'cid': '301', 'ecl': 'oth', 'hgt': '67cm', 'hcl': '#888785', 'eyr': '2040', 'iyr': '2025', 'pid': '26038514'}
#
# Valid passports: 227
# --------------------------------------------------------------------------------
# iyr:2020 byr:1974 hgt:163cm ecl:blu hcl:#7d3b0c eyr:2028 cid:99
#
# Passport #:255
# fields present: ['iyr', 'byr', 'hgt', 'ecl', 'hcl', 'eyr', 'cid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid', 'pid']
#
# Passport is invalid!
#
#
# Valid passports: 227
# --------------------------------------------------------------------------------
# hcl:#a97842
# hgt:186cm
# ecl:grn byr:1969 pid:460360492 iyr:2011 eyr:2028
#
# Passport #:256
# fields present: ['hcl', 'hgt', 'ecl', 'byr', 'pid', 'iyr', 'eyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'hcl': '#a97842', 'hgt': '186cm', 'ecl': 'grn', 'byr': '1969', 'pid': '460360492', 'iyr': '2011', 'eyr': '2028'}
#
# Valid passports: 228
# --------------------------------------------------------------------------------
# byr:2009
# pid:489490924 eyr:2031
# hcl:cb5351 ecl:#083a25 hgt:164cm
#
# Passport #:257
# fields present: ['byr', 'pid', 'eyr', 'hcl', 'ecl', 'hgt']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['iyr']
#
# Passport is invalid!
#
#
# Valid passports: 228
# --------------------------------------------------------------------------------
# iyr:2019
# hcl:3463cc ecl:amb pid:4089063078 eyr:2022 hgt:150cm
# byr:2007
#
# Passport #:258
# fields present: ['iyr', 'hcl', 'ecl', 'pid', 'eyr', 'hgt', 'byr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'iyr': '2019', 'hcl': '3463cc', 'ecl': 'amb', 'pid': '4089063078', 'eyr': '2022', 'hgt': '150cm', 'byr': '2007'}
#
# Valid passports: 229
# --------------------------------------------------------------------------------
# eyr:2028 hcl:#ceb3a1
# hgt:191cm iyr:2019 pid:737842199 ecl:blu cid:268 byr:1925
#
# Passport #:259
# fields present: ['eyr', 'hcl', 'hgt', 'iyr', 'pid', 'ecl', 'cid', 'byr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'eyr': '2028', 'hcl': '#ceb3a1', 'hgt': '191cm', 'iyr': '2019', 'pid': '737842199', 'ecl': 'blu', 'cid': '268', 'byr': '1925'}
#
# Valid passports: 230
# --------------------------------------------------------------------------------
# pid:868397851
# hcl:#efcc98 ecl:grn iyr:2017 eyr:2021 byr:1943
# hgt:179cm
#
# Passport #:260
# fields present: ['pid', 'hcl', 'ecl', 'iyr', 'eyr', 'byr', 'hgt']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'pid': '868397851', 'hcl': '#efcc98', 'ecl': 'grn', 'iyr': '2017', 'eyr': '2021', 'byr': '1943', 'hgt': '179cm'}
#
# Valid passports: 231
# --------------------------------------------------------------------------------
# hcl:#623a2f byr:1987 eyr:2023 iyr:2019 hgt:152cm
# pid:473569020
# ecl:grn
#
# Passport #:261
# fields present: ['hcl', 'byr', 'eyr', 'iyr', 'hgt', 'pid', 'ecl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'hcl': '#623a2f', 'byr': '1987', 'eyr': '2023', 'iyr': '2019', 'hgt': '152cm', 'pid': '473569020', 'ecl': 'grn'}
#
# Valid passports: 232
# --------------------------------------------------------------------------------
# pid:953968630
# hgt:175cm
# byr:1971 ecl:blu hcl:#623a2f iyr:2017 cid:336 eyr:2030
#
# Passport #:262
# fields present: ['pid', 'hgt', 'byr', 'ecl', 'hcl', 'iyr', 'cid', 'eyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'pid': '953968630', 'hgt': '175cm', 'byr': '1971', 'ecl': 'blu', 'hcl': '#623a2f', 'iyr': '2017', 'cid': '336', 'eyr': '2030'}
#
# Valid passports: 233
# --------------------------------------------------------------------------------
# ecl:grt hgt:74cm byr:2022 eyr:2024 pid:39114027
# iyr:2026 hcl:4b5675
#
# Passport #:263
# fields present: ['ecl', 'hgt', 'byr', 'eyr', 'pid', 'iyr', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'ecl': 'grt', 'hgt': '74cm', 'byr': '2022', 'eyr': '2024', 'pid': '39114027', 'iyr': '2026', 'hcl': '4b5675'}
#
# Valid passports: 234
# --------------------------------------------------------------------------------
# pid:#492988
# eyr:2032 hgt:63cm iyr:2006
# ecl:#817211 byr:2019
#
# Passport #:264
# fields present: ['pid', 'eyr', 'hgt', 'iyr', 'ecl', 'byr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['hcl']
#
# Passport is invalid!
#
#
# Valid passports: 234
# --------------------------------------------------------------------------------
# pid:800367032 hcl:#341e13
# ecl:#765111 iyr:2012 byr:2006 hgt:166cm cid:291 eyr:2027
#
# Passport #:265
# fields present: ['pid', 'hcl', 'ecl', 'iyr', 'byr', 'hgt', 'cid', 'eyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'pid': '800367032', 'hcl': '#341e13', 'ecl': '#765111', 'iyr': '2012', 'byr': '2006', 'hgt': '166cm', 'cid': '291', 'eyr': '2027'}
#
# Valid passports: 235
# --------------------------------------------------------------------------------
# eyr:2021 iyr:2012 pid:876581393 ecl:amb hcl:#866857
# hgt:64in byr:1993
#
# Passport #:266
# fields present: ['eyr', 'iyr', 'pid', 'ecl', 'hcl', 'hgt', 'byr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'eyr': '2021', 'iyr': '2012', 'pid': '876581393', 'ecl': 'amb', 'hcl': '#866857', 'hgt': '64in', 'byr': '1993'}
#
# Valid passports: 236
# --------------------------------------------------------------------------------
# iyr:2017 byr:1996 ecl:hzl pid:038990744
# eyr:2028
# hgt:177cm
# hcl:#c0946f
#
# Passport #:267
# fields present: ['iyr', 'byr', 'ecl', 'pid', 'eyr', 'hgt', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'iyr': '2017', 'byr': '1996', 'ecl': 'hzl', 'pid': '038990744', 'eyr': '2028', 'hgt': '177cm', 'hcl': '#c0946f'}
#
# Valid passports: 237
# --------------------------------------------------------------------------------
# hcl:#4214a6
# eyr:2021
# iyr:2019 cid:72 byr:1939
# ecl:hzl pid:783071912 hgt:187cm
#
# Passport #:268
# fields present: ['hcl', 'eyr', 'iyr', 'cid', 'byr', 'ecl', 'pid', 'hgt']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'hcl': '#4214a6', 'eyr': '2021', 'iyr': '2019', 'cid': '72', 'byr': '1939', 'ecl': 'hzl', 'pid': '783071912', 'hgt': '187cm'}
#
# Valid passports: 238
# --------------------------------------------------------------------------------
# eyr:2020 hgt:158cm
# pid:274060737 cid:277
# iyr:2015 hcl:#bf9b5e byr:1950 ecl:brn
#
# Passport #:269
# fields present: ['eyr', 'hgt', 'pid', 'cid', 'iyr', 'hcl', 'byr', 'ecl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'eyr': '2020', 'hgt': '158cm', 'pid': '274060737', 'cid': '277', 'iyr': '2015', 'hcl': '#bf9b5e', 'byr': '1950', 'ecl': 'brn'}
#
# Valid passports: 239
# --------------------------------------------------------------------------------
# byr:1921 hcl:#7d3b0c cid:329 hgt:155cm eyr:2030 pid:718399669 iyr:2011 ecl:brn
#
# Passport #:270
# fields present: ['byr', 'hcl', 'cid', 'hgt', 'eyr', 'pid', 'iyr', 'ecl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'byr': '1921', 'hcl': '#7d3b0c', 'cid': '329', 'hgt': '155cm', 'eyr': '2030', 'pid': '718399669', 'iyr': '2011', 'ecl': 'brn'}
#
# Valid passports: 240
# --------------------------------------------------------------------------------
# cid:147 eyr:2021 hgt:167cm iyr:2010 ecl:grn byr:1975 hcl:#6b5442
# pid:285479783
#
# Passport #:271
# fields present: ['cid', 'eyr', 'hgt', 'iyr', 'ecl', 'byr', 'hcl', 'pid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'cid': '147', 'eyr': '2021', 'hgt': '167cm', 'iyr': '2010', 'ecl': 'grn', 'byr': '1975', 'hcl': '#6b5442', 'pid': '285479783'}
#
# Valid passports: 241
# --------------------------------------------------------------------------------
# hgt:187cm
# byr:2004 eyr:2025 hcl:bb331b
# pid:851189955 iyr:2016
# ecl:amb
#
# Passport #:272
# fields present: ['hgt', 'byr', 'eyr', 'hcl', 'pid', 'iyr', 'ecl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'hgt': '187cm', 'byr': '2004', 'eyr': '2025', 'hcl': 'bb331b', 'pid': '851189955', 'iyr': '2016', 'ecl': 'amb'}
#
# Valid passports: 242
# --------------------------------------------------------------------------------
# hcl:#94007d pid:361561551 byr:1927 eyr:2026 iyr:2020
# ecl:gry hgt:158cm
#
# Passport #:273
# fields present: ['hcl', 'pid', 'byr', 'eyr', 'iyr', 'ecl', 'hgt']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'hcl': '#94007d', 'pid': '361561551', 'byr': '1927', 'eyr': '2026', 'iyr': '2020', 'ecl': 'gry', 'hgt': '158cm'}
#
# Valid passports: 243
# --------------------------------------------------------------------------------
# byr:1993 pid:#24c4af iyr:2023 hgt:175cm eyr:2028
# hcl:z ecl:hzl cid:308
#
# Passport #:274
# fields present: ['byr', 'pid', 'iyr', 'hgt', 'eyr', 'hcl', 'ecl', 'cid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'byr': '1993', 'pid': '#24c4af', 'iyr': '2023', 'hgt': '175cm', 'eyr': '2028', 'hcl': 'z', 'ecl': 'hzl', 'cid': '308'}
#
# Valid passports: 244
# --------------------------------------------------------------------------------
# byr:1985 hcl:#c0946f eyr:2034 hgt:172cm
# cid:300 iyr:2013 ecl:gry pid:389455676
#
# Passport #:275
# fields present: ['byr', 'hcl', 'eyr', 'hgt', 'cid', 'iyr', 'ecl', 'pid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'byr': '1985', 'hcl': '#c0946f', 'eyr': '2034', 'hgt': '172cm', 'cid': '300', 'iyr': '2013', 'ecl': 'gry', 'pid': '389455676'}
#
# Valid passports: 245
# --------------------------------------------------------------------------------
# eyr:2030 iyr:2017 byr:1956 hgt:178cm
# pid:864401853 hcl:#6b5442
#
# Passport #:276
# fields present: ['eyr', 'iyr', 'byr', 'hgt', 'pid', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['ecl']
#
# Passport is invalid!
#
#
# Valid passports: 245
# --------------------------------------------------------------------------------
# pid:836559549
# iyr:2011
# hgt:167cm
# ecl:amb hcl:#c0946f
# eyr:2026 byr:1981
#
# Passport #:277
# fields present: ['pid', 'iyr', 'hgt', 'ecl', 'hcl', 'eyr', 'byr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'pid': '836559549', 'iyr': '2011', 'hgt': '167cm', 'ecl': 'amb', 'hcl': '#c0946f', 'eyr': '2026', 'byr': '1981'}
#
# Valid passports: 246
# --------------------------------------------------------------------------------
# pid:111085991 iyr:2011
# ecl:blu eyr:2026 cid:311
# byr:1920 hgt:182cm hcl:#602927
#
# Passport #:278
# fields present: ['pid', 'iyr', 'ecl', 'eyr', 'cid', 'byr', 'hgt', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'pid': '111085991', 'iyr': '2011', 'ecl': 'blu', 'eyr': '2026', 'cid': '311', 'byr': '1920', 'hgt': '182cm', 'hcl': '#602927'}
#
# Valid passports: 247
# --------------------------------------------------------------------------------
# ecl:oth pid:284436132
# byr:1929 cid:121
# eyr:2027
# iyr:2010
# hgt:75in
# hcl:#6b5442
#
# Passport #:279
# fields present: ['ecl', 'pid', 'byr', 'cid', 'eyr', 'iyr', 'hgt', 'hcl']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'ecl': 'oth', 'pid': '284436132', 'byr': '1929', 'cid': '121', 'eyr': '2027', 'iyr': '2010', 'hgt': '75in', 'hcl': '#6b5442'}
#
# Valid passports: 248
# --------------------------------------------------------------------------------
# byr:1987
# hcl:#7d3b0c iyr:2018 hgt:180cm
# ecl:blu eyr:2029 pid:878348021
#
# Passport #:280
# fields present: ['byr', 'hcl', 'iyr', 'hgt', 'ecl', 'eyr', 'pid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: []
#
# Passport is valid
#
# {'byr': '1987', 'hcl': '#7d3b0c', 'iyr': '2018', 'hgt': '180cm', 'ecl': 'blu', 'eyr': '2029', 'pid': '878348021'}
#
# Valid passports: 249
# --------------------------------------------------------------------------------
# hgt:183cm cid:98
# byr:1953 hcl:#866857 eyr:2021 iyr:2012 pid:158898193
#
# Passport #:281
# fields present: ['hgt', 'cid', 'byr', 'hcl', 'eyr', 'iyr', 'pid']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid', 'ecl']
#
# Passport is invalid!
#
#
# Valid passports: 249
# --------------------------------------------------------------------------------
# eyr:2030 pid:039638764 ecl:hzl hgt:190cm byr:1926
# cid:294 hcl:#b6652a iyr:2017
#
# Passport #:282
# fields present: ['eyr', 'pid', 'ecl', 'hgt', 'byr', 'cid', 'hcl', 'iyr']
# valid fields: ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# differences: ['cid']
#
# Passport is valid
#
# {'eyr': '2030', 'pid': '039638764', 'ecl': 'hzl', 'hgt': '190cm', 'byr': '1926', 'cid': '294', 'hcl': '#b6652a', 'iyr': '2017'}
#
# Valid passports: 250
# --------------------------------------------------------------------------------

# %%
valid_count
# Out:
# 250

# %% [markdown]
# ### Part 2
#
# byr
# - four digits; at least 1920 and at most 2002
#
# iyr
# - four digits; at least 2010 and at most 2020.
#
# eyr
# - four digits; at least 2020 and at most 2030.
#
# hgt
# - a number followed by either cm or in:
# - If cm, the number must be at least 150 and at most 193.
# - If in, the number must be at least 59 and at most 76.
#
# hcl
# - a # followed by exactly six characters 0-9 or a-f.
#
# ecl
# - exactly one of: amb blu brn gry grn hzl oth.
#
# pid
# - a nine-digit number, including leading zeroes.
#
# cid
# - ignored, missing or not.

# %%
byr_min = 1920
byr_max = 2002

iyr_min = 2010
iyr_max = 2020

eyr_min = 2020
eyr_max = 2030

cm_min = 150
cm_max = 193

in_min = 59
in_max = 76

pid_max = 9

ecl_opts = ['amb', 'blu', 'brn', 'gry', 'grn', 'hzl', 'oth']

num_keys = ['byr','iyr', 'eyr']

# %%
results
# Out:
# {'valids': [{'eyr': '2024',
#    'pid': '662406624',
#    'hcl': '#cfa07d',
#    'byr': '1947',
#    'iyr': '2015',
#    'ecl': 'amb',
#    'hgt': '150cm'},
#   {'iyr': '2013',
#    'byr': '1997',
#    'hgt': '182cm',
#    'hcl': '#ceb3a1',
#    'eyr': '2027',
#    'ecl': 'gry',
#    'cid': '102',
#    'pid': '018128535'},
#   {'hcl': '#a97842',
#    'eyr': '2026',
#    'byr': '1980',
#    'ecl': 'grn',
#    'pid': '726519569',
#    'hgt': '184cm',
#    'cid': '132',
#    'iyr': '2011'},
#   {'ecl': 'grn',
#    'hcl': '#6b5442',
#    'pid': '619743219',
#    'cid': '69',
#    'hgt': '176cm',
#    'eyr': '2027',
#    'iyr': '2012',
#    'byr': '1980'},
#   {'ecl': 'brn',
#    'byr': '1969',
#    'iyr': '2014',
#    'hgt': '164cm',
#    'eyr': '2020',
#    'pid': '982796633',
#    'hcl': '#602927'},
#   {'cid': '117',
#    'hcl': '#efcc98',
#    'iyr': '2010',
#    'pid': '322719183',
#    'hgt': '176cm',
#    'eyr': '2020',
#    'byr': '1957',
#    'ecl': 'brn'},
#   {'byr': '1954',
#    'hgt': '178cm',
#    'hcl': '#38f7fd',
#    'pid': '838813262',
#    'ecl': 'blu',
#    'eyr': '2029',
#    'iyr': '2019'},
#   {'eyr': '2023',
#    'ecl': 'amb',
#    'iyr': '2020',
#    'byr': '1927',
#    'pid': '242570886',
#    'hcl': '#18171d',
#    'hgt': '192cm'},
#   {'iyr': '1990',
#    'cid': '295',
#    'hgt': '131',
#    'pid': '187cm',
#    'byr': '2014',
#    'ecl': 'xry',
#    'hcl': 'z',
#    'eyr': '1928'},
#   {'ecl': 'hzl',
#    'byr': '1953',
#    'eyr': '2023',
#    'hcl': '#866857',
#    'hgt': '181cm',
#    'iyr': '2010',
#    'pid': '568185567'},
#   {'byr': '2030',
#    'hcl': '#fffffd',
#    'ecl': '#a4a596',
#    'hgt': '168cm',
#    'iyr': '1936',
#    'eyr': '2020',
#    'cid': '296',
#    'pid': '168786676'},
#   {'byr': '2030',
#    'iyr': '2026',
#    'eyr': '1974',
#    'hcl': '7fcaa5',
#    'ecl': 'utc',
#    'pid': '190cm',
#    'hgt': '67cm'},
#   {'byr': '2023',
#    'eyr': '2037',
#    'hgt': '59cm',
#    'ecl': 'lzr',
#    'hcl': 'z',
#    'iyr': '2026',
#    'pid': '#ea9083'},
#   {'byr': '2003',
#    'hcl': 'z',
#    'hgt': '91',
#    'iyr': '1990',
#    'eyr': '2024',
#    'ecl': '#123d73',
#    'pid': '48494230'},
#   {'byr': '2022',
#    'eyr': '2020',
#    'iyr': '2030',
#    'ecl': 'gmt',
#    'hgt': '191cm',
#    'pid': '3509331253',
#    'hcl': '#888785'},
#   {'iyr': '1994',
#    'ecl': '#c3d564',
#    'byr': '2009',
#    'hgt': '162cm',
#    'hcl': '336498',
#    'pid': '#e99d09',
#    'cid': '288',
#    'eyr': '1921'},
#   {'byr': '1924',
#    'cid': '290',
#    'iyr': '2010',
#    'ecl': 'amb',
#    'eyr': '2020',
#    'hgt': '156cm',
#    'hcl': '#7d3b0c',
#    'pid': '795497164'},
#   {'cid': '301',
#    'iyr': '2017',
#    'hgt': '67cm',
#    'hcl': '#888785',
#    'ecl': '#0405b9',
#    'byr': '1964',
#    'pid': '707857518',
#    'eyr': '1976'},
#   {'ecl': 'gry',
#    'pid': '474303066',
#    'iyr': '2011',
#    'hcl': '#18171d',
#    'hgt': '165cm',
#    'byr': '1921',
#    'eyr': '2024'},
#   {'hcl': '#6b5442',
#    'ecl': 'amb',
#    'iyr': '2020',
#    'hgt': '191cm',
#    'byr': '1949',
#    'cid': '301',
#    'pid': '075846582',
#    'eyr': '2029'},
#   {'hcl': '#a97842',
#    'cid': '186',
#    'iyr': '2014',
#    'ecl': 'gry',
#    'hgt': '191cm',
#    'eyr': '2023',
#    'pid': '645548969',
#    'byr': '1956'},
#   {'hgt': '72cm',
#    'byr': '2023',
#    'eyr': '2034',
#    'hcl': 'z',
#    'ecl': '#f5249e',
#    'iyr': '1997',
#    'pid': '#79af7a'},
#   {'eyr': '2038',
#    'byr': '2015',
#    'hgt': '70cm',
#    'ecl': 'grt',
#    'hcl': '9d58a1',
#    'iyr': '1926',
#    'pid': '6290928420'},
#   {'pid': '620857794',
#    'eyr': '2022',
#    'byr': '1950',
#    'hgt': '159cm',
#    'hcl': '#ceb3a1',
#    'ecl': 'amb',
#    'iyr': '2015'},
#   {'eyr': '1954',
#    'ecl': '#ab2ce4',
#    'pid': '#14eedd',
#    'iyr': '2009',
#    'hcl': '29e484',
#    'byr': '2022',
#    'hgt': '73cm'},
#   {'hgt': '59cm',
#    'byr': '2026',
#    'cid': '245',
#    'iyr': '2020',
#    'eyr': '2029',
#    'pid': '073943129',
#    'ecl': 'hzl',
#    'hcl': '#b6652a'},
#   {'iyr': '2014',
#    'byr': '2015',
#    'hcl': '#a97842',
#    'eyr': '2029',
#    'pid': '#132098',
#    'hgt': '150',
#    'ecl': 'oth'},
#   {'hgt': '151in',
#    'ecl': '#967d49',
#    'eyr': '2026',
#    'hcl': '#18171d',
#    'pid': '384230726',
#    'byr': '1934',
#    'iyr': '2018'},
#   {'iyr': '2020',
#    'eyr': '2021',
#    'byr': '1937',
#    'pid': '735047371',
#    'cid': '159',
#    'ecl': 'blu',
#    'hgt': '177cm',
#    'hcl': '#22b774'},
#   {'ecl': 'hzl',
#    'hcl': '#6b5442',
#    'byr': '1933',
#    'iyr': '2019',
#    'pid': '348486702',
#    'eyr': '2020',
#    'hgt': '193cm'},
#   {'byr': '1928',
#    'ecl': 'gry',
#    'eyr': '2028',
#    'hcl': '#fffffd',
#    'pid': '571149069',
#    'iyr': '2012',
#    'hgt': '175cm'},
#   {'iyr': '2027',
#    'byr': '2015',
#    'hgt': '191in',
#    'pid': '102033301',
#    'ecl': 'xry',
#    'eyr': '2031',
#    'hcl': '#602927'},
#   {'ecl': 'oth',
#    'cid': '163',
#    'hcl': 'z',
#    'iyr': '2014',
#    'byr': '1944',
#    'hgt': '173cm',
#    'eyr': '2027',
#    'pid': '#0524c1'},
#   {'ecl': 'brn',
#    'byr': '2030',
#    'hgt': '71cm',
#    'eyr': '1931',
#    'cid': '165',
#    'iyr': '2010',
#    'hcl': '#cfa07d',
#    'pid': '509642098'},
#   {'ecl': 'amb',
#    'eyr': '2023',
#    'byr': '1924',
#    'pid': '901038027',
#    'hgt': '70in',
#    'iyr': '2010',
#    'hcl': 'z'},
#   {'hgt': '71',
#    'hcl': '#fffffd',
#    'byr': '1976',
#    'cid': '108',
#    'eyr': '2038',
#    'ecl': 'grt',
#    'iyr': '2018',
#    'pid': '190cm'},
#   {'iyr': '2017',
#    'byr': '1963',
#    'ecl': 'grn',
#    'hgt': '175cm',
#    'pid': '160915270',
#    'eyr': '2028',
#    'hcl': '#cfa07d'},
#   {'pid': '569740130',
#    'hgt': '171cm',
#    'hcl': '#733820',
#    'ecl': 'gry',
#    'eyr': '2024',
#    'iyr': '2020',
#    'byr': '1973'},
#   {'byr': '1937',
#    'iyr': '2016',
#    'ecl': 'gry',
#    'hgt': '181cm',
#    'pid': '521705827',
#    'hcl': '#b6652a',
#    'eyr': '2027',
#    'cid': '295'},
#   {'hgt': '156cm',
#    'ecl': 'blu',
#    'iyr': '2019',
#    'hcl': '#866857',
#    'pid': '662418718',
#    'byr': '2000',
#    'eyr': '2024'},
#   {'byr': '1971',
#    'pid': '693616099',
#    'hcl': '#efcc98',
#    'hgt': '175cm',
#    'iyr': '2016',
#    'ecl': 'gry',
#    'eyr': '2023'},
#   {'iyr': '2013',
#    'eyr': '2024',
#    'ecl': 'gry',
#    'pid': '414295491',
#    'byr': '1986',
#    'hgt': '188cm',
#    'hcl': '#b6652a'},
#   {'eyr': '2022',
#    'byr': '1975',
#    'iyr': '2020',
#    'ecl': 'grn',
#    'cid': '68',
#    'hcl': '#a97842',
#    'hgt': '151cm',
#    'pid': '229803943'},
#   {'cid': '258',
#    'iyr': '2012',
#    'ecl': 'hzl',
#    'byr': '2001',
#    'eyr': '2021',
#    'hcl': '#866857',
#    'pid': '990590217',
#    'hgt': '172cm'},
#   {'cid': '339',
#    'byr': '1957',
#    'hcl': '#866857',
#    'pid': '343480061',
#    'eyr': '2039',
#    'hgt': '191cm',
#    'iyr': '2021',
#    'ecl': 'utc'},
#   {'hcl': '#602927',
#    'byr': '1933',
#    'eyr': '2028',
#    'hgt': '165cm',
#    'ecl': 'gry',
#    'iyr': '2018',
#    'pid': '658484617'},
#   {'ecl': 'oth',
#    'hgt': '188cm',
#    'cid': '110',
#    'pid': '056975690',
#    'iyr': '2016',
#    'byr': '1950',
#    'eyr': '2023',
#    'hcl': '#cfa07d'},
#   {'cid': '342',
#    'hcl': '#fffffd',
#    'eyr': '2024',
#    'pid': '153555359',
#    'byr': '1974',
#    'ecl': 'gry',
#    'hgt': '191cm',
#    'iyr': '2020'},
#   {'iyr': '2015',
#    'eyr': '2030',
#    'hgt': '191cm',
#    'byr': '1979',
#    'ecl': '#ec4873',
#    'pid': '994113786',
#    'hcl': '#cfa07d'},
#   {'pid': '552331609',
#    'ecl': 'grn',
#    'hgt': '171cm',
#    'eyr': '2022',
#    'hcl': '#b6652a',
#    'iyr': '2020',
#    'byr': '1931'},
#   {'hgt': '177cm',
#    'iyr': '2010',
#    'pid': '934058099',
#    'eyr': '2020',
#    'ecl': 'blu',
#    'byr': '1967',
#    'cid': '112',
#    'hcl': '#7d3b0c'},
#   {'eyr': '2020',
#    'iyr': '2019',
#    'hcl': '#a97842',
#    'pid': '149148750',
#    'ecl': 'brn',
#    'hgt': '159cm',
#    'byr': '1981',
#    'cid': '339'},
#   {'cid': '344',
#    'eyr': '2021',
#    'byr': '1968',
#    'pid': '777786047',
#    'ecl': 'grn',
#    'hgt': '192cm',
#    'hcl': '#888785',
#    'iyr': '2015'},
#   {'hgt': '173cm',
#    'eyr': '2030',
#    'hcl': '#733820',
#    'pid': '610226642',
#    'byr': '1954',
#    'cid': '80',
#    'iyr': '2013',
#    'ecl': 'blu'},
#   {'byr': '1999',
#    'eyr': '2023',
#    'ecl': 'amb',
#    'pid': '912145128',
#    'hgt': '181cm',
#    'iyr': '2015',
#    'hcl': '#a97842'},
#   {'eyr': '2027',
#    'hgt': '188cm',
#    'pid': '080715145',
#    'hcl': '#341e13',
#    'iyr': '2013',
#    'ecl': 'oth',
#    'byr': '1965'},
#   {'hgt': '170cm',
#    'byr': '1950',
#    'iyr': '2013',
#    'pid': '010541784',
#    'eyr': '2027',
#    'ecl': 'zzz',
#    'hcl': 'a3bae8'},
#   {'hgt': '190cm',
#    'eyr': '2024',
#    'ecl': '#6dcedc',
#    'pid': '909319684',
#    'iyr': '2011',
#    'byr': '1959',
#    'hcl': 'z',
#    'cid': '182'},
#   {'eyr': '2028',
#    'iyr': '2016',
#    'hcl': '#623a2f',
#    'pid': '208417572',
#    'byr': '1929',
#    'cid': '137',
#    'ecl': 'hzl',
#    'hgt': '167cm'},
#   {'hcl': '#6b5442',
#    'ecl': 'grn',
#    'byr': '1938',
#    'eyr': '2023',
#    'cid': '307',
#    'hgt': '59in',
#    'iyr': '2014',
#    'pid': '205268145'},
#   {'pid': '047489285',
#    'eyr': '2026',
#    'hcl': '#b6652a',
#    'byr': '1920',
#    'iyr': '2015',
#    'hgt': '183cm',
#    'ecl': 'gry'},
#   {'ecl': 'blu',
#    'hcl': '#508e8b',
#    'iyr': '2016',
#    'eyr': '1954',
#    'hgt': '151cm',
#    'pid': '086752750',
#    'byr': '1920'},
#   {'iyr': '2011',
#    'byr': '1981',
#    'hgt': '186cm',
#    'cid': '117',
#    'hcl': '#6b5442',
#    'ecl': 'amb',
#    'pid': '756830713',
#    'eyr': '2026'},
#   {'eyr': '2037',
#    'pid': '364464758',
#    'hcl': 'z',
#    'ecl': 'grn',
#    'hgt': '112',
#    'iyr': '2013',
#    'byr': '2022'},
#   {'ecl': 'hzl',
#    'cid': '65',
#    'pid': '679487194',
#    'byr': '1986',
#    'hgt': '169cm',
#    'hcl': '#cfa07d',
#    'eyr': '2025',
#    'iyr': '2013'},
#   {'cid': '192',
#    'byr': '1921',
#    'pid': '#5fe831',
#    'ecl': '#fbb2b9',
#    'hgt': '62cm',
#    'eyr': '1971',
#    'iyr': '2024',
#    'hcl': 'z'},
#   {'hcl': '#cfa07d',
#    'eyr': '2026',
#    'hgt': '74in',
#    'iyr': '2019',
#    'ecl': 'xry',
#    'pid': '622690982',
#    'byr': '1982'},
#   {'eyr': '2026',
#    'pid': '523515724',
#    'iyr': '2013',
#    'byr': '1973',
#    'hgt': '167cm',
#    'ecl': 'grn',
#    'hcl': '#866857'},
#   {'byr': '2009',
#    'eyr': '1985',
#    'pid': '484497014',
#    'ecl': '#0bfcf2',
#    'iyr': '1992',
#    'cid': '131',
#    'hcl': '39d6b0',
#    'hgt': '177in'},
#   {'eyr': '2020',
#    'iyr': '2016',
#    'ecl': 'brn',
#    'hcl': '#ceb3a1',
#    'byr': '1966',
#    'pid': '696621560',
#    'cid': '62',
#    'hgt': '59in'},
#   {'hgt': '166cm',
#    'hcl': '#7d3b0c',
#    'iyr': '2016',
#    'ecl': 'brn',
#    'pid': '190cm',
#    'eyr': '2020',
#    'byr': '2001'},
#   {'eyr': '2021',
#    'iyr': '2012',
#    'hcl': '#6b5442',
#    'ecl': 'amb',
#    'hgt': '169cm',
#    'pid': '969150085',
#    'byr': '1925'},
#   {'ecl': 'brn',
#    'hgt': '175cm',
#    'byr': '1992',
#    'iyr': '2016',
#    'pid': '415209726',
#    'eyr': '2027',
#    'cid': '72',
#    'hcl': '#866857'},
#   {'hcl': '4f5dd1',
#    'cid': '336',
#    'ecl': 'grn',
#    'iyr': '1931',
#    'pid': '6212280197',
#    'byr': '2016',
#    'eyr': '2037',
#    'hgt': '187in'},
#   {'iyr': '2017',
#    'byr': '1940',
#    'eyr': '2025',
#    'pid': '115098205',
#    'hgt': '151cm',
#    'ecl': 'grn',
#    'cid': '122',
#    'hcl': '#6b5442'},
#   {'hcl': '#efcc98',
#    'iyr': '2020',
#    'pid': '709548547',
#    'hgt': '179cm',
#    'eyr': '2030',
#    'ecl': 'gry',
#    'byr': '1975'},
#   {'cid': '217',
#    'hcl': '#888785',
#    'eyr': '2029',
#    'ecl': 'hzl',
#    'iyr': '2013',
#    'pid': '160053490',
#    'hgt': '166cm',
#    'byr': '1992'},
#   {'hgt': '154cm',
#    'iyr': '2010',
#    'ecl': 'blu',
#    'pid': '717041634',
#    'byr': '1928',
#    'cid': '123',
#    'eyr': '2027',
#    'hcl': '#a97842'},
#   {'hgt': '179cm',
#    'pid': '065528723',
#    'hcl': '#888785',
#    'byr': '1937',
#    'eyr': '2028',
#    'iyr': '2013',
#    'ecl': 'hzl'},
#   {'iyr': '2027',
#    'cid': '261',
#    'eyr': '2037',
#    'ecl': '#ced7d5',
#    'pid': '157cm',
#    'hcl': '3a80c1',
#    'byr': '2029',
#    'hgt': '187in'},
#   {'eyr': '2028',
#    'hgt': '157cm',
#    'hcl': '#733820',
#    'iyr': '2012',
#    'ecl': 'blu',
#    'byr': '1952',
#    'pid': '915063263',
#    'cid': '335'},
#   {'eyr': '2023',
#    'hcl': '#efcc98',
#    'pid': '490625944',
#    'byr': '1961',
#    'ecl': 'grn',
#    'hgt': '155cm',
#    'iyr': '2018'},
#   {'cid': '247',
#    'pid': '2807544665',
#    'eyr': '2021',
#    'ecl': 'oth',
#    'hgt': '191cm',
#    'byr': '1928',
#    'iyr': '2013',
#    'hcl': '#623a2f'},
#   {'hgt': '175cm',
#    'eyr': '1992',
#    'cid': '328',
#    'pid': '263110997',
#    'ecl': '#e53989',
#    'byr': '2014',
#    'hcl': '#a97842',
#    'iyr': '2026'},
#   {'pid': '491396731',
#    'eyr': '2027',
#    'hgt': '172cm',
#    'hcl': '#623a2f',
#    'cid': '92',
#    'iyr': '2017',
#    'byr': '1983',
#    'ecl': 'grn'},
#   {'hcl': '#fffffd',
#    'iyr': '2018',
#    'byr': '1983',
#    'pid': '714591144',
#    'ecl': 'grn',
#    'eyr': '2021',
#    'hgt': '160cm'},
#   {'eyr': '2027',
#    'hgt': '63in',
#    'ecl': 'blu',
#    'byr': '1987',
#    'pid': '397963077',
#    'iyr': '2018',
#    'hcl': '#ceb3a1'},
#   {'eyr': '2027',
#    'hgt': '184cm',
#    'hcl': '#6b5442',
#    'iyr': '2012',
#    'byr': '1984',
#    'ecl': 'blu',
#    'pid': '196287205'},
#   {'iyr': '1998',
#    'ecl': 'hzl',
#    'pid': '7872103596',
#    'byr': '1991',
#    'cid': '275',
#    'eyr': '2039',
#    'hgt': '174cm',
#    'hcl': '0d2ad6'},
#   {'iyr': '2010',
#    'hcl': '#efcc98',
#    'byr': '1992',
#    'hgt': '65cm',
#    'eyr': '2038',
#    'pid': '383236012',
#    'cid': '68',
#    'ecl': 'lzr'},
#   {'hgt': '190in',
#    'cid': '127',
#    'byr': '1947',
#    'pid': '515728209',
#    'hcl': '#733820',
#    'iyr': '2014',
#    'ecl': 'amb',
#    'eyr': '2020'},
#   {'iyr': '2017',
#    'eyr': '2028',
#    'hcl': '#623a2f',
#    'byr': '1964',
#    'ecl': 'grn',
#    'pid': '198467794',
#    'hgt': '169cm'},
#   {'ecl': 'utc',
#    'hgt': '59cm',
#    'byr': '2007',
#    'iyr': '2030',
#    'hcl': '7ac4db',
#    'eyr': '2038',
#    'pid': '#7206c6'},
#   {'iyr': '2010',
#    'hcl': 'z',
#    'eyr': '2021',
#    'ecl': 'brn',
#    'hgt': '173',
#    'cid': '86',
#    'pid': '194240791',
#    'byr': '1975'},
#   {'pid': '9347286034',
#    'hgt': '63cm',
#    'iyr': '1992',
#    'eyr': '2034',
#    'hcl': '66031b',
#    'ecl': 'grt',
#    'byr': '1929'},
#   {'pid': '593398904',
#    'byr': '1939',
#    'iyr': '2019',
#    'hcl': '#b6652a',
#    'ecl': 'gry',
#    'eyr': '2023',
#    'hgt': '70cm'},
#   {'byr': '1991',
#    'iyr': '2019',
#    'hgt': '164cm',
#    'pid': '282852411',
#    'cid': '340',
#    'ecl': 'amb',
#    'hcl': '#341e13',
#    'eyr': '2027'},
#   {'eyr': '2020',
#    'iyr': '2014',
#    'ecl': 'grn',
#    'hcl': '#866857',
#    'hgt': '158cm',
#    'byr': '1931',
#    'pid': '321748597'},
#   {'cid': '98',
#    'byr': '2023',
#    'iyr': '2019',
#    'pid': '#48f79f',
#    'hcl': '73c882',
#    'eyr': '1973',
#    'hgt': '151in',
#    'ecl': 'utc'},
#   {'iyr': '2023',
#    'hcl': '#18171d',
#    'pid': '52221892',
#    'eyr': '2039',
#    'byr': '2008',
#    'hgt': '72cm',
#    'ecl': '#db8d14'},
#   {'hcl': '#fd033b',
#    'eyr': '2026',
#    'ecl': 'blu',
#    'iyr': '2016',
#    'byr': '1953',
#    'hgt': '157cm',
#    'pid': '502619036'},
#   {'byr': '2015',
#    'pid': '159cm',
#    'iyr': '2025',
#    'hgt': '158cm',
#    'eyr': '1943',
#    'hcl': 'z',
#    'ecl': 'grn'},
#   {'ecl': 'blu',
#    'iyr': '2016',
#    'pid': '842400950',
#    'hcl': '#733820',
#    'cid': '266',
#    'eyr': '2027',
#    'byr': '1931',
#    'hgt': '161cm'},
#   {'cid': '197',
#    'pid': '204952666',
#    'ecl': 'amb',
#    'hgt': '70in',
#    'iyr': '2016',
#    'byr': '1936',
#    'hcl': '#98cbe3',
#    'eyr': '2025'},
#   {'ecl': 'hzl',
#    'iyr': '2014',
#    'pid': '30428184',
#    'cid': '237',
#    'hgt': '171cm',
#    'byr': '1942',
#    'hcl': '#888785',
#    'eyr': '1986'},
#   {'eyr': '2025',
#    'pid': '579385370',
#    'hgt': '193cm',
#    'hcl': '#c0946f',
#    'byr': '1979',
#    'iyr': '2016',
#    'ecl': 'amb',
#    'cid': '284'},
#   {'eyr': '2029',
#    'byr': '1946',
#    'pid': '278271295',
#    'ecl': 'grn',
#    'hcl': '#cfa07d',
#    'cid': '271',
#    'hgt': '172cm',
#    'iyr': '2020'},
#   {'pid': '731752614',
#    'eyr': '2020',
#    'byr': '1983',
#    'cid': '248',
#    'ecl': 'oth',
#    'hgt': '179cm',
#    'iyr': '2017',
#    'hcl': '#fffffd'},
#   {'hcl': 'z',
#    'cid': '203',
#    'eyr': '2032',
#    'ecl': '#3f9d3d',
#    'hgt': '65cm',
#    'pid': '4042846885',
#    'byr': '2019',
#    'iyr': '1946'},
#   {'hgt': '171cm',
#    'ecl': 'gry',
#    'eyr': '2027',
#    'iyr': '2013',
#    'hcl': '#7d3b0c',
#    'pid': '92288579',
#    'byr': '1955'},
#   {'ecl': 'brn',
#    'hgt': '164cm',
#    'byr': '1969',
#    'hcl': '#cbf9c9',
#    'pid': '022724981',
#    'eyr': '2030',
#    'iyr': '2013',
#    'cid': '244'},
#   {'hgt': '162cm',
#    'byr': '1974',
#    'iyr': '2015',
#    'pid': '927525094',
#    'hcl': '#3d3011',
#    'ecl': 'blu',
#    'eyr': '2023'},
#   {'hgt': '157cm',
#    'eyr': '2020',
#    'pid': '221286943',
#    'hcl': '#fffffd',
#    'ecl': 'amb',
#    'iyr': '2018',
#    'byr': '1945'},
#   {'pid': '138492032',
#    'hcl': 'e35302',
#    'ecl': '#caaede',
#    'eyr': '1931',
#    'byr': '2001',
#    'hgt': '156',
#    'iyr': '1998'},
#   {'pid': '912182030',
#    'cid': '189',
#    'hgt': '162',
#    'hcl': '#277b39',
#    'iyr': '2013',
#    'eyr': '2023',
#    'byr': '2023',
#    'ecl': 'blu'},
#   {'eyr': '2027',
#    'hcl': '#fffffd',
#    'ecl': 'brn',
#    'cid': '304',
#    'iyr': '2016',
#    'byr': '1969',
#    'pid': '866607511',
#    'hgt': '192cm'},
#   {'hgt': '64in',
#    'ecl': 'amb',
#    'byr': '1958',
#    'pid': '720439412',
#    'iyr': '2015',
#    'eyr': '2022',
#    'hcl': '#ceb3a1'},
#   {'eyr': '2024',
#    'hgt': '159cm',
#    'pid': '187867283',
#    'iyr': '2016',
#    'ecl': 'oth',
#    'hcl': '#fffffd',
#    'byr': '1988'},
#   {'ecl': '#910bf2',
#    'byr': '1969',
#    'iyr': '2011',
#    'hcl': 'z',
#    'eyr': '2024',
#    'pid': '579502502',
#    'cid': '103',
#    'hgt': '174cm'},
#   {'pid': '718692455',
#    'eyr': '2028',
#    'iyr': '2016',
#    'hcl': '#602927',
#    'ecl': 'blu',
#    'byr': '1954',
#    'cid': '251',
#    'hgt': '182cm'},
#   {'eyr': '2021',
#    'hcl': '#341e13',
#    'ecl': 'amb',
#    'byr': '1933',
#    'hgt': '179cm',
#    'iyr': '2011',
#    'pid': '083172316'},
#   {'iyr': '1998',
#    'hcl': 'z',
#    'eyr': '1944',
#    'byr': '2006',
#    'pid': '453368738',
#    'hgt': '160',
#    'ecl': '#9da5f1',
#    'cid': '261'},
#   {'pid': '993701676',
#    'eyr': '2028',
#    'ecl': 'gry',
#    'byr': '1951',
#    'hcl': '#888785',
#    'cid': '116',
#    'iyr': '2020',
#    'hgt': '192cm'},
#   {'hcl': 'z',
#    'eyr': '2033',
#    'ecl': 'lzr',
#    'iyr': '2029',
#    'cid': '326',
#    'hgt': '68cm',
#    'byr': '2026',
#    'pid': '96742419'},
#   {'hcl': '#a97842',
#    'ecl': 'brn',
#    'byr': '1920',
#    'hgt': '173cm',
#    'iyr': '2015',
#    'eyr': '2024',
#    'pid': '176967666'},
#   {'byr': '1930',
#    'eyr': '2025',
#    'pid': '792694131',
#    'hgt': '179cm',
#    'ecl': 'brn',
#    'hcl': '#a97842',
#    'iyr': '2015'},
#   {'hgt': '167cm',
#    'byr': '1960',
#    'eyr': '2022',
#    'hcl': '#efcc98',
#    'cid': '87',
#    'ecl': 'blu',
#    'iyr': '2012',
#    'pid': '431515059'},
#   {'hcl': '#cfa07d',
#    'eyr': '2023',
#    'hgt': '188cm',
#    'ecl': 'grn',
#    'pid': '081575957',
#    'byr': '1938',
#    'iyr': '2012'},
#   {'iyr': '2010',
#    'byr': '1973',
#    'cid': '108',
#    'eyr': '2026',
#    'pid': '880191154',
#    'hcl': '#888785',
#    'hgt': '181cm',
#    'ecl': 'brn'},
#   {'eyr': '2021',
#    'iyr': '2010',
#    'byr': '1942',
#    'hcl': '#7d3b0c',
#    'ecl': 'hzl',
#    'pid': '886241926',
#    'hgt': '171cm'},
#   {'cid': '53',
#    'byr': '1993',
#    'pid': '150cm',
#    'eyr': '2035',
#    'hcl': '#888785',
#    'hgt': '153cm',
#    'ecl': '#128262',
#    'iyr': '2021'},
#   {'ecl': 'gry',
#    'pid': '555911148',
#    'hcl': '#733820',
#    'eyr': '2022',
#    'hgt': '154cm',
#    'iyr': '2012',
#    'byr': '1935',
#    'cid': '338'},
#   {'eyr': '2024',
#    'ecl': 'blu',
#    'byr': '1955',
#    'hcl': '#b6652a',
#    'pid': '517975316',
#    'iyr': '2010',
#    'hgt': '166cm'},
#   {'pid': '133785752',
#    'ecl': 'blu',
#    'eyr': '2024',
#    'byr': '1973',
#    'iyr': '2019',
#    'hcl': '#fffffd',
#    'cid': '236',
#    'hgt': '173cm'},
#   {'cid': '222',
#    'byr': '2013',
#    'hcl': 'z',
#    'eyr': '2036',
#    'pid': '7443967478',
#    'ecl': 'brn',
#    'iyr': '2030',
#    'hgt': '62cm'},
#   {'hgt': '193cm',
#    'cid': '259',
#    'hcl': '#18171d',
#    'ecl': 'grn',
#    'byr': '1995',
#    'pid': '727880050',
#    'eyr': '2030',
#    'iyr': '2010'},
#   {'hcl': '#c0946f',
#    'cid': '275',
#    'eyr': '1954',
#    'pid': '772184635',
#    'ecl': '#76add7',
#    'byr': '2009',
#    'iyr': '2018',
#    'hgt': '151cm'},
#   {'ecl': '#52ed0f',
#    'eyr': '2033',
#    'hcl': '#18171d',
#    'pid': '475397948',
#    'byr': '1946',
#    'iyr': '2028',
#    'hgt': '178cm'},
#   {'iyr': '2012',
#    'hgt': '152cm',
#    'eyr': '2027',
#    'byr': '1923',
#    'ecl': 'brn',
#    'hcl': '#18171d',
#    'pid': '513722888',
#    'cid': '171'},
#   {'iyr': '2029',
#    'hgt': '111',
#    'hcl': 'z',
#    'ecl': '#33e3bc',
#    'eyr': '1930',
#    'byr': '1934',
#    'pid': '94036732'},
#   {'hgt': '154cm',
#    'eyr': '2024',
#    'hcl': '#6b5442',
#    'iyr': '2017',
#    'byr': '1974',
#    'ecl': 'amb',
#    'pid': '470968353',
#    'cid': '345'},
#   {'hgt': '184cm',
#    'hcl': '#617375',
#    'eyr': '2028',
#    'byr': '1975',
#    'ecl': 'oth',
#    'iyr': '2018',
#    'pid': '735589126'},
#   {'hcl': '#623a2f',
#    'ecl': '#34964b',
#    'eyr': '2009',
#    'pid': '169cm',
#    'byr': '2028',
#    'hgt': '169cm',
#    'iyr': '2028'},
#   {'eyr': '2029',
#    'iyr': '2016',
#    'byr': '1985',
#    'hgt': '192cm',
#    'hcl': '#602927',
#    'cid': '167',
#    'ecl': 'blu',
#    'pid': '620818510'},
#   {'eyr': '2029',
#    'byr': '1968',
#    'ecl': 'blu',
#    'hgt': '183cm',
#    'iyr': '2011',
#    'pid': '952376140',
#    'hcl': '#efcc98'},
#   {'iyr': '2020',
#    'byr': '1981',
#    'pid': '850136149',
#    'eyr': '2028',
#    'hgt': '159cm',
#    'hcl': '#7d3b0c',
#    'ecl': 'brn'},
#   {'ecl': 'brn',
#    'pid': '480452858',
#    'hgt': '65in',
#    'cid': '340',
#    'eyr': '2022',
#    'byr': '1946',
#    'hcl': '#602927',
#    'iyr': '2015'},
#   {'hgt': '172',
#    'hcl': 'z',
#    'eyr': '1958',
#    'iyr': '1941',
#    'byr': '2019',
#    'pid': '389995951',
#    'ecl': 'dne'},
#   {'byr': '2025',
#    'hcl': '4c8dcd',
#    'hgt': '177in',
#    'ecl': '#55d635',
#    'cid': '197',
#    'pid': '91192572',
#    'iyr': '1921',
#    'eyr': '2038'},
#   {'iyr': '2027',
#    'pid': '154cm',
#    'hgt': '185in',
#    'byr': '2012',
#    'eyr': '2036',
#    'hcl': 'efd47d',
#    'ecl': '#64f98d',
#    'cid': '86'},
#   {'eyr': '2029',
#    'pid': '837224515',
#    'ecl': 'grn',
#    'cid': '231',
#    'hcl': '#733820',
#    'iyr': '2019',
#    'hgt': '159cm',
#    'byr': '1977'},
#   {'pid': '974518338',
#    'byr': '1964',
#    'hcl': '#cfa07d',
#    'ecl': 'grn',
#    'eyr': '2030',
#    'hgt': '61in',
#    'iyr': '2019'},
#   {'iyr': '2019',
#    'hgt': '192in',
#    'cid': '94',
#    'eyr': '1922',
#    'byr': '1925',
#    'hcl': 'z',
#    'ecl': 'utc',
#    'pid': '#081266'},
#   {'eyr': '2027',
#    'iyr': '2019',
#    'cid': '328',
#    'byr': '1961',
#    'hcl': '#6b5442',
#    'ecl': 'blu',
#    'hgt': '177cm',
#    'pid': '235426720'},
#   {'hgt': '161cm',
#    'iyr': '2018',
#    'pid': '916160791',
#    'ecl': 'grn',
#    'byr': '1951',
#    'hcl': '#44d03a',
#    'eyr': '2025'},
#   {'hgt': '158cm',
#    'byr': '1942',
#    'iyr': '2012',
#    'hcl': '#602927',
#    'eyr': '2026',
#    'ecl': 'gry',
#    'pid': '651231060'},
#   {'ecl': 'hzl',
#    'cid': '340',
#    'pid': '086942161',
#    'byr': '1986',
#    'hcl': '#a97842',
#    'iyr': '2018',
#    'eyr': '2028',
#    'hgt': '181cm'},
#   {'ecl': 'blu',
#    'pid': '278922687',
#    'cid': '238',
#    'iyr': '2018',
#    'hgt': '153cm',
#    'eyr': '2027',
#    'byr': '1965',
#    'hcl': '#733820'},
#   {'eyr': '2023',
#    'cid': '208',
#    'hgt': '178cm',
#    'hcl': '#341e13',
#    'byr': '1937',
#    'pid': '290981079',
#    'iyr': '2010',
#    'ecl': 'grn'},
#   {'hcl': '#888785',
#    'ecl': 'amb',
#    'byr': '1943',
#    'pid': '559804716',
#    'eyr': '2026',
#    'hgt': '166cm',
#    'iyr': '2019'},
#   {'pid': '947831563',
#    'ecl': 'gry',
#    'byr': '1960',
#    'hcl': '#341e13',
#    'iyr': '2016',
#    'hgt': '173cm',
#    'eyr': '2029'},
#   {'ecl': 'blu',
#    'iyr': '2016',
#    'pid': '724632073',
#    'hcl': '#623a2f',
#    'eyr': '2028',
#    'hgt': '192cm',
#    'byr': '1958'},
#   {'byr': '2021',
#    'eyr': '2016',
#    'hcl': 'z',
#    'iyr': '1988',
#    'pid': '65353943',
#    'ecl': '#bb553b',
#    'hgt': '125'},
#   {'hcl': '#efcc98',
#    'byr': '1963',
#    'pid': '290433211',
#    'eyr': '2023',
#    'ecl': 'hzl',
#    'hgt': '172cm',
#    'iyr': '2013'},
#   {'iyr': '2015',
#    'ecl': 'brn',
#    'byr': '2023',
#    'hcl': '#18171d',
#    'pid': '325330679',
#    'hgt': '190in',
#    'eyr': '2023'},
#   {'pid': '745674970',
#    'hgt': '160cm',
#    'eyr': '2021',
#    'byr': '1925',
#    'ecl': 'gry',
#    'hcl': '#341e13',
#    'iyr': '2015',
#    'cid': '297'},
#   {'eyr': '2021',
#    'pid': '596411633',
#    'byr': '1947',
#    'ecl': 'blu',
#    'cid': '191',
#    'hcl': '#341e13',
#    'hgt': '168cm',
#    'iyr': '2019'},
#   {'eyr': '2030',
#    'pid': '#902a6b',
#    'iyr': '1997',
#    'hcl': '11f396',
#    'hgt': '188cm',
#    'byr': '2025',
#    'ecl': 'dne'},
#   {'eyr': '2025',
#    'byr': '2006',
#    'hcl': '#888785',
#    'ecl': 'hzl',
#    'hgt': '187cm',
#    'iyr': '2012',
#    'pid': '017702828'},
#   {'byr': '1988',
#    'hcl': '#18171d',
#    'iyr': '2019',
#    'pid': '110591871',
#    'ecl': 'hzl',
#    'hgt': '160cm',
#    'eyr': '2029'},
#   {'ecl': 'brn',
#    'hcl': '#c0946f',
#    'iyr': '2030',
#    'pid': '264404022',
#    'byr': '1984',
#    'hgt': '59cm',
#    'eyr': '2040'},
#   {'pid': '5973803069',
#    'hcl': '#cfa07d',
#    'ecl': 'grt',
#    'hgt': '153cm',
#    'eyr': '2039',
#    'byr': '1970',
#    'iyr': '2025'},
#   {'hcl': '#fffffd',
#    'iyr': '2022',
#    'byr': '2026',
#    'hgt': '180',
#    'pid': '82035145',
#    'eyr': '2034',
#    'cid': '118',
#    'ecl': 'utc'},
#   {'hgt': '186cm',
#    'eyr': '2026',
#    'ecl': 'brn',
#    'iyr': '2013',
#    'hcl': '#8f4c9b',
#    'pid': '010260339',
#    'byr': '1948'},
#   {'ecl': 'amb',
#    'hcl': '#18171d',
#    'iyr': '2020',
#    'pid': '259501214',
#    'byr': '1978',
#    'hgt': '193cm',
#    'cid': '263',
#    'eyr': '2022'},
#   {'hgt': '161cm',
#    'iyr': '2015',
#    'byr': '2014',
#    'eyr': '2003',
#    'pid': '708958872',
#    'ecl': 'grt',
#    'hcl': 'f4a430'},
#   {'hgt': '170cm',
#    'eyr': '2021',
#    'pid': '911638274',
#    'cid': '110',
#    'byr': '1963',
#    'ecl': 'blu',
#    'iyr': '2015',
#    'hcl': '1eda64'},
#   {'ecl': 'oth',
#    'byr': '1949',
#    'hgt': '174cm',
#    'hcl': '#18171d',
#    'eyr': '2022',
#    'iyr': '2019',
#    'pid': '305857230'},
#   {'ecl': 'gry',
#    'hcl': '#a97842',
#    'pid': '971971076',
#    'byr': '2002',
#    'iyr': '2019',
#    'hgt': '188cm',
#    'eyr': '2022',
#    'cid': '238'},
#   {'eyr': '2027',
#    'pid': '221315043',
#    'iyr': '2010',
#    'hgt': '159cm',
#    'ecl': 'blu',
#    'byr': '1998',
#    'hcl': '#6b5442'},
#   {'hcl': '#888785',
#    'byr': '1926',
#    'eyr': '2022',
#    'pid': '433807814',
#    'ecl': 'grn',
#    'iyr': '2010',
#    'hgt': '181cm'},
#   {'ecl': 'grn',
#    'hgt': '164cm',
#    'byr': '1951',
#    'hcl': '#18171d',
#    'cid': '75',
#    'pid': '845508281',
#    'eyr': '2021',
#    'iyr': '2017'},
#   {'hcl': '#623a2f',
#    'pid': '497429747',
#    'hgt': '189cm',
#    'byr': '1987',
#    'eyr': '2027',
#    'iyr': '2012',
#    'cid': '95',
#    'ecl': 'hzl'},
#   {'byr': '2000',
#    'hgt': '165cm',
#    'iyr': '2017',
#    'pid': '519443292',
#    'eyr': '2029',
#    'cid': '240',
#    'hcl': '#a97842',
#    'ecl': 'blu'},
#   {'cid': '67',
#    'pid': '038299774',
#    'eyr': '2023',
#    'iyr': '2015',
#    'hgt': '179cm',
#    'byr': '1941',
#    'hcl': '#18171d',
#    'ecl': 'amb'},
#   {'byr': '2000',
#    'eyr': '2025',
#    'ecl': 'oth',
#    'iyr': '2017',
#    'pid': '334154607',
#    'hcl': '#fffffd',
#    'hgt': '173cm'},
#   {'hcl': '#888785',
#    'ecl': 'amb',
#    'cid': '131',
#    'iyr': '2018',
#    'byr': '1996',
#    'eyr': '2026',
#    'hgt': '180cm',
#    'pid': '709543988'},
#   {'iyr': '1988',
#    'pid': '263277424',
#    'hcl': 'ee8912',
#    'byr': '1942',
#    'ecl': 'gry',
#    'eyr': '2040',
#    'hgt': '161cm'},
#   {'eyr': '2020',
#    'byr': '1966',
#    'iyr': '2020',
#    'hgt': '169cm',
#    'pid': '611918000',
#    'hcl': '#7d3b0c',
#    'ecl': 'hzl'},
#   {'hgt': '164cm',
#    'ecl': 'brn',
#    'iyr': '2015',
#    'pid': '192054454',
#    'hcl': '#6b5442',
#    'byr': '1987',
#    'eyr': '2022'},
#   {'byr': '1952',
#    'ecl': 'zzz',
#    'pid': '215953654',
#    'eyr': '2021',
#    'hcl': '#efcc98',
#    'hgt': '153cm',
#    'iyr': '2026'},
#   {'hgt': '167cm',
#    'hcl': '#b6652a',
#    'pid': '847614726',
#    'eyr': '2022',
#    'ecl': 'gry',
#    'byr': '1990',
#    'iyr': '2015'},
#   {'pid': '613273980',
#    'hcl': '#a97842',
#    'ecl': 'oth',
#    'byr': '1924',
#    'hgt': '179cm',
#    'eyr': '2027',
#    'iyr': '1950'},
#   {'hcl': 'z',
#    'hgt': '70cm',
#    'pid': '18807747',
#    'cid': '284',
#    'byr': '2023',
#    'eyr': '2035',
#    'ecl': '#4a1501',
#    'iyr': '1954'},
#   {'iyr': '2016',
#    'hgt': '152cm',
#    'pid': '886247173',
#    'byr': '1940',
#    'hcl': '#c0946f',
#    'eyr': '2027',
#    'ecl': 'oth',
#    'cid': '150'},
#   {'hgt': '152cm',
#    'hcl': '#48cfdf',
#    'eyr': '2025',
#    'cid': '277',
#    'ecl': 'oth',
#    'pid': '246230621',
#    'byr': '1932',
#    'iyr': '2020'},
#   {'ecl': 'amb',
#    'pid': '871180042',
#    'cid': '117',
#    'hcl': '#602927',
#    'iyr': '2011',
#    'hgt': '152cm',
#    'eyr': '2030',
#    'byr': '1999'},
#   {'eyr': '2024',
#    'ecl': 'hzl',
#    'hgt': '171cm',
#    'byr': '1934',
#    'pid': '356408125',
#    'iyr': '2019',
#    'hcl': '#b6652a',
#    'cid': '169'},
#   {'eyr': '2023',
#    'hcl': '#7d3b0c',
#    'byr': '1934',
#    'hgt': '67in',
#    'ecl': 'oth',
#    'pid': '191785527',
#    'cid': '117',
#    'iyr': '2016'},
#   {'iyr': '2029',
#    'hcl': '#602927',
#    'eyr': '2022',
#    'byr': '1931',
#    'ecl': 'oth',
#    'hgt': '192cm',
#    'pid': '231475143'},
#   {'ecl': 'grn',
#    'iyr': '2014',
#    'cid': '250',
#    'hcl': '#b6652a',
#    'byr': '1970',
#    'pid': '675238417',
#    'hgt': '162cm',
#    'eyr': '2026'},
#   {'ecl': 'brn',
#    'hcl': '#623a2f',
#    'eyr': '2021',
#    'pid': '293293433',
#    'hgt': '158',
#    'byr': '1977',
#    'iyr': '2019'},
#   {'hgt': '61cm',
#    'eyr': '2027',
#    'ecl': 'amb',
#    'pid': '181cm',
#    'iyr': '1932',
#    'byr': '1974',
#    'hcl': '#18171d'},
#   {'byr': '1968',
#    'hgt': '167cm',
#    'hcl': '#a97842',
#    'eyr': '2022',
#    'iyr': '2018',
#    'ecl': 'hzl',
#    'pid': '940968694'},
#   {'iyr': '1943',
#    'hgt': '96',
#    'cid': '229',
#    'hcl': 'z',
#    'eyr': '1990',
#    'byr': '2007',
#    'pid': '#25aa73',
#    'ecl': '#74592e'},
#   {'hgt': '182cm',
#    'iyr': '2018',
#    'ecl': 'hzl',
#    'eyr': '2029',
#    'byr': '1946',
#    'pid': '602345030',
#    'hcl': '#ceb3a1'},
#   {'pid': '750306036',
#    'eyr': '2020',
#    'hgt': '181in',
#    'ecl': 'xry',
#    'iyr': '2011',
#    'hcl': 'z',
#    'byr': '1971',
#    'cid': '71'},
#   {'pid': '183825747',
#    'iyr': '2019',
#    'hcl': '#6b5442',
#    'byr': '1974',
#    'hgt': '180cm',
#    'eyr': '2028',
#    'ecl': 'amb'},
#   {'ecl': 'brn',
#    'cid': '200',
#    'pid': '576495225',
#    'byr': '1924',
#    'hcl': '#efcc98',
#    'eyr': '2022',
#    'iyr': '2017',
#    'hgt': '185cm'},
#   {'iyr': '2020',
#    'hgt': '167cm',
#    'byr': '1965',
#    'ecl': 'brn',
#    'hcl': '#888785',
#    'eyr': '2028',
#    'pid': '752062953'},
#   {'byr': '2026',
#    'hcl': 'z',
#    'eyr': '2020',
#    'ecl': '#b4ec74',
#    'pid': '187cm',
#    'iyr': '1974',
#    'cid': '326',
#    'hgt': '150cm'},
#   {'byr': '1996',
#    'pid': '507323629',
#    'iyr': '2015',
#    'cid': '347',
#    'eyr': '2026',
#    'hcl': '#efcc98',
#    'ecl': 'amb',
#    'hgt': '157cm'},
#   {'byr': '2017',
#    'pid': '456780590',
#    'hcl': '#888785',
#    'eyr': '1966',
#    'ecl': 'amb',
#    'iyr': '2023',
#    'cid': '187',
#    'hgt': '62cm'},
#   {'ecl': 'hzl',
#    'iyr': '2015',
#    'hcl': '#6b5442',
#    'hgt': '152cm',
#    'eyr': '2028',
#    'byr': '1982',
#    'pid': '003269467'},
#   {'iyr': '2017',
#    'eyr': '2026',
#    'ecl': 'blu',
#    'cid': '70',
#    'hcl': '#7d3b0c',
#    'byr': '1966',
#    'pid': '160330947',
#    'hgt': '189cm'},
#   {'iyr': '2010',
#    'ecl': 'amb',
#    'hgt': '164cm',
#    'eyr': '2029',
#    'byr': '1963',
#    'pid': '596606374',
#    'hcl': '#efcc98'},
#   {'hcl': '#fffffd',
#    'cid': '277',
#    'pid': '102326370',
#    'hgt': '154cm',
#    'eyr': '2026',
#    'iyr': '2012',
#    'byr': '1968',
#    'ecl': 'hzl'},
#   {'ecl': 'oth',
#    'pid': '477189554',
#    'hcl': '#6b5442',
#    'eyr': '2022',
#    'byr': '1948',
#    'hgt': '74in',
#    'cid': '181',
#    'iyr': '2016'},
#   {'hgt': '169cm',
#    'hcl': '#d7bc93',
#    'cid': '344',
#    'ecl': 'oth',
#    'pid': '#09c55d',
#    'iyr': '2017',
#    'eyr': '2030',
#    'byr': '1928'},
#   {'hcl': '5d02ff',
#    'ecl': '#ca7901',
#    'iyr': '1959',
#    'byr': '2006',
#    'eyr': '2022',
#    'hgt': '164in',
#    'pid': '#d6cdfd'},
#   {'ecl': 'amb',
#    'pid': '5739190196',
#    'eyr': '2021',
#    'hgt': '157in',
#    'hcl': '#efcc98',
#    'byr': '2018',
#    'iyr': '2028'},
#   {'byr': '1995',
#    'ecl': 'hzl',
#    'iyr': '2017',
#    'hcl': '#a97842',
#    'pid': '917039291',
#    'eyr': '2026',
#    'hgt': '175cm'},
#   {'iyr': '2017',
#    'pid': '756519868',
#    'hcl': '#623a2f',
#    'eyr': '2028',
#    'hgt': '158cm',
#    'ecl': 'amb',
#    'byr': '1957'},
#   {'iyr': '2012',
#    'hgt': '158cm',
#    'byr': '2014',
#    'pid': '973021666',
#    'hcl': 'f04766',
#    'eyr': '2035',
#    'ecl': 'utc'},
#   {'ecl': 'blu',
#    'byr': '1989',
#    'eyr': '2022',
#    'pid': '520765501',
#    'cid': '200',
#    'hgt': '193cm',
#    'hcl': '#a97842',
#    'iyr': '2011'},
#   {'byr': '1959',
#    'ecl': 'blu',
#    'hcl': '#733820',
#    'cid': '284',
#    'hgt': '162cm',
#    'eyr': '2022',
#    'pid': '751629408',
#    'iyr': '2016'},
#   {'byr': '1978',
#    'cid': '301',
#    'ecl': 'oth',
#    'hgt': '67cm',
#    'hcl': '#888785',
#    'eyr': '2040',
#    'iyr': '2025',
#    'pid': '26038514'},
#   {'hcl': '#a97842',
#    'hgt': '186cm',
#    'ecl': 'grn',
#    'byr': '1969',
#    'pid': '460360492',
#    'iyr': '2011',
#    'eyr': '2028'},
#   {'iyr': '2019',
#    'hcl': '3463cc',
#    'ecl': 'amb',
#    'pid': '4089063078',
#    'eyr': '2022',
#    'hgt': '150cm',
#    'byr': '2007'},
#   {'eyr': '2028',
#    'hcl': '#ceb3a1',
#    'hgt': '191cm',
#    'iyr': '2019',
#    'pid': '737842199',
#    'ecl': 'blu',
#    'cid': '268',
#    'byr': '1925'},
#   {'pid': '868397851',
#    'hcl': '#efcc98',
#    'ecl': 'grn',
#    'iyr': '2017',
#    'eyr': '2021',
#    'byr': '1943',
#    'hgt': '179cm'},
#   {'hcl': '#623a2f',
#    'byr': '1987',
#    'eyr': '2023',
#    'iyr': '2019',
#    'hgt': '152cm',
#    'pid': '473569020',
#    'ecl': 'grn'},
#   {'pid': '953968630',
#    'hgt': '175cm',
#    'byr': '1971',
#    'ecl': 'blu',
#    'hcl': '#623a2f',
#    'iyr': '2017',
#    'cid': '336',
#    'eyr': '2030'},
#   {'ecl': 'grt',
#    'hgt': '74cm',
#    'byr': '2022',
#    'eyr': '2024',
#    'pid': '39114027',
#    'iyr': '2026',
#    'hcl': '4b5675'},
#   {'pid': '800367032',
#    'hcl': '#341e13',
#    'ecl': '#765111',
#    'iyr': '2012',
#    'byr': '2006',
#    'hgt': '166cm',
#    'cid': '291',
#    'eyr': '2027'},
#   {'eyr': '2021',
#    'iyr': '2012',
#    'pid': '876581393',
#    'ecl': 'amb',
#    'hcl': '#866857',
#    'hgt': '64in',
#    'byr': '1993'},
#   {'iyr': '2017',
#    'byr': '1996',
#    'ecl': 'hzl',
#    'pid': '038990744',
#    'eyr': '2028',
#    'hgt': '177cm',
#    'hcl': '#c0946f'},
#   {'hcl': '#4214a6',
#    'eyr': '2021',
#    'iyr': '2019',
#    'cid': '72',
#    'byr': '1939',
#    'ecl': 'hzl',
#    'pid': '783071912',
#    'hgt': '187cm'},
#   {'eyr': '2020',
#    'hgt': '158cm',
#    'pid': '274060737',
#    'cid': '277',
#    'iyr': '2015',
#    'hcl': '#bf9b5e',
#    'byr': '1950',
#    'ecl': 'brn'},
#   {'byr': '1921',
#    'hcl': '#7d3b0c',
#    'cid': '329',
#    'hgt': '155cm',
#    'eyr': '2030',
#    'pid': '718399669',
#    'iyr': '2011',
#    'ecl': 'brn'},
#   {'cid': '147',
#    'eyr': '2021',
#    'hgt': '167cm',
#    'iyr': '2010',
#    'ecl': 'grn',
#    'byr': '1975',
#    'hcl': '#6b5442',
#    'pid': '285479783'},
#   {'hgt': '187cm',
#    'byr': '2004',
#    'eyr': '2025',
#    'hcl': 'bb331b',
#    'pid': '851189955',
#    'iyr': '2016',
#    'ecl': 'amb'},
#   {'hcl': '#94007d',
#    'pid': '361561551',
#    'byr': '1927',
#    'eyr': '2026',
#    'iyr': '2020',
#    'ecl': 'gry',
#    'hgt': '158cm'},
#   {'byr': '1993',
#    'pid': '#24c4af',
#    'iyr': '2023',
#    'hgt': '175cm',
#    'eyr': '2028',
#    'hcl': 'z',
#    'ecl': 'hzl',
#    'cid': '308'},
#   {'byr': '1985',
#    'hcl': '#c0946f',
#    'eyr': '2034',
#    'hgt': '172cm',
#    'cid': '300',
#    'iyr': '2013',
#    'ecl': 'gry',
#    'pid': '389455676'},
#   {'pid': '836559549',
#    'iyr': '2011',
#    'hgt': '167cm',
#    'ecl': 'amb',
#    'hcl': '#c0946f',
#    'eyr': '2026',
#    'byr': '1981'},
#   {'pid': '111085991',
#    'iyr': '2011',
#    'ecl': 'blu',
#    'eyr': '2026',
#    'cid': '311',
#    'byr': '1920',
#    'hgt': '182cm',
#    'hcl': '#602927'},
#   {'ecl': 'oth',
#    'pid': '284436132',
#    'byr': '1929',
#    'cid': '121',
#    'eyr': '2027',
#    'iyr': '2010',
#    'hgt': '75in',
#    'hcl': '#6b5442'},
#   {'byr': '1987',
#    'hcl': '#7d3b0c',
#    'iyr': '2018',
#    'hgt': '180cm',
#    'ecl': 'blu',
#    'eyr': '2029',
#    'pid': '878348021'},
#   {'eyr': '2030',
#    'pid': '039638764',
#    'ecl': 'hzl',
#    'hgt': '190cm',
#    'byr': '1926',
#    'cid': '294',
#    'hcl': '#b6652a',
#    'iyr': '2017'}]}

# %%
v = results['valids']
len(v)
# Out:
# 250

# %%
byrs = []
iyrs = []
eyrs = []
pids = []

for p in v:
    byrs.append(p['byr'])
    iyrs.append(p['iyr'])
    eyrs.append(p['eyr'])
    pids.append(len(p['pid']))

print('byr:')
print(min(byrs))
print(max(byrs))
print('')

print('iyr:')
print(min(iyrs))
print(max(iyrs))
print('')

print('eyr:')
print(min(eyrs))
print(max(eyrs))
print('')

print('pid:')
print(min(pids))
print(max(pids))
print('')
# Out:
# byr:
# 1920
# 2030
#
# iyr:
# 1921
# 2030
#
# eyr:
# 1921
# 2040
#
# pid:
# 5
# 10

# %%
v = [i for i in v if i]
len(v)
# Out:
# 250

# %%
v
# Out:
# [{'eyr': '2024',
#   'pid': '662406624',
#   'hcl': '#cfa07d',
#   'byr': '1947',
#   'iyr': '2015',
#   'ecl': 'amb',
#   'hgt': '150cm'},
#  {'iyr': '2013',
#   'byr': '1997',
#   'hgt': '182cm',
#   'hcl': '#ceb3a1',
#   'eyr': '2027',
#   'ecl': 'gry',
#   'cid': '102',
#   'pid': '018128535'},
#  {'hcl': '#a97842',
#   'eyr': '2026',
#   'byr': '1980',
#   'ecl': 'grn',
#   'pid': '726519569',
#   'hgt': '184cm',
#   'cid': '132',
#   'iyr': '2011'},
#  {'ecl': 'grn',
#   'hcl': '#6b5442',
#   'pid': '619743219',
#   'cid': '69',
#   'hgt': '176cm',
#   'eyr': '2027',
#   'iyr': '2012',
#   'byr': '1980'},
#  {'ecl': 'brn',
#   'byr': '1969',
#   'iyr': '2014',
#   'hgt': '164cm',
#   'eyr': '2020',
#   'pid': '982796633',
#   'hcl': '#602927'},
#  {'cid': '117',
#   'hcl': '#efcc98',
#   'iyr': '2010',
#   'pid': '322719183',
#   'hgt': '176cm',
#   'eyr': '2020',
#   'byr': '1957',
#   'ecl': 'brn'},
#  {'byr': '1954',
#   'hgt': '178cm',
#   'hcl': '#38f7fd',
#   'pid': '838813262',
#   'ecl': 'blu',
#   'eyr': '2029',
#   'iyr': '2019'},
#  {'eyr': '2023',
#   'ecl': 'amb',
#   'iyr': '2020',
#   'byr': '1927',
#   'pid': '242570886',
#   'hcl': '#18171d',
#   'hgt': '192cm'},
#  {'iyr': '1990',
#   'cid': '295',
#   'hgt': '131',
#   'pid': '187cm',
#   'byr': '2014',
#   'ecl': 'xry',
#   'hcl': 'z',
#   'eyr': '1928'},
#  {'ecl': 'hzl',
#   'byr': '1953',
#   'eyr': '2023',
#   'hcl': '#866857',
#   'hgt': '181cm',
#   'iyr': '2010',
#   'pid': '568185567'},
#  {'byr': '2030',
#   'hcl': '#fffffd',
#   'ecl': '#a4a596',
#   'hgt': '168cm',
#   'iyr': '1936',
#   'eyr': '2020',
#   'cid': '296',
#   'pid': '168786676'},
#  {'byr': '2030',
#   'iyr': '2026',
#   'eyr': '1974',
#   'hcl': '7fcaa5',
#   'ecl': 'utc',
#   'pid': '190cm',
#   'hgt': '67cm'},
#  {'byr': '2023',
#   'eyr': '2037',
#   'hgt': '59cm',
#   'ecl': 'lzr',
#   'hcl': 'z',
#   'iyr': '2026',
#   'pid': '#ea9083'},
#  {'byr': '2003',
#   'hcl': 'z',
#   'hgt': '91',
#   'iyr': '1990',
#   'eyr': '2024',
#   'ecl': '#123d73',
#   'pid': '48494230'},
#  {'byr': '2022',
#   'eyr': '2020',
#   'iyr': '2030',
#   'ecl': 'gmt',
#   'hgt': '191cm',
#   'pid': '3509331253',
#   'hcl': '#888785'},
#  {'iyr': '1994',
#   'ecl': '#c3d564',
#   'byr': '2009',
#   'hgt': '162cm',
#   'hcl': '336498',
#   'pid': '#e99d09',
#   'cid': '288',
#   'eyr': '1921'},
#  {'byr': '1924',
#   'cid': '290',
#   'iyr': '2010',
#   'ecl': 'amb',
#   'eyr': '2020',
#   'hgt': '156cm',
#   'hcl': '#7d3b0c',
#   'pid': '795497164'},
#  {'cid': '301',
#   'iyr': '2017',
#   'hgt': '67cm',
#   'hcl': '#888785',
#   'ecl': '#0405b9',
#   'byr': '1964',
#   'pid': '707857518',
#   'eyr': '1976'},
#  {'ecl': 'gry',
#   'pid': '474303066',
#   'iyr': '2011',
#   'hcl': '#18171d',
#   'hgt': '165cm',
#   'byr': '1921',
#   'eyr': '2024'},
#  {'hcl': '#6b5442',
#   'ecl': 'amb',
#   'iyr': '2020',
#   'hgt': '191cm',
#   'byr': '1949',
#   'cid': '301',
#   'pid': '075846582',
#   'eyr': '2029'},
#  {'hcl': '#a97842',
#   'cid': '186',
#   'iyr': '2014',
#   'ecl': 'gry',
#   'hgt': '191cm',
#   'eyr': '2023',
#   'pid': '645548969',
#   'byr': '1956'},
#  {'hgt': '72cm',
#   'byr': '2023',
#   'eyr': '2034',
#   'hcl': 'z',
#   'ecl': '#f5249e',
#   'iyr': '1997',
#   'pid': '#79af7a'},
#  {'eyr': '2038',
#   'byr': '2015',
#   'hgt': '70cm',
#   'ecl': 'grt',
#   'hcl': '9d58a1',
#   'iyr': '1926',
#   'pid': '6290928420'},
#  {'pid': '620857794',
#   'eyr': '2022',
#   'byr': '1950',
#   'hgt': '159cm',
#   'hcl': '#ceb3a1',
#   'ecl': 'amb',
#   'iyr': '2015'},
#  {'eyr': '1954',
#   'ecl': '#ab2ce4',
#   'pid': '#14eedd',
#   'iyr': '2009',
#   'hcl': '29e484',
#   'byr': '2022',
#   'hgt': '73cm'},
#  {'hgt': '59cm',
#   'byr': '2026',
#   'cid': '245',
#   'iyr': '2020',
#   'eyr': '2029',
#   'pid': '073943129',
#   'ecl': 'hzl',
#   'hcl': '#b6652a'},
#  {'iyr': '2014',
#   'byr': '2015',
#   'hcl': '#a97842',
#   'eyr': '2029',
#   'pid': '#132098',
#   'hgt': '150',
#   'ecl': 'oth'},
#  {'hgt': '151in',
#   'ecl': '#967d49',
#   'eyr': '2026',
#   'hcl': '#18171d',
#   'pid': '384230726',
#   'byr': '1934',
#   'iyr': '2018'},
#  {'iyr': '2020',
#   'eyr': '2021',
#   'byr': '1937',
#   'pid': '735047371',
#   'cid': '159',
#   'ecl': 'blu',
#   'hgt': '177cm',
#   'hcl': '#22b774'},
#  {'ecl': 'hzl',
#   'hcl': '#6b5442',
#   'byr': '1933',
#   'iyr': '2019',
#   'pid': '348486702',
#   'eyr': '2020',
#   'hgt': '193cm'},
#  {'byr': '1928',
#   'ecl': 'gry',
#   'eyr': '2028',
#   'hcl': '#fffffd',
#   'pid': '571149069',
#   'iyr': '2012',
#   'hgt': '175cm'},
#  {'iyr': '2027',
#   'byr': '2015',
#   'hgt': '191in',
#   'pid': '102033301',
#   'ecl': 'xry',
#   'eyr': '2031',
#   'hcl': '#602927'},
#  {'ecl': 'oth',
#   'cid': '163',
#   'hcl': 'z',
#   'iyr': '2014',
#   'byr': '1944',
#   'hgt': '173cm',
#   'eyr': '2027',
#   'pid': '#0524c1'},
#  {'ecl': 'brn',
#   'byr': '2030',
#   'hgt': '71cm',
#   'eyr': '1931',
#   'cid': '165',
#   'iyr': '2010',
#   'hcl': '#cfa07d',
#   'pid': '509642098'},
#  {'ecl': 'amb',
#   'eyr': '2023',
#   'byr': '1924',
#   'pid': '901038027',
#   'hgt': '70in',
#   'iyr': '2010',
#   'hcl': 'z'},
#  {'hgt': '71',
#   'hcl': '#fffffd',
#   'byr': '1976',
#   'cid': '108',
#   'eyr': '2038',
#   'ecl': 'grt',
#   'iyr': '2018',
#   'pid': '190cm'},
#  {'iyr': '2017',
#   'byr': '1963',
#   'ecl': 'grn',
#   'hgt': '175cm',
#   'pid': '160915270',
#   'eyr': '2028',
#   'hcl': '#cfa07d'},
#  {'pid': '569740130',
#   'hgt': '171cm',
#   'hcl': '#733820',
#   'ecl': 'gry',
#   'eyr': '2024',
#   'iyr': '2020',
#   'byr': '1973'},
#  {'byr': '1937',
#   'iyr': '2016',
#   'ecl': 'gry',
#   'hgt': '181cm',
#   'pid': '521705827',
#   'hcl': '#b6652a',
#   'eyr': '2027',
#   'cid': '295'},
#  {'hgt': '156cm',
#   'ecl': 'blu',
#   'iyr': '2019',
#   'hcl': '#866857',
#   'pid': '662418718',
#   'byr': '2000',
#   'eyr': '2024'},
#  {'byr': '1971',
#   'pid': '693616099',
#   'hcl': '#efcc98',
#   'hgt': '175cm',
#   'iyr': '2016',
#   'ecl': 'gry',
#   'eyr': '2023'},
#  {'iyr': '2013',
#   'eyr': '2024',
#   'ecl': 'gry',
#   'pid': '414295491',
#   'byr': '1986',
#   'hgt': '188cm',
#   'hcl': '#b6652a'},
#  {'eyr': '2022',
#   'byr': '1975',
#   'iyr': '2020',
#   'ecl': 'grn',
#   'cid': '68',
#   'hcl': '#a97842',
#   'hgt': '151cm',
#   'pid': '229803943'},
#  {'cid': '258',
#   'iyr': '2012',
#   'ecl': 'hzl',
#   'byr': '2001',
#   'eyr': '2021',
#   'hcl': '#866857',
#   'pid': '990590217',
#   'hgt': '172cm'},
#  {'cid': '339',
#   'byr': '1957',
#   'hcl': '#866857',
#   'pid': '343480061',
#   'eyr': '2039',
#   'hgt': '191cm',
#   'iyr': '2021',
#   'ecl': 'utc'},
#  {'hcl': '#602927',
#   'byr': '1933',
#   'eyr': '2028',
#   'hgt': '165cm',
#   'ecl': 'gry',
#   'iyr': '2018',
#   'pid': '658484617'},
#  {'ecl': 'oth',
#   'hgt': '188cm',
#   'cid': '110',
#   'pid': '056975690',
#   'iyr': '2016',
#   'byr': '1950',
#   'eyr': '2023',
#   'hcl': '#cfa07d'},
#  {'cid': '342',
#   'hcl': '#fffffd',
#   'eyr': '2024',
#   'pid': '153555359',
#   'byr': '1974',
#   'ecl': 'gry',
#   'hgt': '191cm',
#   'iyr': '2020'},
#  {'iyr': '2015',
#   'eyr': '2030',
#   'hgt': '191cm',
#   'byr': '1979',
#   'ecl': '#ec4873',
#   'pid': '994113786',
#   'hcl': '#cfa07d'},
#  {'pid': '552331609',
#   'ecl': 'grn',
#   'hgt': '171cm',
#   'eyr': '2022',
#   'hcl': '#b6652a',
#   'iyr': '2020',
#   'byr': '1931'},
#  {'hgt': '177cm',
#   'iyr': '2010',
#   'pid': '934058099',
#   'eyr': '2020',
#   'ecl': 'blu',
#   'byr': '1967',
#   'cid': '112',
#   'hcl': '#7d3b0c'},
#  {'eyr': '2020',
#   'iyr': '2019',
#   'hcl': '#a97842',
#   'pid': '149148750',
#   'ecl': 'brn',
#   'hgt': '159cm',
#   'byr': '1981',
#   'cid': '339'},
#  {'cid': '344',
#   'eyr': '2021',
#   'byr': '1968',
#   'pid': '777786047',
#   'ecl': 'grn',
#   'hgt': '192cm',
#   'hcl': '#888785',
#   'iyr': '2015'},
#  {'hgt': '173cm',
#   'eyr': '2030',
#   'hcl': '#733820',
#   'pid': '610226642',
#   'byr': '1954',
#   'cid': '80',
#   'iyr': '2013',
#   'ecl': 'blu'},
#  {'byr': '1999',
#   'eyr': '2023',
#   'ecl': 'amb',
#   'pid': '912145128',
#   'hgt': '181cm',
#   'iyr': '2015',
#   'hcl': '#a97842'},
#  {'eyr': '2027',
#   'hgt': '188cm',
#   'pid': '080715145',
#   'hcl': '#341e13',
#   'iyr': '2013',
#   'ecl': 'oth',
#   'byr': '1965'},
#  {'hgt': '170cm',
#   'byr': '1950',
#   'iyr': '2013',
#   'pid': '010541784',
#   'eyr': '2027',
#   'ecl': 'zzz',
#   'hcl': 'a3bae8'},
#  {'hgt': '190cm',
#   'eyr': '2024',
#   'ecl': '#6dcedc',
#   'pid': '909319684',
#   'iyr': '2011',
#   'byr': '1959',
#   'hcl': 'z',
#   'cid': '182'},
#  {'eyr': '2028',
#   'iyr': '2016',
#   'hcl': '#623a2f',
#   'pid': '208417572',
#   'byr': '1929',
#   'cid': '137',
#   'ecl': 'hzl',
#   'hgt': '167cm'},
#  {'hcl': '#6b5442',
#   'ecl': 'grn',
#   'byr': '1938',
#   'eyr': '2023',
#   'cid': '307',
#   'hgt': '59in',
#   'iyr': '2014',
#   'pid': '205268145'},
#  {'pid': '047489285',
#   'eyr': '2026',
#   'hcl': '#b6652a',
#   'byr': '1920',
#   'iyr': '2015',
#   'hgt': '183cm',
#   'ecl': 'gry'},
#  {'ecl': 'blu',
#   'hcl': '#508e8b',
#   'iyr': '2016',
#   'eyr': '1954',
#   'hgt': '151cm',
#   'pid': '086752750',
#   'byr': '1920'},
#  {'iyr': '2011',
#   'byr': '1981',
#   'hgt': '186cm',
#   'cid': '117',
#   'hcl': '#6b5442',
#   'ecl': 'amb',
#   'pid': '756830713',
#   'eyr': '2026'},
#  {'eyr': '2037',
#   'pid': '364464758',
#   'hcl': 'z',
#   'ecl': 'grn',
#   'hgt': '112',
#   'iyr': '2013',
#   'byr': '2022'},
#  {'ecl': 'hzl',
#   'cid': '65',
#   'pid': '679487194',
#   'byr': '1986',
#   'hgt': '169cm',
#   'hcl': '#cfa07d',
#   'eyr': '2025',
#   'iyr': '2013'},
#  {'cid': '192',
#   'byr': '1921',
#   'pid': '#5fe831',
#   'ecl': '#fbb2b9',
#   'hgt': '62cm',
#   'eyr': '1971',
#   'iyr': '2024',
#   'hcl': 'z'},
#  {'hcl': '#cfa07d',
#   'eyr': '2026',
#   'hgt': '74in',
#   'iyr': '2019',
#   'ecl': 'xry',
#   'pid': '622690982',
#   'byr': '1982'},
#  {'eyr': '2026',
#   'pid': '523515724',
#   'iyr': '2013',
#   'byr': '1973',
#   'hgt': '167cm',
#   'ecl': 'grn',
#   'hcl': '#866857'},
#  {'byr': '2009',
#   'eyr': '1985',
#   'pid': '484497014',
#   'ecl': '#0bfcf2',
#   'iyr': '1992',
#   'cid': '131',
#   'hcl': '39d6b0',
#   'hgt': '177in'},
#  {'eyr': '2020',
#   'iyr': '2016',
#   'ecl': 'brn',
#   'hcl': '#ceb3a1',
#   'byr': '1966',
#   'pid': '696621560',
#   'cid': '62',
#   'hgt': '59in'},
#  {'hgt': '166cm',
#   'hcl': '#7d3b0c',
#   'iyr': '2016',
#   'ecl': 'brn',
#   'pid': '190cm',
#   'eyr': '2020',
#   'byr': '2001'},
#  {'eyr': '2021',
#   'iyr': '2012',
#   'hcl': '#6b5442',
#   'ecl': 'amb',
#   'hgt': '169cm',
#   'pid': '969150085',
#   'byr': '1925'},
#  {'ecl': 'brn',
#   'hgt': '175cm',
#   'byr': '1992',
#   'iyr': '2016',
#   'pid': '415209726',
#   'eyr': '2027',
#   'cid': '72',
#   'hcl': '#866857'},
#  {'hcl': '4f5dd1',
#   'cid': '336',
#   'ecl': 'grn',
#   'iyr': '1931',
#   'pid': '6212280197',
#   'byr': '2016',
#   'eyr': '2037',
#   'hgt': '187in'},
#  {'iyr': '2017',
#   'byr': '1940',
#   'eyr': '2025',
#   'pid': '115098205',
#   'hgt': '151cm',
#   'ecl': 'grn',
#   'cid': '122',
#   'hcl': '#6b5442'},
#  {'hcl': '#efcc98',
#   'iyr': '2020',
#   'pid': '709548547',
#   'hgt': '179cm',
#   'eyr': '2030',
#   'ecl': 'gry',
#   'byr': '1975'},
#  {'cid': '217',
#   'hcl': '#888785',
#   'eyr': '2029',
#   'ecl': 'hzl',
#   'iyr': '2013',
#   'pid': '160053490',
#   'hgt': '166cm',
#   'byr': '1992'},
#  {'hgt': '154cm',
#   'iyr': '2010',
#   'ecl': 'blu',
#   'pid': '717041634',
#   'byr': '1928',
#   'cid': '123',
#   'eyr': '2027',
#   'hcl': '#a97842'},
#  {'hgt': '179cm',
#   'pid': '065528723',
#   'hcl': '#888785',
#   'byr': '1937',
#   'eyr': '2028',
#   'iyr': '2013',
#   'ecl': 'hzl'},
#  {'iyr': '2027',
#   'cid': '261',
#   'eyr': '2037',
#   'ecl': '#ced7d5',
#   'pid': '157cm',
#   'hcl': '3a80c1',
#   'byr': '2029',
#   'hgt': '187in'},
#  {'eyr': '2028',
#   'hgt': '157cm',
#   'hcl': '#733820',
#   'iyr': '2012',
#   'ecl': 'blu',
#   'byr': '1952',
#   'pid': '915063263',
#   'cid': '335'},
#  {'eyr': '2023',
#   'hcl': '#efcc98',
#   'pid': '490625944',
#   'byr': '1961',
#   'ecl': 'grn',
#   'hgt': '155cm',
#   'iyr': '2018'},
#  {'cid': '247',
#   'pid': '2807544665',
#   'eyr': '2021',
#   'ecl': 'oth',
#   'hgt': '191cm',
#   'byr': '1928',
#   'iyr': '2013',
#   'hcl': '#623a2f'},
#  {'hgt': '175cm',
#   'eyr': '1992',
#   'cid': '328',
#   'pid': '263110997',
#   'ecl': '#e53989',
#   'byr': '2014',
#   'hcl': '#a97842',
#   'iyr': '2026'},
#  {'pid': '491396731',
#   'eyr': '2027',
#   'hgt': '172cm',
#   'hcl': '#623a2f',
#   'cid': '92',
#   'iyr': '2017',
#   'byr': '1983',
#   'ecl': 'grn'},
#  {'hcl': '#fffffd',
#   'iyr': '2018',
#   'byr': '1983',
#   'pid': '714591144',
#   'ecl': 'grn',
#   'eyr': '2021',
#   'hgt': '160cm'},
#  {'eyr': '2027',
#   'hgt': '63in',
#   'ecl': 'blu',
#   'byr': '1987',
#   'pid': '397963077',
#   'iyr': '2018',
#   'hcl': '#ceb3a1'},
#  {'eyr': '2027',
#   'hgt': '184cm',
#   'hcl': '#6b5442',
#   'iyr': '2012',
#   'byr': '1984',
#   'ecl': 'blu',
#   'pid': '196287205'},
#  {'iyr': '1998',
#   'ecl': 'hzl',
#   'pid': '7872103596',
#   'byr': '1991',
#   'cid': '275',
#   'eyr': '2039',
#   'hgt': '174cm',
#   'hcl': '0d2ad6'},
#  {'iyr': '2010',
#   'hcl': '#efcc98',
#   'byr': '1992',
#   'hgt': '65cm',
#   'eyr': '2038',
#   'pid': '383236012',
#   'cid': '68',
#   'ecl': 'lzr'},
#  {'hgt': '190in',
#   'cid': '127',
#   'byr': '1947',
#   'pid': '515728209',
#   'hcl': '#733820',
#   'iyr': '2014',
#   'ecl': 'amb',
#   'eyr': '2020'},
#  {'iyr': '2017',
#   'eyr': '2028',
#   'hcl': '#623a2f',
#   'byr': '1964',
#   'ecl': 'grn',
#   'pid': '198467794',
#   'hgt': '169cm'},
#  {'ecl': 'utc',
#   'hgt': '59cm',
#   'byr': '2007',
#   'iyr': '2030',
#   'hcl': '7ac4db',
#   'eyr': '2038',
#   'pid': '#7206c6'},
#  {'iyr': '2010',
#   'hcl': 'z',
#   'eyr': '2021',
#   'ecl': 'brn',
#   'hgt': '173',
#   'cid': '86',
#   'pid': '194240791',
#   'byr': '1975'},
#  {'pid': '9347286034',
#   'hgt': '63cm',
#   'iyr': '1992',
#   'eyr': '2034',
#   'hcl': '66031b',
#   'ecl': 'grt',
#   'byr': '1929'},
#  {'pid': '593398904',
#   'byr': '1939',
#   'iyr': '2019',
#   'hcl': '#b6652a',
#   'ecl': 'gry',
#   'eyr': '2023',
#   'hgt': '70cm'},
#  {'byr': '1991',
#   'iyr': '2019',
#   'hgt': '164cm',
#   'pid': '282852411',
#   'cid': '340',
#   'ecl': 'amb',
#   'hcl': '#341e13',
#   'eyr': '2027'},
#  {'eyr': '2020',
#   'iyr': '2014',
#   'ecl': 'grn',
#   'hcl': '#866857',
#   'hgt': '158cm',
#   'byr': '1931',
#   'pid': '321748597'},
#  {'cid': '98',
#   'byr': '2023',
#   'iyr': '2019',
#   'pid': '#48f79f',
#   'hcl': '73c882',
#   'eyr': '1973',
#   'hgt': '151in',
#   'ecl': 'utc'},
#  {'iyr': '2023',
#   'hcl': '#18171d',
#   'pid': '52221892',
#   'eyr': '2039',
#   'byr': '2008',
#   'hgt': '72cm',
#   'ecl': '#db8d14'},
#  {'hcl': '#fd033b',
#   'eyr': '2026',
#   'ecl': 'blu',
#   'iyr': '2016',
#   'byr': '1953',
#   'hgt': '157cm',
#   'pid': '502619036'},
#  {'byr': '2015',
#   'pid': '159cm',
#   'iyr': '2025',
#   'hgt': '158cm',
#   'eyr': '1943',
#   'hcl': 'z',
#   'ecl': 'grn'},
#  {'ecl': 'blu',
#   'iyr': '2016',
#   'pid': '842400950',
#   'hcl': '#733820',
#   'cid': '266',
#   'eyr': '2027',
#   'byr': '1931',
#   'hgt': '161cm'},
#  {'cid': '197',
#   'pid': '204952666',
#   'ecl': 'amb',
#   'hgt': '70in',
#   'iyr': '2016',
#   'byr': '1936',
#   'hcl': '#98cbe3',
#   'eyr': '2025'},
#  {'ecl': 'hzl',
#   'iyr': '2014',
#   'pid': '30428184',
#   'cid': '237',
#   'hgt': '171cm',
#   'byr': '1942',
#   'hcl': '#888785',
#   'eyr': '1986'},
#  {'eyr': '2025',
#   'pid': '579385370',
#   'hgt': '193cm',
#   'hcl': '#c0946f',
#   'byr': '1979',
#   'iyr': '2016',
#   'ecl': 'amb',
#   'cid': '284'},
#  {'eyr': '2029',
#   'byr': '1946',
#   'pid': '278271295',
#   'ecl': 'grn',
#   'hcl': '#cfa07d',
#   'cid': '271',
#   'hgt': '172cm',
#   'iyr': '2020'},
#  {'pid': '731752614',
#   'eyr': '2020',
#   'byr': '1983',
#   'cid': '248',
#   'ecl': 'oth',
#   'hgt': '179cm',
#   'iyr': '2017',
#   'hcl': '#fffffd'},
#  {'hcl': 'z',
#   'cid': '203',
#   'eyr': '2032',
#   'ecl': '#3f9d3d',
#   'hgt': '65cm',
#   'pid': '4042846885',
#   'byr': '2019',
#   'iyr': '1946'},
#  {'hgt': '171cm',
#   'ecl': 'gry',
#   'eyr': '2027',
#   'iyr': '2013',
#   'hcl': '#7d3b0c',
#   'pid': '92288579',
#   'byr': '1955'},
#  {'ecl': 'brn',
#   'hgt': '164cm',
#   'byr': '1969',
#   'hcl': '#cbf9c9',
#   'pid': '022724981',
#   'eyr': '2030',
#   'iyr': '2013',
#   'cid': '244'},
#  {'hgt': '162cm',
#   'byr': '1974',
#   'iyr': '2015',
#   'pid': '927525094',
#   'hcl': '#3d3011',
#   'ecl': 'blu',
#   'eyr': '2023'},
#  {'hgt': '157cm',
#   'eyr': '2020',
#   'pid': '221286943',
#   'hcl': '#fffffd',
#   'ecl': 'amb',
#   'iyr': '2018',
#   'byr': '1945'},
#  {'pid': '138492032',
#   'hcl': 'e35302',
#   'ecl': '#caaede',
#   'eyr': '1931',
#   'byr': '2001',
#   'hgt': '156',
#   'iyr': '1998'},
#  {'pid': '912182030',
#   'cid': '189',
#   'hgt': '162',
#   'hcl': '#277b39',
#   'iyr': '2013',
#   'eyr': '2023',
#   'byr': '2023',
#   'ecl': 'blu'},
#  {'eyr': '2027',
#   'hcl': '#fffffd',
#   'ecl': 'brn',
#   'cid': '304',
#   'iyr': '2016',
#   'byr': '1969',
#   'pid': '866607511',
#   'hgt': '192cm'},
#  {'hgt': '64in',
#   'ecl': 'amb',
#   'byr': '1958',
#   'pid': '720439412',
#   'iyr': '2015',
#   'eyr': '2022',
#   'hcl': '#ceb3a1'},
#  {'eyr': '2024',
#   'hgt': '159cm',
#   'pid': '187867283',
#   'iyr': '2016',
#   'ecl': 'oth',
#   'hcl': '#fffffd',
#   'byr': '1988'},
#  {'ecl': '#910bf2',
#   'byr': '1969',
#   'iyr': '2011',
#   'hcl': 'z',
#   'eyr': '2024',
#   'pid': '579502502',
#   'cid': '103',
#   'hgt': '174cm'},
#  {'pid': '718692455',
#   'eyr': '2028',
#   'iyr': '2016',
#   'hcl': '#602927',
#   'ecl': 'blu',
#   'byr': '1954',
#   'cid': '251',
#   'hgt': '182cm'},
#  {'eyr': '2021',
#   'hcl': '#341e13',
#   'ecl': 'amb',
#   'byr': '1933',
#   'hgt': '179cm',
#   'iyr': '2011',
#   'pid': '083172316'},
#  {'iyr': '1998',
#   'hcl': 'z',
#   'eyr': '1944',
#   'byr': '2006',
#   'pid': '453368738',
#   'hgt': '160',
#   'ecl': '#9da5f1',
#   'cid': '261'},
#  {'pid': '993701676',
#   'eyr': '2028',
#   'ecl': 'gry',
#   'byr': '1951',
#   'hcl': '#888785',
#   'cid': '116',
#   'iyr': '2020',
#   'hgt': '192cm'},
#  {'hcl': 'z',
#   'eyr': '2033',
#   'ecl': 'lzr',
#   'iyr': '2029',
#   'cid': '326',
#   'hgt': '68cm',
#   'byr': '2026',
#   'pid': '96742419'},
#  {'hcl': '#a97842',
#   'ecl': 'brn',
#   'byr': '1920',
#   'hgt': '173cm',
#   'iyr': '2015',
#   'eyr': '2024',
#   'pid': '176967666'},
#  {'byr': '1930',
#   'eyr': '2025',
#   'pid': '792694131',
#   'hgt': '179cm',
#   'ecl': 'brn',
#   'hcl': '#a97842',
#   'iyr': '2015'},
#  {'hgt': '167cm',
#   'byr': '1960',
#   'eyr': '2022',
#   'hcl': '#efcc98',
#   'cid': '87',
#   'ecl': 'blu',
#   'iyr': '2012',
#   'pid': '431515059'},
#  {'hcl': '#cfa07d',
#   'eyr': '2023',
#   'hgt': '188cm',
#   'ecl': 'grn',
#   'pid': '081575957',
#   'byr': '1938',
#   'iyr': '2012'},
#  {'iyr': '2010',
#   'byr': '1973',
#   'cid': '108',
#   'eyr': '2026',
#   'pid': '880191154',
#   'hcl': '#888785',
#   'hgt': '181cm',
#   'ecl': 'brn'},
#  {'eyr': '2021',
#   'iyr': '2010',
#   'byr': '1942',
#   'hcl': '#7d3b0c',
#   'ecl': 'hzl',
#   'pid': '886241926',
#   'hgt': '171cm'},
#  {'cid': '53',
#   'byr': '1993',
#   'pid': '150cm',
#   'eyr': '2035',
#   'hcl': '#888785',
#   'hgt': '153cm',
#   'ecl': '#128262',
#   'iyr': '2021'},
#  {'ecl': 'gry',
#   'pid': '555911148',
#   'hcl': '#733820',
#   'eyr': '2022',
#   'hgt': '154cm',
#   'iyr': '2012',
#   'byr': '1935',
#   'cid': '338'},
#  {'eyr': '2024',
#   'ecl': 'blu',
#   'byr': '1955',
#   'hcl': '#b6652a',
#   'pid': '517975316',
#   'iyr': '2010',
#   'hgt': '166cm'},
#  {'pid': '133785752',
#   'ecl': 'blu',
#   'eyr': '2024',
#   'byr': '1973',
#   'iyr': '2019',
#   'hcl': '#fffffd',
#   'cid': '236',
#   'hgt': '173cm'},
#  {'cid': '222',
#   'byr': '2013',
#   'hcl': 'z',
#   'eyr': '2036',
#   'pid': '7443967478',
#   'ecl': 'brn',
#   'iyr': '2030',
#   'hgt': '62cm'},
#  {'hgt': '193cm',
#   'cid': '259',
#   'hcl': '#18171d',
#   'ecl': 'grn',
#   'byr': '1995',
#   'pid': '727880050',
#   'eyr': '2030',
#   'iyr': '2010'},
#  {'hcl': '#c0946f',
#   'cid': '275',
#   'eyr': '1954',
#   'pid': '772184635',
#   'ecl': '#76add7',
#   'byr': '2009',
#   'iyr': '2018',
#   'hgt': '151cm'},
#  {'ecl': '#52ed0f',
#   'eyr': '2033',
#   'hcl': '#18171d',
#   'pid': '475397948',
#   'byr': '1946',
#   'iyr': '2028',
#   'hgt': '178cm'},
#  {'iyr': '2012',
#   'hgt': '152cm',
#   'eyr': '2027',
#   'byr': '1923',
#   'ecl': 'brn',
#   'hcl': '#18171d',
#   'pid': '513722888',
#   'cid': '171'},
#  {'iyr': '2029',
#   'hgt': '111',
#   'hcl': 'z',
#   'ecl': '#33e3bc',
#   'eyr': '1930',
#   'byr': '1934',
#   'pid': '94036732'},
#  {'hgt': '154cm',
#   'eyr': '2024',
#   'hcl': '#6b5442',
#   'iyr': '2017',
#   'byr': '1974',
#   'ecl': 'amb',
#   'pid': '470968353',
#   'cid': '345'},
#  {'hgt': '184cm',
#   'hcl': '#617375',
#   'eyr': '2028',
#   'byr': '1975',
#   'ecl': 'oth',
#   'iyr': '2018',
#   'pid': '735589126'},
#  {'hcl': '#623a2f',
#   'ecl': '#34964b',
#   'eyr': '2009',
#   'pid': '169cm',
#   'byr': '2028',
#   'hgt': '169cm',
#   'iyr': '2028'},
#  {'eyr': '2029',
#   'iyr': '2016',
#   'byr': '1985',
#   'hgt': '192cm',
#   'hcl': '#602927',
#   'cid': '167',
#   'ecl': 'blu',
#   'pid': '620818510'},
#  {'eyr': '2029',
#   'byr': '1968',
#   'ecl': 'blu',
#   'hgt': '183cm',
#   'iyr': '2011',
#   'pid': '952376140',
#   'hcl': '#efcc98'},
#  {'iyr': '2020',
#   'byr': '1981',
#   'pid': '850136149',
#   'eyr': '2028',
#   'hgt': '159cm',
#   'hcl': '#7d3b0c',
#   'ecl': 'brn'},
#  {'ecl': 'brn',
#   'pid': '480452858',
#   'hgt': '65in',
#   'cid': '340',
#   'eyr': '2022',
#   'byr': '1946',
#   'hcl': '#602927',
#   'iyr': '2015'},
#  {'hgt': '172',
#   'hcl': 'z',
#   'eyr': '1958',
#   'iyr': '1941',
#   'byr': '2019',
#   'pid': '389995951',
#   'ecl': 'dne'},
#  {'byr': '2025',
#   'hcl': '4c8dcd',
#   'hgt': '177in',
#   'ecl': '#55d635',
#   'cid': '197',
#   'pid': '91192572',
#   'iyr': '1921',
#   'eyr': '2038'},
#  {'iyr': '2027',
#   'pid': '154cm',
#   'hgt': '185in',
#   'byr': '2012',
#   'eyr': '2036',
#   'hcl': 'efd47d',
#   'ecl': '#64f98d',
#   'cid': '86'},
#  {'eyr': '2029',
#   'pid': '837224515',
#   'ecl': 'grn',
#   'cid': '231',
#   'hcl': '#733820',
#   'iyr': '2019',
#   'hgt': '159cm',
#   'byr': '1977'},
#  {'pid': '974518338',
#   'byr': '1964',
#   'hcl': '#cfa07d',
#   'ecl': 'grn',
#   'eyr': '2030',
#   'hgt': '61in',
#   'iyr': '2019'},
#  {'iyr': '2019',
#   'hgt': '192in',
#   'cid': '94',
#   'eyr': '1922',
#   'byr': '1925',
#   'hcl': 'z',
#   'ecl': 'utc',
#   'pid': '#081266'},
#  {'eyr': '2027',
#   'iyr': '2019',
#   'cid': '328',
#   'byr': '1961',
#   'hcl': '#6b5442',
#   'ecl': 'blu',
#   'hgt': '177cm',
#   'pid': '235426720'},
#  {'hgt': '161cm',
#   'iyr': '2018',
#   'pid': '916160791',
#   'ecl': 'grn',
#   'byr': '1951',
#   'hcl': '#44d03a',
#   'eyr': '2025'},
#  {'hgt': '158cm',
#   'byr': '1942',
#   'iyr': '2012',
#   'hcl': '#602927',
#   'eyr': '2026',
#   'ecl': 'gry',
#   'pid': '651231060'},
#  {'ecl': 'hzl',
#   'cid': '340',
#   'pid': '086942161',
#   'byr': '1986',
#   'hcl': '#a97842',
#   'iyr': '2018',
#   'eyr': '2028',
#   'hgt': '181cm'},
#  {'ecl': 'blu',
#   'pid': '278922687',
#   'cid': '238',
#   'iyr': '2018',
#   'hgt': '153cm',
#   'eyr': '2027',
#   'byr': '1965',
#   'hcl': '#733820'},
#  {'eyr': '2023',
#   'cid': '208',
#   'hgt': '178cm',
#   'hcl': '#341e13',
#   'byr': '1937',
#   'pid': '290981079',
#   'iyr': '2010',
#   'ecl': 'grn'},
#  {'hcl': '#888785',
#   'ecl': 'amb',
#   'byr': '1943',
#   'pid': '559804716',
#   'eyr': '2026',
#   'hgt': '166cm',
#   'iyr': '2019'},
#  {'pid': '947831563',
#   'ecl': 'gry',
#   'byr': '1960',
#   'hcl': '#341e13',
#   'iyr': '2016',
#   'hgt': '173cm',
#   'eyr': '2029'},
#  {'ecl': 'blu',
#   'iyr': '2016',
#   'pid': '724632073',
#   'hcl': '#623a2f',
#   'eyr': '2028',
#   'hgt': '192cm',
#   'byr': '1958'},
#  {'byr': '2021',
#   'eyr': '2016',
#   'hcl': 'z',
#   'iyr': '1988',
#   'pid': '65353943',
#   'ecl': '#bb553b',
#   'hgt': '125'},
#  {'hcl': '#efcc98',
#   'byr': '1963',
#   'pid': '290433211',
#   'eyr': '2023',
#   'ecl': 'hzl',
#   'hgt': '172cm',
#   'iyr': '2013'},
#  {'iyr': '2015',
#   'ecl': 'brn',
#   'byr': '2023',
#   'hcl': '#18171d',
#   'pid': '325330679',
#   'hgt': '190in',
#   'eyr': '2023'},
#  {'pid': '745674970',
#   'hgt': '160cm',
#   'eyr': '2021',
#   'byr': '1925',
#   'ecl': 'gry',
#   'hcl': '#341e13',
#   'iyr': '2015',
#   'cid': '297'},
#  {'eyr': '2021',
#   'pid': '596411633',
#   'byr': '1947',
#   'ecl': 'blu',
#   'cid': '191',
#   'hcl': '#341e13',
#   'hgt': '168cm',
#   'iyr': '2019'},
#  {'eyr': '2030',
#   'pid': '#902a6b',
#   'iyr': '1997',
#   'hcl': '11f396',
#   'hgt': '188cm',
#   'byr': '2025',
#   'ecl': 'dne'},
#  {'eyr': '2025',
#   'byr': '2006',
#   'hcl': '#888785',
#   'ecl': 'hzl',
#   'hgt': '187cm',
#   'iyr': '2012',
#   'pid': '017702828'},
#  {'byr': '1988',
#   'hcl': '#18171d',
#   'iyr': '2019',
#   'pid': '110591871',
#   'ecl': 'hzl',
#   'hgt': '160cm',
#   'eyr': '2029'},
#  {'ecl': 'brn',
#   'hcl': '#c0946f',
#   'iyr': '2030',
#   'pid': '264404022',
#   'byr': '1984',
#   'hgt': '59cm',
#   'eyr': '2040'},
#  {'pid': '5973803069',
#   'hcl': '#cfa07d',
#   'ecl': 'grt',
#   'hgt': '153cm',
#   'eyr': '2039',
#   'byr': '1970',
#   'iyr': '2025'},
#  {'hcl': '#fffffd',
#   'iyr': '2022',
#   'byr': '2026',
#   'hgt': '180',
#   'pid': '82035145',
#   'eyr': '2034',
#   'cid': '118',
#   'ecl': 'utc'},
#  {'hgt': '186cm',
#   'eyr': '2026',
#   'ecl': 'brn',
#   'iyr': '2013',
#   'hcl': '#8f4c9b',
#   'pid': '010260339',
#   'byr': '1948'},
#  {'ecl': 'amb',
#   'hcl': '#18171d',
#   'iyr': '2020',
#   'pid': '259501214',
#   'byr': '1978',
#   'hgt': '193cm',
#   'cid': '263',
#   'eyr': '2022'},
#  {'hgt': '161cm',
#   'iyr': '2015',
#   'byr': '2014',
#   'eyr': '2003',
#   'pid': '708958872',
#   'ecl': 'grt',
#   'hcl': 'f4a430'},
#  {'hgt': '170cm',
#   'eyr': '2021',
#   'pid': '911638274',
#   'cid': '110',
#   'byr': '1963',
#   'ecl': 'blu',
#   'iyr': '2015',
#   'hcl': '1eda64'},
#  {'ecl': 'oth',
#   'byr': '1949',
#   'hgt': '174cm',
#   'hcl': '#18171d',
#   'eyr': '2022',
#   'iyr': '2019',
#   'pid': '305857230'},
#  {'ecl': 'gry',
#   'hcl': '#a97842',
#   'pid': '971971076',
#   'byr': '2002',
#   'iyr': '2019',
#   'hgt': '188cm',
#   'eyr': '2022',
#   'cid': '238'},
#  {'eyr': '2027',
#   'pid': '221315043',
#   'iyr': '2010',
#   'hgt': '159cm',
#   'ecl': 'blu',
#   'byr': '1998',
#   'hcl': '#6b5442'},
#  {'hcl': '#888785',
#   'byr': '1926',
#   'eyr': '2022',
#   'pid': '433807814',
#   'ecl': 'grn',
#   'iyr': '2010',
#   'hgt': '181cm'},
#  {'ecl': 'grn',
#   'hgt': '164cm',
#   'byr': '1951',
#   'hcl': '#18171d',
#   'cid': '75',
#   'pid': '845508281',
#   'eyr': '2021',
#   'iyr': '2017'},
#  {'hcl': '#623a2f',
#   'pid': '497429747',
#   'hgt': '189cm',
#   'byr': '1987',
#   'eyr': '2027',
#   'iyr': '2012',
#   'cid': '95',
#   'ecl': 'hzl'},
#  {'byr': '2000',
#   'hgt': '165cm',
#   'iyr': '2017',
#   'pid': '519443292',
#   'eyr': '2029',
#   'cid': '240',
#   'hcl': '#a97842',
#   'ecl': 'blu'},
#  {'cid': '67',
#   'pid': '038299774',
#   'eyr': '2023',
#   'iyr': '2015',
#   'hgt': '179cm',
#   'byr': '1941',
#   'hcl': '#18171d',
#   'ecl': 'amb'},
#  {'byr': '2000',
#   'eyr': '2025',
#   'ecl': 'oth',
#   'iyr': '2017',
#   'pid': '334154607',
#   'hcl': '#fffffd',
#   'hgt': '173cm'},
#  {'hcl': '#888785',
#   'ecl': 'amb',
#   'cid': '131',
#   'iyr': '2018',
#   'byr': '1996',
#   'eyr': '2026',
#   'hgt': '180cm',
#   'pid': '709543988'},
#  {'iyr': '1988',
#   'pid': '263277424',
#   'hcl': 'ee8912',
#   'byr': '1942',
#   'ecl': 'gry',
#   'eyr': '2040',
#   'hgt': '161cm'},
#  {'eyr': '2020',
#   'byr': '1966',
#   'iyr': '2020',
#   'hgt': '169cm',
#   'pid': '611918000',
#   'hcl': '#7d3b0c',
#   'ecl': 'hzl'},
#  {'hgt': '164cm',
#   'ecl': 'brn',
#   'iyr': '2015',
#   'pid': '192054454',
#   'hcl': '#6b5442',
#   'byr': '1987',
#   'eyr': '2022'},
#  {'byr': '1952',
#   'ecl': 'zzz',
#   'pid': '215953654',
#   'eyr': '2021',
#   'hcl': '#efcc98',
#   'hgt': '153cm',
#   'iyr': '2026'},
#  {'hgt': '167cm',
#   'hcl': '#b6652a',
#   'pid': '847614726',
#   'eyr': '2022',
#   'ecl': 'gry',
#   'byr': '1990',
#   'iyr': '2015'},
#  {'pid': '613273980',
#   'hcl': '#a97842',
#   'ecl': 'oth',
#   'byr': '1924',
#   'hgt': '179cm',
#   'eyr': '2027',
#   'iyr': '1950'},
#  {'hcl': 'z',
#   'hgt': '70cm',
#   'pid': '18807747',
#   'cid': '284',
#   'byr': '2023',
#   'eyr': '2035',
#   'ecl': '#4a1501',
#   'iyr': '1954'},
#  {'iyr': '2016',
#   'hgt': '152cm',
#   'pid': '886247173',
#   'byr': '1940',
#   'hcl': '#c0946f',
#   'eyr': '2027',
#   'ecl': 'oth',
#   'cid': '150'},
#  {'hgt': '152cm',
#   'hcl': '#48cfdf',
#   'eyr': '2025',
#   'cid': '277',
#   'ecl': 'oth',
#   'pid': '246230621',
#   'byr': '1932',
#   'iyr': '2020'},
#  {'ecl': 'amb',
#   'pid': '871180042',
#   'cid': '117',
#   'hcl': '#602927',
#   'iyr': '2011',
#   'hgt': '152cm',
#   'eyr': '2030',
#   'byr': '1999'},
#  {'eyr': '2024',
#   'ecl': 'hzl',
#   'hgt': '171cm',
#   'byr': '1934',
#   'pid': '356408125',
#   'iyr': '2019',
#   'hcl': '#b6652a',
#   'cid': '169'},
#  {'eyr': '2023',
#   'hcl': '#7d3b0c',
#   'byr': '1934',
#   'hgt': '67in',
#   'ecl': 'oth',
#   'pid': '191785527',
#   'cid': '117',
#   'iyr': '2016'},
#  {'iyr': '2029',
#   'hcl': '#602927',
#   'eyr': '2022',
#   'byr': '1931',
#   'ecl': 'oth',
#   'hgt': '192cm',
#   'pid': '231475143'},
#  {'ecl': 'grn',
#   'iyr': '2014',
#   'cid': '250',
#   'hcl': '#b6652a',
#   'byr': '1970',
#   'pid': '675238417',
#   'hgt': '162cm',
#   'eyr': '2026'},
#  {'ecl': 'brn',
#   'hcl': '#623a2f',
#   'eyr': '2021',
#   'pid': '293293433',
#   'hgt': '158',
#   'byr': '1977',
#   'iyr': '2019'},
#  {'hgt': '61cm',
#   'eyr': '2027',
#   'ecl': 'amb',
#   'pid': '181cm',
#   'iyr': '1932',
#   'byr': '1974',
#   'hcl': '#18171d'},
#  {'byr': '1968',
#   'hgt': '167cm',
#   'hcl': '#a97842',
#   'eyr': '2022',
#   'iyr': '2018',
#   'ecl': 'hzl',
#   'pid': '940968694'},
#  {'iyr': '1943',
#   'hgt': '96',
#   'cid': '229',
#   'hcl': 'z',
#   'eyr': '1990',
#   'byr': '2007',
#   'pid': '#25aa73',
#   'ecl': '#74592e'},
#  {'hgt': '182cm',
#   'iyr': '2018',
#   'ecl': 'hzl',
#   'eyr': '2029',
#   'byr': '1946',
#   'pid': '602345030',
#   'hcl': '#ceb3a1'},
#  {'pid': '750306036',
#   'eyr': '2020',
#   'hgt': '181in',
#   'ecl': 'xry',
#   'iyr': '2011',
#   'hcl': 'z',
#   'byr': '1971',
#   'cid': '71'},
#  {'pid': '183825747',
#   'iyr': '2019',
#   'hcl': '#6b5442',
#   'byr': '1974',
#   'hgt': '180cm',
#   'eyr': '2028',
#   'ecl': 'amb'},
#  {'ecl': 'brn',
#   'cid': '200',
#   'pid': '576495225',
#   'byr': '1924',
#   'hcl': '#efcc98',
#   'eyr': '2022',
#   'iyr': '2017',
#   'hgt': '185cm'},
#  {'iyr': '2020',
#   'hgt': '167cm',
#   'byr': '1965',
#   'ecl': 'brn',
#   'hcl': '#888785',
#   'eyr': '2028',
#   'pid': '752062953'},
#  {'byr': '2026',
#   'hcl': 'z',
#   'eyr': '2020',
#   'ecl': '#b4ec74',
#   'pid': '187cm',
#   'iyr': '1974',
#   'cid': '326',
#   'hgt': '150cm'},
#  {'byr': '1996',
#   'pid': '507323629',
#   'iyr': '2015',
#   'cid': '347',
#   'eyr': '2026',
#   'hcl': '#efcc98',
#   'ecl': 'amb',
#   'hgt': '157cm'},
#  {'byr': '2017',
#   'pid': '456780590',
#   'hcl': '#888785',
#   'eyr': '1966',
#   'ecl': 'amb',
#   'iyr': '2023',
#   'cid': '187',
#   'hgt': '62cm'},
#  {'ecl': 'hzl',
#   'iyr': '2015',
#   'hcl': '#6b5442',
#   'hgt': '152cm',
#   'eyr': '2028',
#   'byr': '1982',
#   'pid': '003269467'},
#  {'iyr': '2017',
#   'eyr': '2026',
#   'ecl': 'blu',
#   'cid': '70',
#   'hcl': '#7d3b0c',
#   'byr': '1966',
#   'pid': '160330947',
#   'hgt': '189cm'},
#  {'iyr': '2010',
#   'ecl': 'amb',
#   'hgt': '164cm',
#   'eyr': '2029',
#   'byr': '1963',
#   'pid': '596606374',
#   'hcl': '#efcc98'},
#  {'hcl': '#fffffd',
#   'cid': '277',
#   'pid': '102326370',
#   'hgt': '154cm',
#   'eyr': '2026',
#   'iyr': '2012',
#   'byr': '1968',
#   'ecl': 'hzl'},
#  {'ecl': 'oth',
#   'pid': '477189554',
#   'hcl': '#6b5442',
#   'eyr': '2022',
#   'byr': '1948',
#   'hgt': '74in',
#   'cid': '181',
#   'iyr': '2016'},
#  {'hgt': '169cm',
#   'hcl': '#d7bc93',
#   'cid': '344',
#   'ecl': 'oth',
#   'pid': '#09c55d',
#   'iyr': '2017',
#   'eyr': '2030',
#   'byr': '1928'},
#  {'hcl': '5d02ff',
#   'ecl': '#ca7901',
#   'iyr': '1959',
#   'byr': '2006',
#   'eyr': '2022',
#   'hgt': '164in',
#   'pid': '#d6cdfd'},
#  {'ecl': 'amb',
#   'pid': '5739190196',
#   'eyr': '2021',
#   'hgt': '157in',
#   'hcl': '#efcc98',
#   'byr': '2018',
#   'iyr': '2028'},
#  {'byr': '1995',
#   'ecl': 'hzl',
#   'iyr': '2017',
#   'hcl': '#a97842',
#   'pid': '917039291',
#   'eyr': '2026',
#   'hgt': '175cm'},
#  {'iyr': '2017',
#   'pid': '756519868',
#   'hcl': '#623a2f',
#   'eyr': '2028',
#   'hgt': '158cm',
#   'ecl': 'amb',
#   'byr': '1957'},
#  {'iyr': '2012',
#   'hgt': '158cm',
#   'byr': '2014',
#   'pid': '973021666',
#   'hcl': 'f04766',
#   'eyr': '2035',
#   'ecl': 'utc'},
#  {'ecl': 'blu',
#   'byr': '1989',
#   'eyr': '2022',
#   'pid': '520765501',
#   'cid': '200',
#   'hgt': '193cm',
#   'hcl': '#a97842',
#   'iyr': '2011'},
#  {'byr': '1959',
#   'ecl': 'blu',
#   'hcl': '#733820',
#   'cid': '284',
#   'hgt': '162cm',
#   'eyr': '2022',
#   'pid': '751629408',
#   'iyr': '2016'},
#  {'byr': '1978',
#   'cid': '301',
#   'ecl': 'oth',
#   'hgt': '67cm',
#   'hcl': '#888785',
#   'eyr': '2040',
#   'iyr': '2025',
#   'pid': '26038514'},
#  {'hcl': '#a97842',
#   'hgt': '186cm',
#   'ecl': 'grn',
#   'byr': '1969',
#   'pid': '460360492',
#   'iyr': '2011',
#   'eyr': '2028'},
#  {'iyr': '2019',
#   'hcl': '3463cc',
#   'ecl': 'amb',
#   'pid': '4089063078',
#   'eyr': '2022',
#   'hgt': '150cm',
#   'byr': '2007'},
#  {'eyr': '2028',
#   'hcl': '#ceb3a1',
#   'hgt': '191cm',
#   'iyr': '2019',
#   'pid': '737842199',
#   'ecl': 'blu',
#   'cid': '268',
#   'byr': '1925'},
#  {'pid': '868397851',
#   'hcl': '#efcc98',
#   'ecl': 'grn',
#   'iyr': '2017',
#   'eyr': '2021',
#   'byr': '1943',
#   'hgt': '179cm'},
#  {'hcl': '#623a2f',
#   'byr': '1987',
#   'eyr': '2023',
#   'iyr': '2019',
#   'hgt': '152cm',
#   'pid': '473569020',
#   'ecl': 'grn'},
#  {'pid': '953968630',
#   'hgt': '175cm',
#   'byr': '1971',
#   'ecl': 'blu',
#   'hcl': '#623a2f',
#   'iyr': '2017',
#   'cid': '336',
#   'eyr': '2030'},
#  {'ecl': 'grt',
#   'hgt': '74cm',
#   'byr': '2022',
#   'eyr': '2024',
#   'pid': '39114027',
#   'iyr': '2026',
#   'hcl': '4b5675'},
#  {'pid': '800367032',
#   'hcl': '#341e13',
#   'ecl': '#765111',
#   'iyr': '2012',
#   'byr': '2006',
#   'hgt': '166cm',
#   'cid': '291',
#   'eyr': '2027'},
#  {'eyr': '2021',
#   'iyr': '2012',
#   'pid': '876581393',
#   'ecl': 'amb',
#   'hcl': '#866857',
#   'hgt': '64in',
#   'byr': '1993'},
#  {'iyr': '2017',
#   'byr': '1996',
#   'ecl': 'hzl',
#   'pid': '038990744',
#   'eyr': '2028',
#   'hgt': '177cm',
#   'hcl': '#c0946f'},
#  {'hcl': '#4214a6',
#   'eyr': '2021',
#   'iyr': '2019',
#   'cid': '72',
#   'byr': '1939',
#   'ecl': 'hzl',
#   'pid': '783071912',
#   'hgt': '187cm'},
#  {'eyr': '2020',
#   'hgt': '158cm',
#   'pid': '274060737',
#   'cid': '277',
#   'iyr': '2015',
#   'hcl': '#bf9b5e',
#   'byr': '1950',
#   'ecl': 'brn'},
#  {'byr': '1921',
#   'hcl': '#7d3b0c',
#   'cid': '329',
#   'hgt': '155cm',
#   'eyr': '2030',
#   'pid': '718399669',
#   'iyr': '2011',
#   'ecl': 'brn'},
#  {'cid': '147',
#   'eyr': '2021',
#   'hgt': '167cm',
#   'iyr': '2010',
#   'ecl': 'grn',
#   'byr': '1975',
#   'hcl': '#6b5442',
#   'pid': '285479783'},
#  {'hgt': '187cm',
#   'byr': '2004',
#   'eyr': '2025',
#   'hcl': 'bb331b',
#   'pid': '851189955',
#   'iyr': '2016',
#   'ecl': 'amb'},
#  {'hcl': '#94007d',
#   'pid': '361561551',
#   'byr': '1927',
#   'eyr': '2026',
#   'iyr': '2020',
#   'ecl': 'gry',
#   'hgt': '158cm'},
#  {'byr': '1993',
#   'pid': '#24c4af',
#   'iyr': '2023',
#   'hgt': '175cm',
#   'eyr': '2028',
#   'hcl': 'z',
#   'ecl': 'hzl',
#   'cid': '308'},
#  {'byr': '1985',
#   'hcl': '#c0946f',
#   'eyr': '2034',
#   'hgt': '172cm',
#   'cid': '300',
#   'iyr': '2013',
#   'ecl': 'gry',
#   'pid': '389455676'},
#  {'pid': '836559549',
#   'iyr': '2011',
#   'hgt': '167cm',
#   'ecl': 'amb',
#   'hcl': '#c0946f',
#   'eyr': '2026',
#   'byr': '1981'},
#  {'pid': '111085991',
#   'iyr': '2011',
#   'ecl': 'blu',
#   'eyr': '2026',
#   'cid': '311',
#   'byr': '1920',
#   'hgt': '182cm',
#   'hcl': '#602927'},
#  {'ecl': 'oth',
#   'pid': '284436132',
#   'byr': '1929',
#   'cid': '121',
#   'eyr': '2027',
#   'iyr': '2010',
#   'hgt': '75in',
#   'hcl': '#6b5442'},
#  {'byr': '1987',
#   'hcl': '#7d3b0c',
#   'iyr': '2018',
#   'hgt': '180cm',
#   'ecl': 'blu',
#   'eyr': '2029',
#   'pid': '878348021'},
#  {'eyr': '2030',
#   'pid': '039638764',
#   'ecl': 'hzl',
#   'hgt': '190cm',
#   'byr': '1926',
#   'cid': '294',
#   'hcl': '#b6652a',
#   'iyr': '2017'}]

# %%
import re


for p in v:
    for key in num_keys:
        p[key]=int(p[key])
        
    if p['byr'] < byr_min or p['byr'] > byr_max:
        p.clear()
        continue
    if p['iyr'] < iyr_min or p['iyr'] > iyr_max:
        p.clear()
        continue
    if p['eyr'] < eyr_min or p['eyr'] > eyr_max:
        p.clear()
        continue
        
    if len(p['pid']) != pid_max:
        p.clear()
        continue
        
    hgt = p['hgt']
    if 'cm' not in hgt:
        if 'in' not in hgt:
            p.clear()
            continue
    if 'in' not in hgt:
        if 'cm' not in hgt:
            p.clear()
            continue
    if 'cm' in hgt:
        newhgt = re.split('(cm)', hgt)
        newhgt[0] = int(newhgt[0])
        p['hgt'] = newhgt[:2]
        if p['hgt'][0] < cm_min or p['hgt'][0] > cm_max:
            p.clear()
            continue
    if 'in' in hgt:
        newhgt = re.split('(in)', hgt)
        newhgt[0] = int(newhgt[0])
        p['hgt'] = newhgt[:2]
        if p['hgt'][0] < in_min or p['hgt'][0] > in_max:
            p.clear()
            continue
    
    if p['ecl'] not in ecl_opts:
        p.clear()
        continue
    
    if p['hcl'][0] != '#':
        p.clear()
        continue
    if len(p['hcl']) > 7:
        p.clear()
        continue
    

v = [i for i in v if i]
v
# Out:
# [{'eyr': 2024,
#   'pid': '662406624',
#   'hcl': '#cfa07d',
#   'byr': 1947,
#   'iyr': 2015,
#   'ecl': 'amb',
#   'hgt': [150, 'cm']},
#  {'iyr': 2013,
#   'byr': 1997,
#   'hgt': [182, 'cm'],
#   'hcl': '#ceb3a1',
#   'eyr': 2027,
#   'ecl': 'gry',
#   'cid': '102',
#   'pid': '018128535'},
#  {'hcl': '#a97842',
#   'eyr': 2026,
#   'byr': 1980,
#   'ecl': 'grn',
#   'pid': '726519569',
#   'hgt': [184, 'cm'],
#   'cid': '132',
#   'iyr': 2011},
#  {'ecl': 'grn',
#   'hcl': '#6b5442',
#   'pid': '619743219',
#   'cid': '69',
#   'hgt': [176, 'cm'],
#   'eyr': 2027,
#   'iyr': 2012,
#   'byr': 1980},
#  {'ecl': 'brn',
#   'byr': 1969,
#   'iyr': 2014,
#   'hgt': [164, 'cm'],
#   'eyr': 2020,
#   'pid': '982796633',
#   'hcl': '#602927'},
#  {'cid': '117',
#   'hcl': '#efcc98',
#   'iyr': 2010,
#   'pid': '322719183',
#   'hgt': [176, 'cm'],
#   'eyr': 2020,
#   'byr': 1957,
#   'ecl': 'brn'},
#  {'byr': 1954,
#   'hgt': [178, 'cm'],
#   'hcl': '#38f7fd',
#   'pid': '838813262',
#   'ecl': 'blu',
#   'eyr': 2029,
#   'iyr': 2019},
#  {'eyr': 2023,
#   'ecl': 'amb',
#   'iyr': 2020,
#   'byr': 1927,
#   'pid': '242570886',
#   'hcl': '#18171d',
#   'hgt': [192, 'cm']},
#  {'ecl': 'hzl',
#   'byr': 1953,
#   'eyr': 2023,
#   'hcl': '#866857',
#   'hgt': [181, 'cm'],
#   'iyr': 2010,
#   'pid': '568185567'},
#  {'byr': 1924,
#   'cid': '290',
#   'iyr': 2010,
#   'ecl': 'amb',
#   'eyr': 2020,
#   'hgt': [156, 'cm'],
#   'hcl': '#7d3b0c',
#   'pid': '795497164'},
#  {'ecl': 'gry',
#   'pid': '474303066',
#   'iyr': 2011,
#   'hcl': '#18171d',
#   'hgt': [165, 'cm'],
#   'byr': 1921,
#   'eyr': 2024},
#  {'hcl': '#6b5442',
#   'ecl': 'amb',
#   'iyr': 2020,
#   'hgt': [191, 'cm'],
#   'byr': 1949,
#   'cid': '301',
#   'pid': '075846582',
#   'eyr': 2029},
#  {'hcl': '#a97842',
#   'cid': '186',
#   'iyr': 2014,
#   'ecl': 'gry',
#   'hgt': [191, 'cm'],
#   'eyr': 2023,
#   'pid': '645548969',
#   'byr': 1956},
#  {'pid': '620857794',
#   'eyr': 2022,
#   'byr': 1950,
#   'hgt': [159, 'cm'],
#   'hcl': '#ceb3a1',
#   'ecl': 'amb',
#   'iyr': 2015},
#  {'iyr': 2020,
#   'eyr': 2021,
#   'byr': 1937,
#   'pid': '735047371',
#   'cid': '159',
#   'ecl': 'blu',
#   'hgt': [177, 'cm'],
#   'hcl': '#22b774'},
#  {'ecl': 'hzl',
#   'hcl': '#6b5442',
#   'byr': 1933,
#   'iyr': 2019,
#   'pid': '348486702',
#   'eyr': 2020,
#   'hgt': [193, 'cm']},
#  {'byr': 1928,
#   'ecl': 'gry',
#   'eyr': 2028,
#   'hcl': '#fffffd',
#   'pid': '571149069',
#   'iyr': 2012,
#   'hgt': [175, 'cm']},
#  {'iyr': 2017,
#   'byr': 1963,
#   'ecl': 'grn',
#   'hgt': [175, 'cm'],
#   'pid': '160915270',
#   'eyr': 2028,
#   'hcl': '#cfa07d'},
#  {'pid': '569740130',
#   'hgt': [171, 'cm'],
#   'hcl': '#733820',
#   'ecl': 'gry',
#   'eyr': 2024,
#   'iyr': 2020,
#   'byr': 1973},
#  {'byr': 1937,
#   'iyr': 2016,
#   'ecl': 'gry',
#   'hgt': [181, 'cm'],
#   'pid': '521705827',
#   'hcl': '#b6652a',
#   'eyr': 2027,
#   'cid': '295'},
#  {'hgt': [156, 'cm'],
#   'ecl': 'blu',
#   'iyr': 2019,
#   'hcl': '#866857',
#   'pid': '662418718',
#   'byr': 2000,
#   'eyr': 2024},
#  {'byr': 1971,
#   'pid': '693616099',
#   'hcl': '#efcc98',
#   'hgt': [175, 'cm'],
#   'iyr': 2016,
#   'ecl': 'gry',
#   'eyr': 2023},
#  {'iyr': 2013,
#   'eyr': 2024,
#   'ecl': 'gry',
#   'pid': '414295491',
#   'byr': 1986,
#   'hgt': [188, 'cm'],
#   'hcl': '#b6652a'},
#  {'eyr': 2022,
#   'byr': 1975,
#   'iyr': 2020,
#   'ecl': 'grn',
#   'cid': '68',
#   'hcl': '#a97842',
#   'hgt': [151, 'cm'],
#   'pid': '229803943'},
#  {'cid': '258',
#   'iyr': 2012,
#   'ecl': 'hzl',
#   'byr': 2001,
#   'eyr': 2021,
#   'hcl': '#866857',
#   'pid': '990590217',
#   'hgt': [172, 'cm']},
#  {'hcl': '#602927',
#   'byr': 1933,
#   'eyr': 2028,
#   'hgt': [165, 'cm'],
#   'ecl': 'gry',
#   'iyr': 2018,
#   'pid': '658484617'},
#  {'ecl': 'oth',
#   'hgt': [188, 'cm'],
#   'cid': '110',
#   'pid': '056975690',
#   'iyr': 2016,
#   'byr': 1950,
#   'eyr': 2023,
#   'hcl': '#cfa07d'},
#  {'cid': '342',
#   'hcl': '#fffffd',
#   'eyr': 2024,
#   'pid': '153555359',
#   'byr': 1974,
#   'ecl': 'gry',
#   'hgt': [191, 'cm'],
#   'iyr': 2020},
#  {'pid': '552331609',
#   'ecl': 'grn',
#   'hgt': [171, 'cm'],
#   'eyr': 2022,
#   'hcl': '#b6652a',
#   'iyr': 2020,
#   'byr': 1931},
#  {'hgt': [177, 'cm'],
#   'iyr': 2010,
#   'pid': '934058099',
#   'eyr': 2020,
#   'ecl': 'blu',
#   'byr': 1967,
#   'cid': '112',
#   'hcl': '#7d3b0c'},
#  {'eyr': 2020,
#   'iyr': 2019,
#   'hcl': '#a97842',
#   'pid': '149148750',
#   'ecl': 'brn',
#   'hgt': [159, 'cm'],
#   'byr': 1981,
#   'cid': '339'},
#  {'cid': '344',
#   'eyr': 2021,
#   'byr': 1968,
#   'pid': '777786047',
#   'ecl': 'grn',
#   'hgt': [192, 'cm'],
#   'hcl': '#888785',
#   'iyr': 2015},
#  {'hgt': [173, 'cm'],
#   'eyr': 2030,
#   'hcl': '#733820',
#   'pid': '610226642',
#   'byr': 1954,
#   'cid': '80',
#   'iyr': 2013,
#   'ecl': 'blu'},
#  {'byr': 1999,
#   'eyr': 2023,
#   'ecl': 'amb',
#   'pid': '912145128',
#   'hgt': [181, 'cm'],
#   'iyr': 2015,
#   'hcl': '#a97842'},
#  {'eyr': 2027,
#   'hgt': [188, 'cm'],
#   'pid': '080715145',
#   'hcl': '#341e13',
#   'iyr': 2013,
#   'ecl': 'oth',
#   'byr': 1965},
#  {'eyr': 2028,
#   'iyr': 2016,
#   'hcl': '#623a2f',
#   'pid': '208417572',
#   'byr': 1929,
#   'cid': '137',
#   'ecl': 'hzl',
#   'hgt': [167, 'cm']},
#  {'hcl': '#6b5442',
#   'ecl': 'grn',
#   'byr': 1938,
#   'eyr': 2023,
#   'cid': '307',
#   'hgt': [59, 'in'],
#   'iyr': 2014,
#   'pid': '205268145'},
#  {'pid': '047489285',
#   'eyr': 2026,
#   'hcl': '#b6652a',
#   'byr': 1920,
#   'iyr': 2015,
#   'hgt': [183, 'cm'],
#   'ecl': 'gry'},
#  {'iyr': 2011,
#   'byr': 1981,
#   'hgt': [186, 'cm'],
#   'cid': '117',
#   'hcl': '#6b5442',
#   'ecl': 'amb',
#   'pid': '756830713',
#   'eyr': 2026},
#  {'ecl': 'hzl',
#   'cid': '65',
#   'pid': '679487194',
#   'byr': 1986,
#   'hgt': [169, 'cm'],
#   'hcl': '#cfa07d',
#   'eyr': 2025,
#   'iyr': 2013},
#  {'eyr': 2026,
#   'pid': '523515724',
#   'iyr': 2013,
#   'byr': 1973,
#   'hgt': [167, 'cm'],
#   'ecl': 'grn',
#   'hcl': '#866857'},
#  {'eyr': 2020,
#   'iyr': 2016,
#   'ecl': 'brn',
#   'hcl': '#ceb3a1',
#   'byr': 1966,
#   'pid': '696621560',
#   'cid': '62',
#   'hgt': [59, 'in']},
#  {'eyr': 2021,
#   'iyr': 2012,
#   'hcl': '#6b5442',
#   'ecl': 'amb',
#   'hgt': [169, 'cm'],
#   'pid': '969150085',
#   'byr': 1925},
#  {'ecl': 'brn',
#   'hgt': [175, 'cm'],
#   'byr': 1992,
#   'iyr': 2016,
#   'pid': '415209726',
#   'eyr': 2027,
#   'cid': '72',
#   'hcl': '#866857'},
#  {'iyr': 2017,
#   'byr': 1940,
#   'eyr': 2025,
#   'pid': '115098205',
#   'hgt': [151, 'cm'],
#   'ecl': 'grn',
#   'cid': '122',
#   'hcl': '#6b5442'},
#  {'hcl': '#efcc98',
#   'iyr': 2020,
#   'pid': '709548547',
#   'hgt': [179, 'cm'],
#   'eyr': 2030,
#   'ecl': 'gry',
#   'byr': 1975},
#  {'cid': '217',
#   'hcl': '#888785',
#   'eyr': 2029,
#   'ecl': 'hzl',
#   'iyr': 2013,
#   'pid': '160053490',
#   'hgt': [166, 'cm'],
#   'byr': 1992},
#  {'hgt': [154, 'cm'],
#   'iyr': 2010,
#   'ecl': 'blu',
#   'pid': '717041634',
#   'byr': 1928,
#   'cid': '123',
#   'eyr': 2027,
#   'hcl': '#a97842'},
#  {'hgt': [179, 'cm'],
#   'pid': '065528723',
#   'hcl': '#888785',
#   'byr': 1937,
#   'eyr': 2028,
#   'iyr': 2013,
#   'ecl': 'hzl'},
#  {'eyr': 2028,
#   'hgt': [157, 'cm'],
#   'hcl': '#733820',
#   'iyr': 2012,
#   'ecl': 'blu',
#   'byr': 1952,
#   'pid': '915063263',
#   'cid': '335'},
#  {'eyr': 2023,
#   'hcl': '#efcc98',
#   'pid': '490625944',
#   'byr': 1961,
#   'ecl': 'grn',
#   'hgt': [155, 'cm'],
#   'iyr': 2018},
#  {'pid': '491396731',
#   'eyr': 2027,
#   'hgt': [172, 'cm'],
#   'hcl': '#623a2f',
#   'cid': '92',
#   'iyr': 2017,
#   'byr': 1983,
#   'ecl': 'grn'},
#  {'hcl': '#fffffd',
#   'iyr': 2018,
#   'byr': 1983,
#   'pid': '714591144',
#   'ecl': 'grn',
#   'eyr': 2021,
#   'hgt': [160, 'cm']},
#  {'eyr': 2027,
#   'hgt': [63, 'in'],
#   'ecl': 'blu',
#   'byr': 1987,
#   'pid': '397963077',
#   'iyr': 2018,
#   'hcl': '#ceb3a1'},
#  {'eyr': 2027,
#   'hgt': [184, 'cm'],
#   'hcl': '#6b5442',
#   'iyr': 2012,
#   'byr': 1984,
#   'ecl': 'blu',
#   'pid': '196287205'},
#  {'iyr': 2017,
#   'eyr': 2028,
#   'hcl': '#623a2f',
#   'byr': 1964,
#   'ecl': 'grn',
#   'pid': '198467794',
#   'hgt': [169, 'cm']},
#  {'byr': 1991,
#   'iyr': 2019,
#   'hgt': [164, 'cm'],
#   'pid': '282852411',
#   'cid': '340',
#   'ecl': 'amb',
#   'hcl': '#341e13',
#   'eyr': 2027},
#  {'eyr': 2020,
#   'iyr': 2014,
#   'ecl': 'grn',
#   'hcl': '#866857',
#   'hgt': [158, 'cm'],
#   'byr': 1931,
#   'pid': '321748597'},
#  {'hcl': '#fd033b',
#   'eyr': 2026,
#   'ecl': 'blu',
#   'iyr': 2016,
#   'byr': 1953,
#   'hgt': [157, 'cm'],
#   'pid': '502619036'},
#  {'ecl': 'blu',
#   'iyr': 2016,
#   'pid': '842400950',
#   'hcl': '#733820',
#   'cid': '266',
#   'eyr': 2027,
#   'byr': 1931,
#   'hgt': [161, 'cm']},
#  {'cid': '197',
#   'pid': '204952666',
#   'ecl': 'amb',
#   'hgt': [70, 'in'],
#   'iyr': 2016,
#   'byr': 1936,
#   'hcl': '#98cbe3',
#   'eyr': 2025},
#  {'eyr': 2025,
#   'pid': '579385370',
#   'hgt': [193, 'cm'],
#   'hcl': '#c0946f',
#   'byr': 1979,
#   'iyr': 2016,
#   'ecl': 'amb',
#   'cid': '284'},
#  {'eyr': 2029,
#   'byr': 1946,
#   'pid': '278271295',
#   'ecl': 'grn',
#   'hcl': '#cfa07d',
#   'cid': '271',
#   'hgt': [172, 'cm'],
#   'iyr': 2020},
#  {'pid': '731752614',
#   'eyr': 2020,
#   'byr': 1983,
#   'cid': '248',
#   'ecl': 'oth',
#   'hgt': [179, 'cm'],
#   'iyr': 2017,
#   'hcl': '#fffffd'},
#  {'ecl': 'brn',
#   'hgt': [164, 'cm'],
#   'byr': 1969,
#   'hcl': '#cbf9c9',
#   'pid': '022724981',
#   'eyr': 2030,
#   'iyr': 2013,
#   'cid': '244'},
#  {'hgt': [162, 'cm'],
#   'byr': 1974,
#   'iyr': 2015,
#   'pid': '927525094',
#   'hcl': '#3d3011',
#   'ecl': 'blu',
#   'eyr': 2023},
#  {'hgt': [157, 'cm'],
#   'eyr': 2020,
#   'pid': '221286943',
#   'hcl': '#fffffd',
#   'ecl': 'amb',
#   'iyr': 2018,
#   'byr': 1945},
#  {'eyr': 2027,
#   'hcl': '#fffffd',
#   'ecl': 'brn',
#   'cid': '304',
#   'iyr': 2016,
#   'byr': 1969,
#   'pid': '866607511',
#   'hgt': [192, 'cm']},
#  {'hgt': [64, 'in'],
#   'ecl': 'amb',
#   'byr': 1958,
#   'pid': '720439412',
#   'iyr': 2015,
#   'eyr': 2022,
#   'hcl': '#ceb3a1'},
#  {'eyr': 2024,
#   'hgt': [159, 'cm'],
#   'pid': '187867283',
#   'iyr': 2016,
#   'ecl': 'oth',
#   'hcl': '#fffffd',
#   'byr': 1988},
#  {'pid': '718692455',
#   'eyr': 2028,
#   'iyr': 2016,
#   'hcl': '#602927',
#   'ecl': 'blu',
#   'byr': 1954,
#   'cid': '251',
#   'hgt': [182, 'cm']},
#  {'eyr': 2021,
#   'hcl': '#341e13',
#   'ecl': 'amb',
#   'byr': 1933,
#   'hgt': [179, 'cm'],
#   'iyr': 2011,
#   'pid': '083172316'},
#  {'pid': '993701676',
#   'eyr': 2028,
#   'ecl': 'gry',
#   'byr': 1951,
#   'hcl': '#888785',
#   'cid': '116',
#   'iyr': 2020,
#   'hgt': [192, 'cm']},
#  {'hcl': '#a97842',
#   'ecl': 'brn',
#   'byr': 1920,
#   'hgt': [173, 'cm'],
#   'iyr': 2015,
#   'eyr': 2024,
#   'pid': '176967666'},
#  {'byr': 1930,
#   'eyr': 2025,
#   'pid': '792694131',
#   'hgt': [179, 'cm'],
#   'ecl': 'brn',
#   'hcl': '#a97842',
#   'iyr': 2015},
#  {'hgt': [167, 'cm'],
#   'byr': 1960,
#   'eyr': 2022,
#   'hcl': '#efcc98',
#   'cid': '87',
#   'ecl': 'blu',
#   'iyr': 2012,
#   'pid': '431515059'},
#  {'hcl': '#cfa07d',
#   'eyr': 2023,
#   'hgt': [188, 'cm'],
#   'ecl': 'grn',
#   'pid': '081575957',
#   'byr': 1938,
#   'iyr': 2012},
#  {'iyr': 2010,
#   'byr': 1973,
#   'cid': '108',
#   'eyr': 2026,
#   'pid': '880191154',
#   'hcl': '#888785',
#   'hgt': [181, 'cm'],
#   'ecl': 'brn'},
#  {'eyr': 2021,
#   'iyr': 2010,
#   'byr': 1942,
#   'hcl': '#7d3b0c',
#   'ecl': 'hzl',
#   'pid': '886241926',
#   'hgt': [171, 'cm']},
#  {'ecl': 'gry',
#   'pid': '555911148',
#   'hcl': '#733820',
#   'eyr': 2022,
#   'hgt': [154, 'cm'],
#   'iyr': 2012,
#   'byr': 1935,
#   'cid': '338'},
#  {'eyr': 2024,
#   'ecl': 'blu',
#   'byr': 1955,
#   'hcl': '#b6652a',
#   'pid': '517975316',
#   'iyr': 2010,
#   'hgt': [166, 'cm']},
#  {'pid': '133785752',
#   'ecl': 'blu',
#   'eyr': 2024,
#   'byr': 1973,
#   'iyr': 2019,
#   'hcl': '#fffffd',
#   'cid': '236',
#   'hgt': [173, 'cm']},
#  {'hgt': [193, 'cm'],
#   'cid': '259',
#   'hcl': '#18171d',
#   'ecl': 'grn',
#   'byr': 1995,
#   'pid': '727880050',
#   'eyr': 2030,
#   'iyr': 2010},
#  {'iyr': 2012,
#   'hgt': [152, 'cm'],
#   'eyr': 2027,
#   'byr': 1923,
#   'ecl': 'brn',
#   'hcl': '#18171d',
#   'pid': '513722888',
#   'cid': '171'},
#  {'hgt': [154, 'cm'],
#   'eyr': 2024,
#   'hcl': '#6b5442',
#   'iyr': 2017,
#   'byr': 1974,
#   'ecl': 'amb',
#   'pid': '470968353',
#   'cid': '345'},
#  {'hgt': [184, 'cm'],
#   'hcl': '#617375',
#   'eyr': 2028,
#   'byr': 1975,
#   'ecl': 'oth',
#   'iyr': 2018,
#   'pid': '735589126'},
#  {'eyr': 2029,
#   'iyr': 2016,
#   'byr': 1985,
#   'hgt': [192, 'cm'],
#   'hcl': '#602927',
#   'cid': '167',
#   'ecl': 'blu',
#   'pid': '620818510'},
#  {'eyr': 2029,
#   'byr': 1968,
#   'ecl': 'blu',
#   'hgt': [183, 'cm'],
#   'iyr': 2011,
#   'pid': '952376140',
#   'hcl': '#efcc98'},
#  {'iyr': 2020,
#   'byr': 1981,
#   'pid': '850136149',
#   'eyr': 2028,
#   'hgt': [159, 'cm'],
#   'hcl': '#7d3b0c',
#   'ecl': 'brn'},
#  {'ecl': 'brn',
#   'pid': '480452858',
#   'hgt': [65, 'in'],
#   'cid': '340',
#   'eyr': 2022,
#   'byr': 1946,
#   'hcl': '#602927',
#   'iyr': 2015},
#  {'eyr': 2029,
#   'pid': '837224515',
#   'ecl': 'grn',
#   'cid': '231',
#   'hcl': '#733820',
#   'iyr': 2019,
#   'hgt': [159, 'cm'],
#   'byr': 1977},
#  {'pid': '974518338',
#   'byr': 1964,
#   'hcl': '#cfa07d',
#   'ecl': 'grn',
#   'eyr': 2030,
#   'hgt': [61, 'in'],
#   'iyr': 2019},
#  {'eyr': 2027,
#   'iyr': 2019,
#   'cid': '328',
#   'byr': 1961,
#   'hcl': '#6b5442',
#   'ecl': 'blu',
#   'hgt': [177, 'cm'],
#   'pid': '235426720'},
#  {'hgt': [161, 'cm'],
#   'iyr': 2018,
#   'pid': '916160791',
#   'ecl': 'grn',
#   'byr': 1951,
#   'hcl': '#44d03a',
#   'eyr': 2025},
#  {'hgt': [158, 'cm'],
#   'byr': 1942,
#   'iyr': 2012,
#   'hcl': '#602927',
#   'eyr': 2026,
#   'ecl': 'gry',
#   'pid': '651231060'},
#  {'ecl': 'hzl',
#   'cid': '340',
#   'pid': '086942161',
#   'byr': 1986,
#   'hcl': '#a97842',
#   'iyr': 2018,
#   'eyr': 2028,
#   'hgt': [181, 'cm']},
#  {'ecl': 'blu',
#   'pid': '278922687',
#   'cid': '238',
#   'iyr': 2018,
#   'hgt': [153, 'cm'],
#   'eyr': 2027,
#   'byr': 1965,
#   'hcl': '#733820'},
#  {'eyr': 2023,
#   'cid': '208',
#   'hgt': [178, 'cm'],
#   'hcl': '#341e13',
#   'byr': 1937,
#   'pid': '290981079',
#   'iyr': 2010,
#   'ecl': 'grn'},
#  {'hcl': '#888785',
#   'ecl': 'amb',
#   'byr': 1943,
#   'pid': '559804716',
#   'eyr': 2026,
#   'hgt': [166, 'cm'],
#   'iyr': 2019},
#  {'pid': '947831563',
#   'ecl': 'gry',
#   'byr': 1960,
#   'hcl': '#341e13',
#   'iyr': 2016,
#   'hgt': [173, 'cm'],
#   'eyr': 2029},
#  {'ecl': 'blu',
#   'iyr': 2016,
#   'pid': '724632073',
#   'hcl': '#623a2f',
#   'eyr': 2028,
#   'hgt': [192, 'cm'],
#   'byr': 1958},
#  {'hcl': '#efcc98',
#   'byr': 1963,
#   'pid': '290433211',
#   'eyr': 2023,
#   'ecl': 'hzl',
#   'hgt': [172, 'cm'],
#   'iyr': 2013},
#  {'pid': '745674970',
#   'hgt': [160, 'cm'],
#   'eyr': 2021,
#   'byr': 1925,
#   'ecl': 'gry',
#   'hcl': '#341e13',
#   'iyr': 2015,
#   'cid': '297'},
#  {'eyr': 2021,
#   'pid': '596411633',
#   'byr': 1947,
#   'ecl': 'blu',
#   'cid': '191',
#   'hcl': '#341e13',
#   'hgt': [168, 'cm'],
#   'iyr': 2019},
#  {'byr': 1988,
#   'hcl': '#18171d',
#   'iyr': 2019,
#   'pid': '110591871',
#   'ecl': 'hzl',
#   'hgt': [160, 'cm'],
#   'eyr': 2029},
#  {'hgt': [186, 'cm'],
#   'eyr': 2026,
#   'ecl': 'brn',
#   'iyr': 2013,
#   'hcl': '#8f4c9b',
#   'pid': '010260339',
#   'byr': 1948},
#  {'ecl': 'amb',
#   'hcl': '#18171d',
#   'iyr': 2020,
#   'pid': '259501214',
#   'byr': 1978,
#   'hgt': [193, 'cm'],
#   'cid': '263',
#   'eyr': 2022},
#  {'ecl': 'oth',
#   'byr': 1949,
#   'hgt': [174, 'cm'],
#   'hcl': '#18171d',
#   'eyr': 2022,
#   'iyr': 2019,
#   'pid': '305857230'},
#  {'ecl': 'gry',
#   'hcl': '#a97842',
#   'pid': '971971076',
#   'byr': 2002,
#   'iyr': 2019,
#   'hgt': [188, 'cm'],
#   'eyr': 2022,
#   'cid': '238'},
#  {'eyr': 2027,
#   'pid': '221315043',
#   'iyr': 2010,
#   'hgt': [159, 'cm'],
#   'ecl': 'blu',
#   'byr': 1998,
#   'hcl': '#6b5442'},
#  {'hcl': '#888785',
#   'byr': 1926,
#   'eyr': 2022,
#   'pid': '433807814',
#   'ecl': 'grn',
#   'iyr': 2010,
#   'hgt': [181, 'cm']},
#  {'ecl': 'grn',
#   'hgt': [164, 'cm'],
#   'byr': 1951,
#   'hcl': '#18171d',
#   'cid': '75',
#   'pid': '845508281',
#   'eyr': 2021,
#   'iyr': 2017},
#  {'hcl': '#623a2f',
#   'pid': '497429747',
#   'hgt': [189, 'cm'],
#   'byr': 1987,
#   'eyr': 2027,
#   'iyr': 2012,
#   'cid': '95',
#   'ecl': 'hzl'},
#  {'byr': 2000,
#   'hgt': [165, 'cm'],
#   'iyr': 2017,
#   'pid': '519443292',
#   'eyr': 2029,
#   'cid': '240',
#   'hcl': '#a97842',
#   'ecl': 'blu'},
#  {'cid': '67',
#   'pid': '038299774',
#   'eyr': 2023,
#   'iyr': 2015,
#   'hgt': [179, 'cm'],
#   'byr': 1941,
#   'hcl': '#18171d',
#   'ecl': 'amb'},
#  {'byr': 2000,
#   'eyr': 2025,
#   'ecl': 'oth',
#   'iyr': 2017,
#   'pid': '334154607',
#   'hcl': '#fffffd',
#   'hgt': [173, 'cm']},
#  {'hcl': '#888785',
#   'ecl': 'amb',
#   'cid': '131',
#   'iyr': 2018,
#   'byr': 1996,
#   'eyr': 2026,
#   'hgt': [180, 'cm'],
#   'pid': '709543988'},
#  {'eyr': 2020,
#   'byr': 1966,
#   'iyr': 2020,
#   'hgt': [169, 'cm'],
#   'pid': '611918000',
#   'hcl': '#7d3b0c',
#   'ecl': 'hzl'},
#  {'hgt': [164, 'cm'],
#   'ecl': 'brn',
#   'iyr': 2015,
#   'pid': '192054454',
#   'hcl': '#6b5442',
#   'byr': 1987,
#   'eyr': 2022},
#  {'hgt': [167, 'cm'],
#   'hcl': '#b6652a',
#   'pid': '847614726',
#   'eyr': 2022,
#   'ecl': 'gry',
#   'byr': 1990,
#   'iyr': 2015},
#  {'iyr': 2016,
#   'hgt': [152, 'cm'],
#   'pid': '886247173',
#   'byr': 1940,
#   'hcl': '#c0946f',
#   'eyr': 2027,
#   'ecl': 'oth',
#   'cid': '150'},
#  {'hgt': [152, 'cm'],
#   'hcl': '#48cfdf',
#   'eyr': 2025,
#   'cid': '277',
#   'ecl': 'oth',
#   'pid': '246230621',
#   'byr': 1932,
#   'iyr': 2020},
#  {'ecl': 'amb',
#   'pid': '871180042',
#   'cid': '117',
#   'hcl': '#602927',
#   'iyr': 2011,
#   'hgt': [152, 'cm'],
#   'eyr': 2030,
#   'byr': 1999},
#  {'eyr': 2024,
#   'ecl': 'hzl',
#   'hgt': [171, 'cm'],
#   'byr': 1934,
#   'pid': '356408125',
#   'iyr': 2019,
#   'hcl': '#b6652a',
#   'cid': '169'},
#  {'eyr': 2023,
#   'hcl': '#7d3b0c',
#   'byr': 1934,
#   'hgt': [67, 'in'],
#   'ecl': 'oth',
#   'pid': '191785527',
#   'cid': '117',
#   'iyr': 2016},
#  {'ecl': 'grn',
#   'iyr': 2014,
#   'cid': '250',
#   'hcl': '#b6652a',
#   'byr': 1970,
#   'pid': '675238417',
#   'hgt': [162, 'cm'],
#   'eyr': 2026},
#  {'byr': 1968,
#   'hgt': [167, 'cm'],
#   'hcl': '#a97842',
#   'eyr': 2022,
#   'iyr': 2018,
#   'ecl': 'hzl',
#   'pid': '940968694'},
#  {'hgt': [182, 'cm'],
#   'iyr': 2018,
#   'ecl': 'hzl',
#   'eyr': 2029,
#   'byr': 1946,
#   'pid': '602345030',
#   'hcl': '#ceb3a1'},
#  {'pid': '183825747',
#   'iyr': 2019,
#   'hcl': '#6b5442',
#   'byr': 1974,
#   'hgt': [180, 'cm'],
#   'eyr': 2028,
#   'ecl': 'amb'},
#  {'ecl': 'brn',
#   'cid': '200',
#   'pid': '576495225',
#   'byr': 1924,
#   'hcl': '#efcc98',
#   'eyr': 2022,
#   'iyr': 2017,
#   'hgt': [185, 'cm']},
#  {'iyr': 2020,
#   'hgt': [167, 'cm'],
#   'byr': 1965,
#   'ecl': 'brn',
#   'hcl': '#888785',
#   'eyr': 2028,
#   'pid': '752062953'},
#  {'byr': 1996,
#   'pid': '507323629',
#   'iyr': 2015,
#   'cid': '347',
#   'eyr': 2026,
#   'hcl': '#efcc98',
#   'ecl': 'amb',
#   'hgt': [157, 'cm']},
#  {'ecl': 'hzl',
#   'iyr': 2015,
#   'hcl': '#6b5442',
#   'hgt': [152, 'cm'],
#   'eyr': 2028,
#   'byr': 1982,
#   'pid': '003269467'},
#  {'iyr': 2017,
#   'eyr': 2026,
#   'ecl': 'blu',
#   'cid': '70',
#   'hcl': '#7d3b0c',
#   'byr': 1966,
#   'pid': '160330947',
#   'hgt': [189, 'cm']},
#  {'iyr': 2010,
#   'ecl': 'amb',
#   'hgt': [164, 'cm'],
#   'eyr': 2029,
#   'byr': 1963,
#   'pid': '596606374',
#   'hcl': '#efcc98'},
#  {'hcl': '#fffffd',
#   'cid': '277',
#   'pid': '102326370',
#   'hgt': [154, 'cm'],
#   'eyr': 2026,
#   'iyr': 2012,
#   'byr': 1968,
#   'ecl': 'hzl'},
#  {'ecl': 'oth',
#   'pid': '477189554',
#   'hcl': '#6b5442',
#   'eyr': 2022,
#   'byr': 1948,
#   'hgt': [74, 'in'],
#   'cid': '181',
#   'iyr': 2016},
#  {'byr': 1995,
#   'ecl': 'hzl',
#   'iyr': 2017,
#   'hcl': '#a97842',
#   'pid': '917039291',
#   'eyr': 2026,
#   'hgt': [175, 'cm']},
#  {'iyr': 2017,
#   'pid': '756519868',
#   'hcl': '#623a2f',
#   'eyr': 2028,
#   'hgt': [158, 'cm'],
#   'ecl': 'amb',
#   'byr': 1957},
#  {'ecl': 'blu',
#   'byr': 1989,
#   'eyr': 2022,
#   'pid': '520765501',
#   'cid': '200',
#   'hgt': [193, 'cm'],
#   'hcl': '#a97842',
#   'iyr': 2011},
#  {'byr': 1959,
#   'ecl': 'blu',
#   'hcl': '#733820',
#   'cid': '284',
#   'hgt': [162, 'cm'],
#   'eyr': 2022,
#   'pid': '751629408',
#   'iyr': 2016},
#  {'hcl': '#a97842',
#   'hgt': [186, 'cm'],
#   'ecl': 'grn',
#   'byr': 1969,
#   'pid': '460360492',
#   'iyr': 2011,
#   'eyr': 2028},
#  {'eyr': 2028,
#   'hcl': '#ceb3a1',
#   'hgt': [191, 'cm'],
#   'iyr': 2019,
#   'pid': '737842199',
#   'ecl': 'blu',
#   'cid': '268',
#   'byr': 1925},
#  {'pid': '868397851',
#   'hcl': '#efcc98',
#   'ecl': 'grn',
#   'iyr': 2017,
#   'eyr': 2021,
#   'byr': 1943,
#   'hgt': [179, 'cm']},
#  {'hcl': '#623a2f',
#   'byr': 1987,
#   'eyr': 2023,
#   'iyr': 2019,
#   'hgt': [152, 'cm'],
#   'pid': '473569020',
#   'ecl': 'grn'},
#  {'pid': '953968630',
#   'hgt': [175, 'cm'],
#   'byr': 1971,
#   'ecl': 'blu',
#   'hcl': '#623a2f',
#   'iyr': 2017,
#   'cid': '336',
#   'eyr': 2030},
#  {'eyr': 2021,
#   'iyr': 2012,
#   'pid': '876581393',
#   'ecl': 'amb',
#   'hcl': '#866857',
#   'hgt': [64, 'in'],
#   'byr': 1993},
#  {'iyr': 2017,
#   'byr': 1996,
#   'ecl': 'hzl',
#   'pid': '038990744',
#   'eyr': 2028,
#   'hgt': [177, 'cm'],
#   'hcl': '#c0946f'},
#  {'hcl': '#4214a6',
#   'eyr': 2021,
#   'iyr': 2019,
#   'cid': '72',
#   'byr': 1939,
#   'ecl': 'hzl',
#   'pid': '783071912',
#   'hgt': [187, 'cm']},
#  {'eyr': 2020,
#   'hgt': [158, 'cm'],
#   'pid': '274060737',
#   'cid': '277',
#   'iyr': 2015,
#   'hcl': '#bf9b5e',
#   'byr': 1950,
#   'ecl': 'brn'},
#  {'byr': 1921,
#   'hcl': '#7d3b0c',
#   'cid': '329',
#   'hgt': [155, 'cm'],
#   'eyr': 2030,
#   'pid': '718399669',
#   'iyr': 2011,
#   'ecl': 'brn'},
#  {'cid': '147',
#   'eyr': 2021,
#   'hgt': [167, 'cm'],
#   'iyr': 2010,
#   'ecl': 'grn',
#   'byr': 1975,
#   'hcl': '#6b5442',
#   'pid': '285479783'},
#  {'hcl': '#94007d',
#   'pid': '361561551',
#   'byr': 1927,
#   'eyr': 2026,
#   'iyr': 2020,
#   'ecl': 'gry',
#   'hgt': [158, 'cm']},
#  {'pid': '836559549',
#   'iyr': 2011,
#   'hgt': [167, 'cm'],
#   'ecl': 'amb',
#   'hcl': '#c0946f',
#   'eyr': 2026,
#   'byr': 1981},
#  {'pid': '111085991',
#   'iyr': 2011,
#   'ecl': 'blu',
#   'eyr': 2026,
#   'cid': '311',
#   'byr': 1920,
#   'hgt': [182, 'cm'],
#   'hcl': '#602927'},
#  {'ecl': 'oth',
#   'pid': '284436132',
#   'byr': 1929,
#   'cid': '121',
#   'eyr': 2027,
#   'iyr': 2010,
#   'hgt': [75, 'in'],
#   'hcl': '#6b5442'},
#  {'byr': 1987,
#   'hcl': '#7d3b0c',
#   'iyr': 2018,
#   'hgt': [180, 'cm'],
#   'ecl': 'blu',
#   'eyr': 2029,
#   'pid': '878348021'},
#  {'eyr': 2030,
#   'pid': '039638764',
#   'ecl': 'hzl',
#   'hgt': [190, 'cm'],
#   'byr': 1926,
#   'cid': '294',
#   'hcl': '#b6652a',
#   'iyr': 2017}]

# %%
len(v)
# Out:
# 158

# %%
hcls
# Out:
# []
